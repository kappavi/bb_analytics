# %%
import os
import pandas as pd
from sqlalchemy import create_engine, text
from dotenv import load_dotenv
import re
import io
import time

# Load environment variables
load_dotenv('../../.env')

# Create the engine
def get_engine():
    db_user = os.getenv('DB_USER')
    db_password = os.getenv('DB_PASSWORD') 
    db_host = os.getenv('DB_HOST')
    db_port = os.getenv('DB_PORT')
    db_database = os.getenv('DB_DATABASE')
    
    connection_string = f"postgresql+psycopg2://{db_user}:{db_password}@{db_host}:{db_port}/{db_database}"
    
    engine = create_engine(
        connection_string,
        connect_args={
            "sslmode": "require"  # Azure PostgreSQL requires SSL
        }
    )
    return engine

def format_query(query_text, params):
    """
    Format query by replacing $(param_name) with actual values
    Similar to the Node.js formatQuery function
    """
    formatted_query = query_text
    for key, value in params.items():
        # Replace $(key) with the actual value
        pattern = f"\\$\\({key}\\)"
        if isinstance(value, str):
            formatted_query = re.sub(pattern, f"'{value}'", formatted_query)
        else:
            formatted_query = re.sub(pattern, str(value), formatted_query)
    
    return formatted_query

def run_query(query_filename, rawQuery=None, params=None, engine=None):
    """
    Run a SQL query from a file with parameters
    Similar to the Node.js runQuery function
    """
    if engine is None:
        engine = get_engine()
    
    if params is None:
        params = {}
    
    try:
        if rawQuery is None:
            # Read the SQL file
            query_path = os.path.join('queries', query_filename)
            with open(query_path, 'r') as file:
                query_text = file.read()
        else:
            query_text = rawQuery
        
        # Format the query with parameters
        formatted_query = format_query(query_text, params)
        
        # Execute the query and return DataFrame
        df = pd.read_sql(formatted_query, engine)
        return df
        
    except Exception as error:
        print(f"Error while running query: {query_filename} -> {error}")
        print(f"Formatted query:\n{formatted_query}")
        raise error
    

def write_to_table(df, schema_name, table_name, engine=None):
    """
    Write a DataFrame to a table
    """
    if engine is None:
        engine = get_engine()
     # 1) Create empty table matching df’s schema
    df.head(0).to_sql(
        table_name,
        engine,
        schema=schema_name,
        if_exists='replace',
        index=False
    )

    # 2) stream via COPY with quoted columns
    buffer = io.StringIO()
    df.to_csv(buffer, index=False, header=False)
    buffer.seek(0)

    cols = ', '.join(f'"{col}"' for col in df.columns)
    copy_sql = (
        f'COPY "{schema_name}"."{table_name}" ({cols}) '
        'FROM STDIN WITH (FORMAT csv)'
    )

    conn   = engine.raw_connection()
    cursor = conn.cursor()
    try:
        cursor.copy_expert(copy_sql, buffer)
        conn.commit()
    finally:
        cursor.close()
        conn.close()

# %%
import pandas as pd 

# based on the pay period and merchant id, get the pricing info
def get_period_merchant_pricing_info(price_period, merchant_id, use_scraping=True):
    """
    Get pricing info using SQL file with parameters
    """
    params = {
        'price_period': price_period,
        'merchant_id': merchant_id
    }
    if use_scraping:
        df = run_query('get_pricing_info_with_scraping_price.sql', params)
    else:
        df = run_query('get_pricing_info_with_sales.sql', params)
    return df


# filter for item_id = 8225801
df = get_period_merchant_pricing_info(10, 17)
d_8225801 = df[df['item_id'] == 8225801]
d_8225801.head(20)
# Out:
#     bb_id  store_id  item_id                                     name  \
# 0  2319.0      1173  8225801  Golden Curry Sauce Mix Mild 7.8oz(220g)
# 1  2319.0      1173  8225801  Golden Curry Sauce Mix Mild 7.8oz(220g)
#
#                         day  regular_price sale_price  selling_price  \
# 0 2024-11-21 00:00:00+00:00           4.99       3.99           3.99
# 1 2024-11-21 00:00:00+00:00           4.99       3.99           4.99
#
#    unit_cost  units_sold
# 0     2.5306         2.0
# 1     2.5306         4.0

# %%
# all pricing info for all pay periods and merchants
def get_all_pricing_info(use_scraping=True):
    """
    Get all pricing info using SQL file with parameters
    """
    params = {
    }
    if use_scraping:
        df = run_query('get_all_pricing_info_with_scraping.sql', params)
    else:
        df = run_query('get_all_pricing_info_with_sales.sql', params)
    return df

df = get_all_pricing_info()
df.head(5)
# Out:
# Error while running query: get_all_pricing_info_with_scraping.sql -> Not an executable object: {}
# Formatted query:
# {}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/engine/base.py:1411, in Connection.execute(self, statement, parameters, execution_options)
#    1410 try:
# -> 1411     meth = statement._execute_on_connection
#    1412 except AttributeError as err:
#
# AttributeError: 'dict' object has no attribute '_execute_on_connection'
#
# The above exception was the direct cause of the following exception:
#
# ObjectNotExecutableError                  Traceback (most recent call last)
# Cell In[17], line 14
#      11         df = run_query('get_all_pricing_info_with_sales.sql', params)
#      12     return df
# ---> 14 df = get_all_pricing_info()
#      15 df.head(5)
#
# Cell In[17], line 9, in get_all_pricing_info(use_scraping)
#       6 params = {
#       7 }
#       8 if use_scraping:
# ----> 9     df = run_query('get_all_pricing_info_with_scraping.sql', params)
#      10 else:
#      11     df = run_query('get_all_pricing_info_with_sales.sql', params)
#
# Cell In[16], line 74, in run_query(query_filename, rawQuery, params, engine)
#      72 print(f"Error while running query: {query_filename} -> {error}")
#      73 print(f"Formatted query:\n{formatted_query}")
# ---> 74 raise error
#
# Cell In[16], line 68, in run_query(query_filename, rawQuery, params, engine)
#      65     formatted_query = format_query(query_text, params)
#      67     # Execute the query and return DataFrame
# ---> 68     df = pd.read_sql(formatted_query, engine)
#      69     return df
#      71 except Exception as error:
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/sql.py:734, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     724     return pandas_sql.read_table(
#     725         sql,
#     726         index_col=index_col,
#    (...)
#     731         dtype_backend=dtype_backend,
#     732     )
#     733 else:
# --> 734     return pandas_sql.read_query(
#     735         sql,
#     736         index_col=index_col,
#     737         params=params,
#     738         coerce_float=coerce_float,
#     739         parse_dates=parse_dates,
#     740         chunksize=chunksize,
#     741         dtype_backend=dtype_backend,
#     742         dtype=dtype,
#     743     )
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/sql.py:1836, in SQLDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    1779 def read_query(
#    1780     self,
#    1781     sql: str,
#    (...)
#    1788     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    1789 ) -> DataFrame | Iterator[DataFrame]:
#    1790     """
#    1791     Read SQL query into a DataFrame.
#    1792
#    (...)
#    1834
#    1835     """
# -> 1836     result = self.execute(sql, params)
#    1837     columns = result.keys()
#    1839     if chunksize is not None:
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/sql.py:1660, in SQLDatabase.execute(self, sql, params)
#    1658 if isinstance(sql, str):
#    1659     return self.con.exec_driver_sql(sql, *args)
# -> 1660 return self.con.execute(sql, *args)
#
# File ~/Library/Python/3.9/lib/python/site-packages/sqlalchemy/engine/base.py:1413, in Connection.execute(self, statement, parameters, execution_options)
#    1411     meth = statement._execute_on_connection
#    1412 except AttributeError as err:
# -> 1413     raise exc.ObjectNotExecutableError(statement) from err
#    1414 else:
#    1415     return meth(
#    1416         self,
#    1417         distilled_parameters,
#    1418         execution_options or NO_OPTIONS,
#    1419     )
#
# ObjectNotExecutableError: Not an executable object: {}

# %%
df_all_8225801_10_17 = df[(df['item_id'] == 8225801) & (df['period_id'] == 10) & (df['merchant_id'] == 17)]
df_all_8225801_10_17.head(5)
# Out:
#       bb_id  merchant_id  period_id  store_id  item_id  \
# 131  2319.0           17         10      1173  8225801
# 132  2319.0           17         10      1173  8225801
#
#                                         name                       day  \
# 131  Golden Curry Sauce Mix Mild 7.8oz(220g) 2024-11-21 00:00:00+00:00
# 132  Golden Curry Sauce Mix Mild 7.8oz(220g) 2024-11-21 00:00:00+00:00
#
#      regular_price sale_price  selling_price  unit_cost  units_sold  \
# 131           4.99       3.99           3.99     2.5306         2.0
# 132           4.99       3.99           4.99     2.5306         4.0
#
#      avg_basket_size
# 131            99.91
# 132           126.58

# %% [markdown]
# # for single merchant and period:

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import ipywidgets as widgets
from IPython.display import display, clear_output

def get_available_items(df):
    """
    Get all available item IDs and their names from the dataframe
    """
    items = df[['item_id', 'name']].drop_duplicates().sort_values('item_id')
    return items

def calculate_profits(df, item_id):
    """
    Calculate actual profits using unit_cost data
    """
    d = df[df['item_id'] == item_id].copy()
    if d.empty:
        return pd.DataFrame()
    
    # Convert columns to numeric
    numeric_cols = ['regular_price', 'sale_price', 'selling_price', 'units_sold', 'unit_cost']
    for col in numeric_cols:
        if col in d.columns:
            d[col] = pd.to_numeric(d[col], errors='coerce')
    
    # Calculate actual profit using unit_cost
    unit_cost = d['unit_cost'].fillna(0)
    selling_price = d['selling_price'].fillna(0)
    units_sold = d['units_sold'].fillna(0)
    
    d['profit_per_unit'] = selling_price - unit_cost
    d['total_profit'] = d['profit_per_unit'] * units_sold
    d['profit_margin'] = np.where(selling_price > 0, 
                                  (d['profit_per_unit'] / selling_price) * 100, 0)
    
    # Additional useful metrics
    d['revenue'] = selling_price * units_sold
    d['total_cost'] = unit_cost * units_sold
    d['markup_percentage'] = np.where(unit_cost > 0,
                                     (d['profit_per_unit'] / unit_cost) * 100, 0)
    
    return d

def create_item_selector(df):
    """
    Create an interactive widget for selecting and visualizing items
    """
    # Get available items
    available_items = get_available_items(df)
    
    # Create dropdown options (item_id: name format)
    dropdown_options = [(f"{row['item_id']}: {row['name']}", row['item_id']) 
                       for _, row in available_items.iterrows()]
    
    # Create widgets
    item_dropdown = widgets.Dropdown(
        options=dropdown_options,
        description='Select Item:',
        style={'description_width': 'initial'},
        layout=widgets.Layout(width='600px')
    )
    
    # Buttons
    plot_prices_btn = widgets.Button(description="Plot Prices & Volume", button_style='primary')
    plot_profits_btn = widgets.Button(description="Plot Profit Analysis", button_style='success')
    show_stats_btn = widgets.Button(description="Show All Statistics", button_style='info')
    
    # Output area
    output = widgets.Output()
    
    def plot_prices(b):
        with output:
            clear_output(wait=True)
            if item_dropdown.value:
                plot_price_variance(df, item_dropdown.value)
    
    def plot_profit_analysis(b):
        with output:
            clear_output(wait=True)
            if item_dropdown.value:
                plot_profit_variance(df, item_dropdown.value)
    
    def show_item_statistics(b):
        with output:
            clear_output(wait=True)
            if item_dropdown.value:
                show_price_statistics(df, [item_dropdown.value])
    
    # Bind button clicks
    plot_prices_btn.on_click(plot_prices)
    plot_profits_btn.on_click(plot_profit_analysis)
    show_stats_btn.on_click(show_item_statistics)
    
    # Layout
    ui = widgets.VBox([
        widgets.HTML("<h3>Item Price & Profit Analysis Dashboard</h3>"),
        widgets.HTML(f"<p>Total items available: {len(available_items)}</p>"),
        item_dropdown,
        widgets.HBox([plot_prices_btn, plot_profits_btn, show_stats_btn]),
        output
    ])
    
    return ui

def plot_price_variance(df, item_id):
    """
    Enhanced single item plotting function for prices and volume
    """
    # Filter to that item and sort by date
    d = df[df['item_id'] == item_id].sort_values('day').copy()
    if d.empty:
        print(f"No data for item_id = {item_id}")
        return
    
    # Convert price columns to numeric
    price_cols = ['regular_price', 'sale_price', 'selling_price', 'unit_cost']
    for col in price_cols:
        if col in d.columns:
            d[col] = pd.to_numeric(d[col], errors='coerce')
    
    # Get all price values to determine optimal y-axis range
    all_prices = []
    for col in price_cols:
        if col in d.columns:
            prices = d[col].dropna()
            if not prices.empty:
                all_prices.extend(prices.tolist())
    
    if not all_prices:
        print(f"No price data available for item_id = {item_id}")
        return
    
    min_price = min(all_prices)
    max_price = max(all_prices)
    price_range = max_price - min_price
    
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(14, 10))
    
    # Top plot: Prices including cost
    if 'regular_price' in d.columns:
        regular_data = d[d['regular_price'].notna()]
        if not regular_data.empty:
            ax1.plot(regular_data['day'], regular_data['regular_price'], 
                    label='Regular Price', marker='o', linewidth=2, color='blue')
    
    if 'sale_price' in d.columns:
        sale_data = d[d['sale_price'].notna()]
        if not sale_data.empty:
            ax1.plot(sale_data['day'], sale_data['sale_price'], 
                    label='Sale Price', marker='s', linewidth=2, color='green')
    
    if 'selling_price' in d.columns:
        selling_data = d[d['selling_price'].notna()]
        if not selling_data.empty:
            ax1.plot(selling_data['day'], selling_data['selling_price'], 
                    label='Selling Price', marker='^', linewidth=2, color='red')
    
    # Add unit cost line
    if 'unit_cost' in d.columns:
        cost_data = d[d['unit_cost'].notna()]
        if not cost_data.empty:
            ax1.plot(cost_data['day'], cost_data['unit_cost'], 
                    label='Unit Cost', marker='x', linewidth=2, color='orange', linestyle='--')
    
    ax1.set_xlabel('Date')
    ax1.set_ylabel('Price ($)')
    ax1.set_title(f'Price Variance for Item {item_id}: {d["name"].iloc[0]}')
    ax1.legend()
    ax1.tick_params(axis='x', rotation=45)
    ax1.grid(True, alpha=0.3)
    ax1.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${x:.2f}'))
    
    # Add padding to y-axis
    padding = price_range * 0.05 if price_range > 0 else 0.1
    ax1.set_ylim(max(0, min_price - padding), max_price + padding)
    
    # Bottom plot: Units sold
    if 'units_sold' in d.columns:
        volume_data = d[d['units_sold'].notna()]
        if not volume_data.empty:
            ax2.bar(volume_data['day'], pd.to_numeric(volume_data['units_sold'], errors='coerce'), 
                   alpha=0.7, color='purple', label='Units Sold')
            ax2.set_xlabel('Date')
            ax2.set_ylabel('Units Sold')
            ax2.set_title('Sales Volume')
            ax2.tick_params(axis='x', rotation=45)
            ax2.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()

def plot_profit_variance(df, item_id):
    """
    Plot actual profit analysis using unit_cost data
    """
    # Calculate profits
    profit_data = calculate_profits(df, item_id)
    if profit_data.empty:
        print(f"No data for item_id = {item_id}")
        return
    
    # Filter out rows with no sales
    profit_data = profit_data[profit_data['units_sold'] > 0].sort_values('day')
    
    if profit_data.empty:
        print(f"No sales data for item_id = {item_id}")
        return
    
    fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(16, 12))
    
    # Plot 1: Profit per unit over time
    ax1.plot(profit_data['day'], profit_data['profit_per_unit'], 
             marker='o', linewidth=2, color='green', label='Profit per Unit')
    ax1.axhline(y=0, color='red', linestyle='--', alpha=0.7, label='Break-even')
    ax1.set_xlabel('Date')
    ax1.set_ylabel('Profit per Unit ($)')
    ax1.set_title('Actual Profit per Unit Over Time')
    ax1.tick_params(axis='x', rotation=45)
    ax1.grid(True, alpha=0.3)
    ax1.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${x:.2f}'))
    ax1.legend()
    
    # Plot 2: Total profit vs revenue vs cost
    width = 0.25
    days = profit_data['day']
    x = np.arange(len(days))
    
    ax2.bar(x - width, profit_data['revenue'], width, label='Revenue', alpha=0.8, color='blue')
    ax2.bar(x, profit_data['total_cost'], width, label='Total Cost', alpha=0.8, color='red')
    ax2.bar(x + width, profit_data['total_profit'], width, label='Total Profit', alpha=0.8, color='green')
    
    ax2.set_xlabel('Date')
    ax2.set_ylabel('Amount ($)')
    ax2.set_title('Revenue vs Cost vs Profit by Day')
    ax2.set_xticks(x)
    ax2.set_xticklabels([d.strftime('%m-%d') for d in days], rotation=45)
    ax2.grid(True, alpha=0.3)
    ax2.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${x:.2f}'))
    ax2.legend()
    
    # Plot 3: Profit margin over time
    ax3.plot(profit_data['day'], profit_data['profit_margin'], 
             marker='s', linewidth=2, color='purple', label='Profit Margin %')
    ax3.axhline(y=0, color='red', linestyle='--', alpha=0.7, label='Break-even')
    ax3.set_xlabel('Date')
    ax3.set_ylabel('Profit Margin (%)')
    ax3.set_title('Profit Margin Over Time')
    ax3.tick_params(axis='x', rotation=45)
    ax3.grid(True, alpha=0.3)
    ax3.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'{x:.1f}%'))
    ax3.legend()
    
    # Plot 4: Cumulative profit
    profit_data['cumulative_profit'] = profit_data['total_profit'].cumsum()
    ax4.plot(profit_data['day'], profit_data['cumulative_profit'], 
             marker='^', linewidth=3, color='navy', label='Cumulative Profit')
    ax4.axhline(y=0, color='red', linestyle='--', alpha=0.7)
    ax4.set_xlabel('Date')
    ax4.set_ylabel('Cumulative Profit ($)')
    ax4.set_title('Cumulative Profit Over Time')
    ax4.tick_params(axis='x', rotation=45)
    ax4.grid(True, alpha=0.3)
    ax4.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${x:.2f}'))
    ax4.fill_between(profit_data['day'], profit_data['cumulative_profit'], 
                     alpha=0.3, color='navy')
    
    plt.suptitle(f'Actual Profit Analysis for Item {item_id}: {profit_data["name"].iloc[0]}', 
                 fontsize=16, y=0.98)
    plt.tight_layout()
    plt.show()

def show_price_statistics(df, item_ids):
    """
    Show detailed statistics including actual profit analysis
    """
    print("="*80)
    print("COMPREHENSIVE PRICE & ACTUAL PROFIT STATISTICS")
    print("="*80)
    
    for item_id in item_ids:
        profit_data = calculate_profits(df, item_id)
        if profit_data.empty:
            continue
        
        # Filter to sales data only for profit calculations
        sales_data = profit_data[profit_data['units_sold'] > 0]
            
        print(f"\nItem {item_id}: {profit_data['name'].iloc[0]}")
        print("-" * 80)
        
        # Price statistics including cost
        price_cols = ['regular_price', 'sale_price', 'selling_price', 'unit_cost']
        for col in price_cols:
            if col in profit_data.columns and not profit_data[col].isna().all():
                prices = profit_data[col].dropna()
                if not prices.empty:
                    print(f"{col.replace('_', ' ').title():<20}: ${prices.min():.2f} - ${prices.max():.2f} (avg: ${prices.mean():.2f}, std: ${prices.std():.2f})")
        
        # Volume statistics
        if not profit_data['units_sold'].isna().all():
            units = profit_data['units_sold'].dropna()
            if not units.empty:
                print(f"{'Units Sold':<20}: {units.min():.0f} - {units.max():.0f} (avg: {units.mean():.1f}, total: {units.sum():.0f})")
        
        # Actual profit statistics (only for days with sales)
        if not sales_data.empty:
            print(f"\n{'ACTUAL PROFIT ANALYSIS':<20}:")
            print(f"{'Profit per Unit':<20}: ${sales_data['profit_per_unit'].min():.2f} - ${sales_data['profit_per_unit'].max():.2f} (avg: ${sales_data['profit_per_unit'].mean():.2f})")
            print(f"{'Total Revenue':<20}: ${sales_data['revenue'].sum():.2f}")
            print(f"{'Total Cost':<20}: ${sales_data['total_cost'].sum():.2f}")
            print(f"{'Total Profit':<20}: ${sales_data['total_profit'].sum():.2f}")
            print(f"{'Avg Daily Profit':<20}: ${sales_data['total_profit'].mean():.2f}")
            print(f"{'Profit Margin':<20}: {sales_data['profit_margin'].min():.1f}% - {sales_data['profit_margin'].max():.1f}% (avg: {sales_data['profit_margin'].mean():.1f}%)")
            print(f"{'Markup %':<20}: {sales_data['markup_percentage'].min():.1f}% - {sales_data['markup_percentage'].max():.1f}% (avg: {sales_data['markup_percentage'].mean():.1f}%)")
            
            # Profitability metrics
            profitable_days = len(sales_data[sales_data['total_profit'] > 0])
            total_sales_days = len(sales_data)
            profitability_rate = (profitable_days / total_sales_days * 100) if total_sales_days > 0 else 0
            print(f"{'Profitable Days':<20}: {profitable_days}/{total_sales_days} ({profitability_rate:.1f}%)")
            
            # ROI calculation
            if sales_data['total_cost'].sum() > 0:
                roi = (sales_data['total_profit'].sum() / sales_data['total_cost'].sum()) * 100
                print(f"{'Return on Investment':<20}: {roi:.1f}%")
        
        # Store information
        stores = profit_data['store_id'].unique()
        print(f"\n{'Store Coverage':<20}: {len(stores)} stores ({', '.join(map(str, stores))})")
        
        # Date range
        if not profit_data['day'].empty:
            print(f"{'Date Range':<20}: {profit_data['day'].min().strftime('%Y-%m-%d')} to {profit_data['day'].max().strftime('%Y-%m-%d')}")

# Quick function to show all available items
def show_available_items(df):
    """
    Display all available items in a nice format
    """
    items = get_available_items(df)
    print(f"Available Items ({len(items)} total):")
    print("="*80)
    for _, row in items.iterrows():
        print(f"ID: {row['item_id']:<10} Name: {row['name']}")

# Usage:
print("Setting up interactive dashboard...")
dashboard = create_item_selector(df)
display(dashboard)

# Alternative: Show available items first
print("\n" + "="*80)
show_available_items(df)
# Out:
# Setting up interactive dashboard...
# VBox(children=(HTML(value='<h3>Item Price & Profit Analysis Dashboard</h3>'), HTML(value='<p>Total items avail…
# ================================================================================
# Available Items (3837 total):
# ================================================================================
# ID: 8225800    Name: Frozen Udon 2.75lb(1.25kg)
# ID: 8225801    Name: Golden Curry Sauce Mix Mild 7.8oz(220g)
# ID: 8225802    Name: Duck Packaged Fz Smoked/Sliced Half Duck (1 Pack)
# ID: 8225803    Name: Glass Noodles 15.87oz(450g)
# ID: 8225804    Name: Paik Ramyun 4.1 oz(115g) x 4 Packs
# ID: 8225805    Name: Paik Jjajang Ramyun 4.94 oz(140g) x 4 Packs
# ID: 8225806    Name: Jeongseon Pancake 1.32lb(600g)
# ID: 8225807    Name: Marine Choco Boy 20PK 19.75oz(560g)
# ID: 8225808    Name: Cooked Black Rice Bowl 7.4oz(210g) 3 Packs
# ID: 8225809    Name: Stir-Fried Gan Jjajang Black Bean Sauce 7.48oz(212g)
# ID: 8225810    Name: Instant Miso Soup Spinach 5.76oz(172.8g)
# ID: 8225811    Name: Neoguri Spicy 4.2oz(120g) 4 Packs
# ID: 8225812    Name: Dukboki Sauce 1.76oz(50g)
# ID: 8225813    Name: Black Bean Paste with Smoky Flavor 10.58oz(300g)
# ID: 8225814    Name: Golden Curry Sauce Mix Medium Hot 7.8oz(220g)
# ID: 8225816    Name: Seasoned Green Laver(GIM) Box 10pk 7.1oz (201g)
# ID: 8225817    Name: Viet Huong Three Crabs Fish Sauce 24 fl.oz(682ml)
# ID: 8225818    Name: Dried Seaweed 7.05 Oz (200 G)
# ID: 8225819    Name: Korean Vermicelli 10.58oz(300g)
# ID: 8225820    Name: Mung Bean Vermicelli 17.6oz(500g)
# ID: 8225821    Name: Japanese Style Buckwheat Noodles 3lb(1.4kg)
# ID: 8225822    Name: Sticky Rice Cake 4ea 5.29oz(150g)
# ID: 8225823    Name: Curry Medium 17.63 OZ (500 G)
# ID: 8225824    Name: Beef Bone Soup 16.9 fl.oz(500ml) 6 Packs
# ID: 8225825    Name: Jajang Tteokbokki(Rice Cake With Black Bean Sauce) 4.52oz(128g)
# ID: 8225826    Name: Wide Vermicelli 14.1oz(400g)
# ID: 8225828    Name: Sweet Red Bean Ongsimi 1.54 Lb (700g)
# ID: 8225829    Name: Cold Noodle Arrowroot 2.2 LB (1 KG)
# ID: 8225830    Name: KOREAN SPICY COLD NOODLE 32OZ(910G)
# ID: 8225831    Name: (H-Mart Exclusive) Jjajang Ramen Bundle 20.6 OZ (4+1 PK)
# ID: 8225832    Name: Strawberry Flavored Milk Drink 6.8oz(200ml) 6 Packs
# ID: 8225833    Name: Ricecake Cup With Hot & Spicy Sauce 4.4oz(125g)
# ID: 8225834    Name: Cut Cabbage Kimchi (Mat Kimchi) 2.2lb(1kg)
# ID: 8225835    Name: Shin Ramen 16Pk Box 4.23OZ(120G)*16
# ID: 8225836    Name: Bibim Men Spicy Cold Noodles 4.58oz(130g) 5 Pack
# ID: 8225837    Name: Beef Vegetable Extra Large Dumpling 24oz(680g)
# ID: 8225838    Name: Pork & Glass Noodles Potstickers 21.2oz(600g)
# ID: 8225839    Name: 일본식 메밀 자루 소바 31.8oz(900g)
# ID: 8225840    Name: Tteokbokki Rice Cake 2lb(907g)
# ID: 8225841    Name: Moncher Cacao Cake 13.6oz(384g) 12 Pieces
# ID: 8225842    Name: Ansung Tang Myun 4.4oz(125g) 4 Packs
# ID: 8225843    Name: Tasty Hayashi Rice Gravy Mix 5.6 OZ (160 G)
# ID: 8225844    Name: Cooked Brown Rice 7.4oz(210g) 12 Packs
# ID: 8225845    Name: Turtle Chips Choco Churros Big Size 5.6oz(160g)
# ID: 8225846    Name: Cooked White Rice Box 7.4oz(210g) 12 Ea
# ID: 8225847    Name: Gomtang Ramen 3.59oz(102g) 5 Packs
# ID: 8225848    Name: Corn Cream Soup 2.82oz (80g)
# ID: 8225849    Name: Asain Style Starch Noodle 12oz(340g)
# ID: 8225850    Name: Taro Flavored Milk Drink 6.8FLOZ (200ml) 6 Pack
# ID: 8225851    Name: Tempura Udon Cup Noodle Cup 2.6oz(75g) 6 Cups
# ID: 8225852    Name: Corn Hot Chicken Flavor Ramen 4.59oz(130g) 5 Packs
# ID: 8225853    Name: Gonghwachun Jjangbbong Noodle 3.88oz
# ID: 8225854    Name: Japanese Style Noodle U-Dong 2.76lb(1.25kg)
# ID: 8225855    Name: Bibim Naengmyeon (Korean Spicy Cold Noodle) 25.40oz(720g)
# ID: 8225856    Name: Jin Ramen Box Spicy 76.14oz(2158.53g)
# ID: 8225857    Name: Beef Sliced Ribeye Bulgogi, Frozen 3lb(1.3Kg)
# ID: 8225858    Name: Carbo Hot Chicken Flavor Ramen 4.5oz(130g) 5 Packs
# ID: 8225859    Name: Jin Ramen Hot Flavor 4.23oz(120g) 4 Packs
# ID: 8225860    Name: Bul Jjamppong Noodle Soup 4.90oz(139g) 4 Packs
# ID: 8225861    Name: Plain Instant Noodle 3.88oz(110g)
# ID: 8225862    Name: Jumbo Bibimbap Flavor Big Triangle Kimbap 5.64 Oz (160g) X 2 Ea
# ID: 8225863    Name: Golden Curry Sauce Mix Hot 7.8oz(220g)
# ID: 8225864    Name: Golden Curry Sauce Mix Extra Hot Flavor 7.8oz(220g)
# ID: 8225865    Name: Rice Paper (22cm) 12 OZ (340 G)
# ID: 8225866    Name: Sanukiya Yude Udon 21.75 OZ (616 G)
# ID: 8225867    Name: Shindangdong Rice Cake Snack 230g
# ID: 8225868    Name: Chapagetti Ramen 4.5OZ(127G) 10 Packs
# ID: 8225869    Name: Fresh Flat Wheat Noodle Kalguksu 3lb(1.36kg)
# ID: 8225870    Name: Thick Wheat Noodle Jajang Guk Su 3lb(1.36kg)
# ID: 8225871    Name: 3 Minutes Curry Medium Hot Flavor 6.7oz(190g)
# ID: 8225872    Name: Green Grape Iced Tea Pouches 8.11 fl.oz(230ml) 10 Pouches
# ID: 8225873    Name: Carbo Hot Chicken Topokki Big Bowl 6.17oz(175g)
# ID: 8225874    Name: Cook-tok Rice Cup Carbonara 5.11oz(145g)
# ID: 8225875    Name: Jumbo Kimchi Tuna Mayo Flavor Big Triangle Kimbap 5.64 Oz (160g) X 2 Ea
# ID: 8225876    Name: Kimchi Vegetable Extra Large Dumpling 27oz(1.6lb)
# ID: 8225877    Name: Dry Miso Soup 0.28oz(8g) 5 Packs
# ID: 8225878    Name: Spicy Tteokbokki(Rice Cake) 4.5oz(128g)
# ID: 8225879    Name: Plant-Based Bulgogi Rice Balls 17.6oz(500g)
# ID: 8225881    Name: Sweet Cinnamon Hotteok 12.7oz(360g)
# ID: 8225882    Name: Ddukbokki Kit (Cup) 10.90 OZ (309 G)
# ID: 8225883    Name: Raddish Kimchi Fried Rice 14.1oz(400g)
# ID: 8225884    Name: Rice Tteok-bokki 15.02oz(426g)
# ID: 8225885    Name: Traditional Vermicelli 1.1lb(500g)
# ID: 8225886    Name: Shrimp Cracker Spicy Flavor 2.6oz(75g)
# ID: 8225887    Name: Dasida Beef Flavored Soup Stock 2.2lb(1kg)
# ID: 8225888    Name: Jin Ramen Mild Flavor 4.23oz(120g) 4 Packs
# ID: 8225889    Name: Spicy Shrimp Flavor Cup Noodle Soup 2.36oz(67g) 6 Cups
# ID: 8225890    Name: Jjajangmen 28.2oz(200g) 4 Packs
# ID: 8225891    Name: Air Dried Crab Ramen 3.43oz(97g) 4 Packs
# ID: 8225892    Name: Sesame Flavor Noodle Bowl 3.88oz(110g)
# ID: 8225893    Name: Dumpling Wrapper 14oz(398g)
# ID: 8225894    Name: Korean Cut Vermicelli 17.63oz(500g)
# ID: 8225895    Name: Mochi (Pink)3.53oz
# ID: 8225896    Name: Mochi (White)3.53oz
# ID: 8225897    Name: Mochi (Green)3.53oz
# ID: 8225898    Name: Spicy Dried Squid Kimbap 8.46oz(240g)
# ID: 8225899    Name: Rice Porridge 15.87 OZ (420 G)
# ID: 8225900    Name: Cream Carbonara Hot Chicken Flavor Ramen 4.936oz(140g) 5 Packs
# ID: 8225901    Name: Shin Ramyun Toomba 4.83 Oz (137g) 4 Pack
# ID: 8225902    Name: Cream Soup 2.82oz (80g)
# ID: 8225903    Name: Pork Vegetable Extra Large Dumpling 32oz(907g)
# ID: 8225904    Name: Crispy Potstickers Meat & Vegetable 32oz(907g)
# ID: 8225905    Name: Wheat Flour Cake 35.27oz(1kg)
# ID: 8225906    Name: Shrimp Ramen Big Cup 4.05oz(115g)
# ID: 8225907    Name: Ace Cracker Big Size 12.84oz(364g)
# ID: 8225908    Name: Choco Mont 12 PK 432G(36G*12)
# ID: 8225909    Name: Rice Cake with Honey 10.22oz(290g)
# ID: 8225910    Name: Garaetteok Korean Traditional Rice Cake 14.81 Oz (420g)
# ID: 8225911    Name: BCD Soon Tofu - Hot 13oz(368g)
# ID: 8225912    Name: Rice Wrapper Potstickers 1.75lb(794g)
# ID: 8225913    Name: Premium Pork Loin Fritter 12oz(340g)
# ID: 8225914    Name: Soup For Cold Noodles Dongchimi 59.15 FL OZ (1750 ML)
# ID: 8225915    Name: Cheese Pork cutlet 14oz(396g)
# ID: 8225916    Name: Premium Grade Rice 15lb(6.8kg)
# ID: 8225917    Name: Spring Rolls Skin 12oz(345g)
# ID: 8225918    Name: Shrimp Cracker 2.6oz(75g)
# ID: 8225919    Name: Instant Miso Soup Fried Bean Curd 6.21oz(176g)
# ID: 8225920    Name: Noodle-Style Tofu Fettuccine 3.5oz(100g)
# ID: 8225921    Name: Noodle-Style Tofu Spaghetti 3.5oz(100g)
# ID: 8225922    Name: Jumbo Kimchi & Pork Dumplings 22.2oz(630g)
# ID: 8225923    Name: Sliced Rice Cakes 4.4lb(2kg)
# ID: 8225924    Name: Air Dried Shin Ramen Light 3.4oz(97g) 4 Packs
# ID: 8225925    Name: Jjamppong Ramen 14.2 Oz/4 Pack
# ID: 8225926    Name: Air Dried Mild Ramen 3.38oz(96g) 4 Packs
# ID: 8225927    Name: KATSUO UDON 16.4oz
# ID: 8225928    Name: Vietnamese Style Pho 11.2oz(317g)
# ID: 8225929    Name: Jjamppong Noodle Soup Kit 12.8oz(362g)
# ID: 8225930    Name: Jjajang Powder 3.52oz (100g)
# ID: 8225931    Name: Jin Ramen Box Mild 76.14oz(2158.53g)
# ID: 8225932    Name: (H-Mart Exclusive) Air Dried Mild Ramen 17 OZ (4+1 PK)
# ID: 8225933    Name: Jumbo Tuna Mayo Flavor Big Triangle Kimbap 5.64 Oz (160g) X 2 Ea
# ID: 8225934    Name: Chapagetti Chajang Noodle 4.5oz(127g) 4 Packs
# ID: 8225935    Name: Vermont Curry Sauce Mix  Mild 8.8oz(250g)
# ID: 8225936    Name: Honey Flavored Twist Snack 2.64oz(75g)
# ID: 8225937    Name: Korean Style Fresh Arrowroot Cold Noodle 2.21lb(1.01kg)
# ID: 8225938    Name: Beef Sliced Short Plate, Frozen 2lb(907g)
# ID: 8225939    Name: Curry Powder Mild 3.52oz (100g)
# ID: 8225940    Name: Shin Ramyun 4.23oz(120g)
# ID: 8225941    Name: Yeul Ramen Hot Taste 4.23oz(120g) 5 Packs
# ID: 8225942    Name: Teum Sae Ramen 4.23oz(120g) 5 Packs
# ID: 8225943    Name: Hot Chicken Flavor Ramen 4.94oz(140g) 5 Packs
# ID: 8225944    Name: Dadam Beef Bone Stock Soup 3.52oz(100g) (20g x 5ea)
# ID: 8225945    Name: Korean Style Noodles Somen 3lb(1.4kg)
# ID: 8225946    Name: Fresh Jjolmyeon 2.2lb(1kg)
# ID: 8225947    Name: Korean Galbi Flavored Cake 14oz(396g)
# ID: 8225948    Name: Vermicelli & Vegetable Dumpling 14.81oz(420g)
# ID: 8225950    Name: Shin Ramyun Black Multi 4.58oz(130g)
# ID: 8225951    Name: Scorched Rice 1.1lb(500g)
# ID: 8225952    Name: Vegetable Porridge 10.6oz(300g)
# ID: 8225953    Name: Soybean Paste Soup with Zucchini 1.27oz(36g)
# ID: 8225955    Name: Beef Bone Soup 500g
# ID: 8225956    Name: Odongtong Myon (Seafood) Spicy Flavor 4.23oz(120g) 4 Packs
# ID: 8225957    Name: Kimchi Ramen 4.3oz(122g) 4 Packs
# ID: 8225958    Name: Sesame Oil 16.9oz(500ml)
# ID: 8225959    Name: Dongchimi Cold Soup Stock 6pk
# ID: 8225960    Name: Cheese Topokki (Rice Cake) 8.46oz(240g)
# ID: 8225961    Name: Sliced Pork CT Butt (Bulgogi), Frozen 1lb(454g)
# ID: 8225962    Name: Spicy Rose Sauce Topokki 12.69oz(360g)
# ID: 8225964    Name: Roasted Black Bean Paste 2.2lb(1kg)
# ID: 8225965    Name: Cooked Rice Bibimbap 9.48oz(269g)
# ID: 8225966    Name: Cooked Rice Spicy Sauce with Octopus 9.87oz(280g)
# ID: 8225967    Name: Cooked White Rice with SoyBean Paste Bibimbap 9.8oz (280g)
# ID: 8225968    Name: Cooked White Rice with Seaweed Soup 5.9oz (167g)
# ID: 8225969    Name: Cooked White Rice with Yellow Cream Curry 9.8oz (280g)
# ID: 8225970    Name: Cooked White Rice with Stir-Fried Kimchi 8.65oz (247g)
# ID: 8225972    Name: BOILED OYSTER SOUP 1.16LB(530G)/30
# ID: 8225973    Name: Rice Paper Square 7.05 OZ (200 G)
# ID: 8225974    Name: Sliced Rice Cake 2.2 LB (1 KG)
# ID: 8225975    Name: Potato Noodles 8.82OZ
# ID: 8225976    Name: Vermicelli 1.1lb(500g)
# ID: 8225977    Name: Kimchi Ramen 4.23oz(120g) 4 Packs
# ID: 8225978    Name: Ichiban Original Noodle
# ID: 8225979    Name: Soup Tteok-bokki 15.02oz(426g)
# ID: 8225980    Name: Cream Soup 10.58OZ (300G)
# ID: 8225981    Name: Easy Tteokbokki Rice Cakes 2.2lb(1kg)
# ID: 8225982    Name: Kimchi and Pork Dumplings 1.5lb(680g)
# ID: 8225984    Name: Ramen Cup 2.3oz(65g) 6 Cups
# ID: 8225985    Name: Mul Naengmyeon (Korean Cold Noodle) 25.40oz(720g)
# ID: 8225986    Name: Cooked White Rice With Soft Tofu Stew 6.1oz(174g)
# ID: 8225997    Name: Beef and Vegetable Soup 1.21lb(549g)
# ID: 8225998    Name: Braised Chicken and Vegetable in Soy Sauce 17.6oz (500G)
# ID: 8225999    Name: Spicy Sausage And Vegetable Soup 1.21 LB (548 G)
# ID: 8226001    Name: Beef Bulgogi Stew With Mushrooms 1.32 LB (598 G)
# ID: 8226003    Name: Stir-fried Chicken Noodle with Spicy Soy Sauce 4.58oz(130g) 4 Packs
# ID: 8226004    Name: Kal Guk Soo Korean Style Noodle Soup 3.45oz(98g) 5 Packs
# ID: 8226005    Name: Hot Chicken Flavor Ramen Big Bowl 3.7oz(105g)
# ID: 8226011    Name: Chew Noodle With Spicy Sauce 1.14 LB (520 G)
# ID: 8226012    Name: Pyongyang Style Cold Noodle 3.32lb(1.51kg)
# ID: 8226014    Name: Knife Cut Noodles 35.2 OZ (1000 G)
# ID: 8226015    Name: Plant Based Flat Dumplings 24.7oz(700g)
# ID: 8226016    Name: Sliced Pork Belly, Frozen 5lb(2.26kg)
# ID: 8226018    Name: Rice Cakes 22.9oz(650g)
# ID: 8226019    Name: BCD Soon Tofu - Med 13oz(368g)
# ID: 8226020    Name: Fermented Bean Paste Stew 14.11oz(400g)
# ID: 8226021    Name: SEOMJINGANG DASEILGI SOUP 1.1 LB (500G)
# ID: 8226022    Name: Cooked Loach Soup 17.64oz(500g)
# ID: 8226023    Name: Spicy Seafood & Fish Roe Soup 19.40oz(550g)
# ID: 8226024    Name: Curled Mallow Soup With Baby Clam 17.64oz(500g)
# ID: 8226025    Name: Abalone Mushroom Porridge 10.6oz(300g)
# ID: 8226026    Name: Spicy Pollack Soup 21.16oz(600g)
# ID: 8226027    Name: ë¶ì°½ë ìëë¶ - ìì£¼ ë§¤ì´ë§ 13oz(368g)
# ID: 8226031    Name: Quattro Cheese Hot Chicken Flavor Ramen 5.11oz(145g) 5 Packs
# ID: 8226034    Name: Red Bibimbap Vegan Kimbap 7.76oz(220g)
# ID: 8226035    Name: Sweet Pumpkin Porridge 10.6oz(300g)
# ID: 8226038    Name: Mushroom Cream Soup 2.82oz (80g)
# ID: 8226040    Name: Tuna-mayo Kimbap 8.46oz(240g)
# ID: 8226043    Name: UNCLE GURYE KOREAN VEGETABLE PANCAKE KIT 5.39 OZ (153G)
# ID: 8226045    Name: Ramie Rice Cake Sesame 14.1oz(400g)
# ID: 8226046    Name: Ramie Rice Cake Cowpea 14.1oz(400g)
# ID: 8226047    Name: Leek Pancake 15.87oz(450g)
# ID: 8226049    Name: Assorted Deep Fried 1.1lbs(500g)
# ID: 8226050    Name: Ricecake with Hot & spicy Sauce 12.7oz(360g)
# ID: 8226052    Name: Hetbahn Cooked White Rice 7.4oz(210g) 6 Ea
# ID: 8226053    Name: Yakisoba Original 3PC 17.46 OZ (495 G)
# ID: 8226056    Name: Korean Fusion Wheat Flour Cake with Cheese 21.16oz(600g)
# ID: 8226060    Name: Korean Style Vermicelli 35.27oz(1kg)
# ID: 8226065    Name: Chicken Karaage Fully Cooked 16 OZ (453 G)
# ID: 8226067    Name: Dosirac Beef 3.17oz(90g)
# ID: 8226068    Name: Longkou Vermicelli 11.3 OZ (320 G)
# ID: 8226069    Name: COOKED SEASONED LOACH SOUP 17.64OZ(500G)
# ID: 8226070    Name: Tumeric Powder 1.69oz(48g)
# ID: 8226072    Name: Jjajangmen 7.16oz(203g) 4 Packs
# ID: 8226073    Name: Toppoki Spicy Black Bean Flavored 1.09lb(495g)
# ID: 8226075    Name: Brown & Brown Sweet Rice 15lb (6800g)
# ID: 8226076    Name: Kimchi & Pureed Soybean Stew 17.64oz(500g)
# ID: 8226077    Name: Pepper Gr Potato Pancake 2 PK 17.64 OZ 500 G(250G X 2)
# ID: 8226078    Name: Chives Pancake 2pk 17.64oz 500g(250g X 2)
# ID: 8226079    Name: Rice Noodle Tomato Flavor 10.8oz(306g)
# ID: 8226080    Name: Abalone Mushroom Bowl 9.52oz(270g)
# ID: 8226082    Name: Singapore Curry La Mian Noodle 6.2oz(178g) 4 Packs
# ID: 8226084    Name: Rice Yellow 15lb(6.8kg)
# ID: 8226085    Name: Korean Style Noodles Somen 5lb(2.26kg)
# ID: 8226087    Name: Pork & Shrimp Dumpling 20oz(566g)
# ID: 8226088    Name: Beef & Vegetable Dumpling 24oz(680g)
# ID: 8226090    Name: Vegetarian Spicy Vermicelli Rice Noodle (Cup) 5.2oz
# ID: 8226091    Name: Vegetarian Beef Vermicelli Rice Noodle (Cup) 3.52oz
# ID: 8226092    Name: Sliced Rice Cake Soup Bowl 5.39 OZ (153 G)
# ID: 8226093    Name: Japchae Bowl Cup 2.91oz(82g)
# ID: 8226095    Name: Artificial Spicy Chicken Flavor Ramen Quattro Cheese 3.88oz(110g)
# ID: 8226096    Name: Jjajangmen Big Bowl 6.7oz(190g)
# ID: 8226097    Name: Saigon Pho Bowl Chicken Flavor 2.5oz(70g)
# ID: 8226099    Name: Shin Ramen Black with Premium Beef Broth 4.85oz(130g) 4 Packs
# ID: 8226100    Name: SHIN RAMYUN RED 4.4 OZ(125G)/4
# ID: 8226101    Name: Shin Ramen Stir Fry 4.62oz(131g) 4 Packs
# ID: 8226102    Name: Rose Buldak Glass Noodle 5.98oz(169.4g)
# ID: 8226105    Name: ì¤ëª¨ë¦¬ ê¹ì¹ì°ê° ë¼ë©´ 5.64oz(160g) 4í©
# ID: 8226106    Name: Jin Ramen Cup Hot Flavor 2.3oz(65g) 6 cups
# ID: 8226107    Name: Somen 48oz(1360g)
# ID: 8226108    Name: Neoguri Ramen Seafood & Mild 4.23oz(120g) X 4 Packs
# ID: 8226109    Name: Kimchi Ramen 4.23oz(140g) 6 Cups
# ID: 8226115    Name: Kimchi Dumpling 2.65lb(1.2kg)
# ID: 8226116    Name: Sunchang 100% Brown Rice Red Pepper Paste 2.2lb(1kg)
# ID: 8226117    Name: 3 Minutes Curry Mild Flavor 6.7oz(190g)
# ID: 8226118    Name: 3 Minutes Jjajang 5.64oz(160g)
# ID: 8226119    Name: Yukgaejang Cup 2.18oz(62g) 6 Packs
# ID: 8226120    Name: Spicy Seafood Soup With Pork and Vegetables 17.60 OZ (500 G)
# ID: 8226121    Name: Korean BBQ Flavored Beef Patty Mild Spicy 16oz(453g)
# ID: 8226122    Name: Dotom Pork & Vegetable Mini Patty 16oz(453g)
# ID: 8226123    Name: Pork & Vegetable Dumpling 24oz(680g)
# ID: 8226124    Name: Sweet&spicy Rice Cake Skewer 11.64oz(330g)
# ID: 8226125    Name: Korean Pancake Brown Sugar 1.1lb(480g)
# ID: 8226126    Name: Bung-eo-ppang Custard Cream 2.31lb
# ID: 8226127    Name: Shin Cup Noodle Soup 2.64oz(75g) 6 Cups
# ID: 8226128    Name: Neoguri Spicy Cup 3.56oz(75g) 6 Cups
# ID: 8226129    Name: Rapokki 11.57oz(328g)
# ID: 8226130    Name: Breaded Mozzarella & Fish Cake on a Stick 2.8oz(80g) 5 Packs
# ID: 8226131    Name: Kimchi Pancake 15.87oz(450g)
# ID: 8226132    Name: ê¹¡íµìì¥ íì í´ë¬¼íì  15.87oz(450g)
# ID: 8226133    Name: Tteokbokki (Big Size Rice Cake With Spicy Sauce) 14.57 Oz (413g)
# ID: 8226134    Name: Cook Tok Rice Cake Newtro Cream Pepper 21.2oz(600g)
# ID: 8226136    Name: Cook Tok Rice Cake Newtro Noodle 19.4oz(550g)
# ID: 8226137    Name: Shrimp Fried Rice 21.2oz(601g)
# ID: 8226139    Name: Mozzarella & Cream Cheese Hotteok 12.7oz(360g)
# ID: 8226142    Name: Burdock Fried Tofu Vegan Kimbap 7.76oz
# ID: 8226144    Name: Jabchae Potstickers 1.8lb(810g)
# ID: 8226145    Name: ëë ìë¶ê³ ê¸° 1lb(454g)
# ID: 8226147    Name: Korean Rice Suhyang Rice 22lb(10kg)
# ID: 8226149    Name: Curry Hot 3.52 OZ (100g)
# ID: 8226151    Name: Yeul(Hot,Spicy) Ramen Bowl 105g
# ID: 8226155    Name: Cooked White Rice with Black Bean Sauce 9.7oz(275g)
# ID: 8226156    Name: Cooked Rice and Teriyaki Tuna with Mayonnaise 8.71oz(247g)
# ID: 8226157    Name: Cooked Rice Kimchi And Tuna Flavor 10.93oz(310g)
# ID: 8226158    Name: Cooked Rice and Fish Roe Sauce with Kimchi 7.83oz(222g)
# ID: 8226159    Name: 3 Minutes Curry Hot Flavor 6.7oz(190g)
# ID: 8226160    Name: Kimchi Hotpot Udon 20oz(566g)
# ID: 8226161    Name: Spicy-rice Cake (Cup) 151g
# ID: 8226162    Name: Spicy Seafood Noodle Soup 4.2oz(120g) 5 Packs
# ID: 8226163    Name: Lobster Ramen 4 Packs 4.23oz(120g)
# ID: 8226164    Name: Jang Ramen (Soy Flavor Noodle) 4.23oz(120g) 5 Packs
# ID: 8226165    Name: Black Bean Paste 10.58oz(300g)
# ID: 8226167    Name: Konac Rice with Brown & Oat Rice 5.29OZ(150G) X 12 EA
# ID: 8226168    Name: Instant Miso Soup Tofu 5.33oz(151g)
# ID: 8226171    Name: Chinese Black Bean Paste 8.82oz(250g)
# ID: 8226176    Name: Singapore Laksa La Mian Noodle 6.5oz(185g) 4 Packs
# ID: 8226178    Name: Mi Goreng Fried Noodles 3oz(85g) 5 Packs
# ID: 8226180    Name: White Jjamppong Seafood Flavor 3.31OZ (94G) X 4 Pack
# ID: 8226182    Name: Japanese Style Buckwheat Noodles (Soba) 3lb(1.4kg)
# ID: 8226183    Name: Tomosiraga Somen 3lb(1.36kg)
# ID: 8226184    Name: Beef Thin&Roll Boneless Short Plate 1lb(454g)
# ID: 8226186    Name: Curry Sauce Mild 7oz(200g)
# ID: 8226187    Name: Curry Sauce Med Hot 7oz(200g)
# ID: 8226189    Name: Mi Goreng Fried Noodles Hot and Spicy 2.8oz(80g) 5 Packs
# ID: 8226190    Name: Sliced Rice Cakes 2.2lb(1kg)
# ID: 8226191    Name: Laver(GIM) Roll Fritter Spicy 1.1lb(500g)
# ID: 8226192    Name: Crispy Seaweed Vegetable Rolls 1.1lb(400g)
# ID: 8226195    Name: Fried Tofu & Burdock Kimbap 8.11oz(230g)
# ID: 8226196    Name: Ichiban Tonkotsu Ramen Bundle 18.5oz(524.46g)
# ID: 8226197    Name: Hot and Spicy Bowl Noodle Soup (Yukejang) 3.03oz(86g)
# ID: 8226198    Name: Udon Noodle 3lb(1.36kg)
# ID: 8226199    Name: Cold Noodles Fresh Green Tea 2.2 LB (1 KG)
# ID: 8226203    Name: Plantspired Crispy Tofu Nuggets 16oz(454g)
# ID: 8226205    Name: Spicy & Sweet Cup Topokki 4.23oz(120g)
# ID: 8226207    Name: Jjamppong Bowl 4.09oz(115g)
# ID: 8226208    Name: Ramie Rice Cake Peeled Cowpea 14.1oz(400g)
# ID: 8226209    Name: Rice Paper 7.05oz(200g)
# ID: 8226212    Name: Ricecake Cup with Cheese Flavored Sauce 4.4oz(125g)
# ID: 8226213    Name: Ricecake Cup with Sweet & Spicy Sauce 4.4oz(125g)
# ID: 8226214    Name: Instant Ginseng Chicken Stew 1.76lb(798g)
# ID: 8226215    Name: Frozen Mussel In Creamy White Wine Sauce
# ID: 8226216    Name: Pork Loin Fritter With Mozzarella Cheese 12oz(340g)
# ID: 8226217    Name: Omori Kimchi Stew Cup Ramen 5.29oz (150g)
# ID: 8226218    Name: Spicy Mushroom Beef Soup with Vegetables 17.6oz (500g)
# ID: 8226219    Name: Wheat Flour Cakes 22.9oz(650g)
# ID: 8226220    Name: Kimchi & Pork & Vegetable Dumpling 24oz(680g)
# ID: 8226221    Name: Spicy Chicken and Vegetable Stew 17.6oz(500G)
# ID: 8226223    Name: Golden Curry Ready-Made Sauce with Vegetables Extra Hot 8.1oz(230g)
# ID: 8226224    Name: Golden Curry Ready-Made Sauce with Vegetables Medium Hot 8.1oz(230g)
# ID: 8226225    Name: Golden Curry Sauce with Vegetables Hot 8.1oz(230g)
# ID: 8226226    Name: Golden Curry Ready-Made Sauce with Vegetables Mild 8.1oz(230g)
# ID: 8226227    Name: Grilled Sea Eel(Teriyaki), Frozen  14.1oz (400g)
# ID: 8226228    Name: Pork & Leek Wontons 21.1oz(600g)
# ID: 8226229    Name: Dukboki Original Spicy 1.32lb(600g)
# ID: 8226230    Name: Spicy Pepper Vegan Kimbap 7.76oz
# ID: 8226231    Name: Cut Cabbage Kimchi (Mat Kimchi) 17.6oz(500g)
# ID: 8226232    Name: MAJJOEUM VEGAN TTEOKBOKKI (ORIGINAL) 4.23 OZ (120G)
# ID: 8226233    Name: Hot Spicy Topokki 8.46oz(240g)
# ID: 8226235    Name: Beef Thin&Roll Ribeye Roll 1lb(454g)
# ID: 8226238    Name: Cooked White Rice 7.4oz(210g) 12 Packs
# ID: 8226239    Name: Jin Jjambbong Spicy Seafood Noodle 4.58oz(130g) 4 Packs
# ID: 8226240    Name: Curry Hot Chicken Flavor Ramen 4.94oz(140g) 5 Packs
# ID: 8226241    Name: Jjajang Hot Chicken Flavor Ramen 4.94oz(140g) 5 Packs
# ID: 8226242    Name: ìì° í«ì¤ì¬ì ì¸ì¤í´í¸ ëë¤ 2.7 oz 5í©
# ID: 8226243    Name: Cheese Hot Chicken Flavor Ramen 4.94oz(140g) 5 Packs
# ID: 8226245    Name: Premium Roasted Sesame Oil 10.82fl oz(320ml)
# ID: 8226246    Name: Spicy Stir-Fry Beef Intestine 7oz(198g)
# ID: 8226248    Name: Pecking Fried Dumpling 2.65lb(1.2kg)
# ID: 8226250    Name: Hot Chicken Topopkki Big Bowl 6.52oz(185g)
# ID: 8226252    Name: Korean Fusion Roast Rice Cake with Cheese 21.16oz(600g)
# ID: 8226253    Name: Bbq Marinated Beef Ribeye Roll Bulgogi 2lb(907g)
# ID: 8226254    Name: Makguksoo Noodle 5LB (2268G)
# ID: 8226256    Name: Kung Pao Vegan Self-heating Pot 10.76oz(305g)
# ID: 8226257    Name: Kimchi Style Bibimbap 14.22oz(403g)
# ID: 8226258    Name: Soon Cup Veggie Ramen 2.64oz(75g) 6 Cups
# ID: 8226260    Name: Green Tea Noodle 4.23 Oz (120g) 4 Pack
# ID: 8226261    Name: Fresh Potato Noodle2.2lb(1kg)
# ID: 8226262    Name: XL Ramen Spicy Kimchi 16.37 Oz (464g)
# ID: 8226264    Name: Flat Sweet Potato Vermicelli 2.2lb(1kg)
# ID: 8226265    Name: Hong Ramen Spicy Flavor 4.2oz(120g) 5 Packs
# ID: 8226266    Name: Spring Roll Skin 22cm 12 OZ (340 G)
# ID: 8226267    Name: Sweet Potato Glass Noodle 1.98lb(900g)
# ID: 8226268    Name: Cream Soup 35.27 OZ (1000 G)
# ID: 8226269    Name: Curry Powder Mild 2.2 LB (1000 G)
# ID: 8226270    Name: Corn Cream Soup 35.27OZ (1000G)
# ID: 8226272    Name: Kimchi & Cheese Rice Balls 17.6oz(500g)
# ID: 8226273    Name: Habanero Tteokbokki(Rice Cake) 4.6oz(132g)
# ID: 8226275    Name: Hot Chicken Flavor Ramen Stew Type 5.11oz(145g) 5 Packs
# ID: 8226276    Name: Extra Hot Chicken Flavor Ramen Cup 2.29oz(65g) 6 Cups
# ID: 8226277    Name: Sweet Red Bean Porridge 10.6oz(300g)
# ID: 8226278    Name: Red Bean Porridge 14.82oz(420g)
# ID: 8226283    Name: Vermont Curry Sauce Mix Hot 8.8oz(250g)
# ID: 8226285    Name: Mushroom Japchae Vegan Kimbap 7.76oz(220g)
# ID: 8226286    Name: Shumai Shrimp 33pc 17.46oz
# ID: 8226287    Name: Kimchi Cheese Rice Balls 17.63oz(500g)
# ID: 8226290    Name: Soybean Soup Noodle 4 PK 16.37 OZ (464 G)
# ID: 8226291    Name: Somen Japanese Style Noodle 3lb(1.36kg)
# ID: 8226292    Name: Original Coffee Mix 0.42oz(12g) 100 Sticks
# ID: 8226298    Name: Vegetable Dumpling 2.65lb(1.2kg)
# ID: 8226299    Name: Yangban Bibimedbap Jjajangbap 8.82 Oz(250g)
# ID: 8226300    Name: Habanero Lime Hot Chicken Flavor Ramen 4.76oz(135g) 5 Packs
# ID: 8226301    Name: Hwa Ramen Hot & Spicy with Soy Peptide 4.23oz(120g) 5 Packs
# ID: 8226302    Name: Cooked Bap White Rice Box 5.55 LB (2500 G)
# ID: 8226304    Name: Kimchi Stew Ramen 4 Pack 13.9 Oz
# ID: 8226305    Name: Seaweed Soup 0.63oz(18g)
# ID: 8226307    Name: Korean BBQ Flavored Beef Patty 16oz(453g)
# ID: 8226309    Name: Radish Kimchi Fried Rice 18oz(510g)
# ID: 8226310    Name: Rice Noodles 14 OZ (400 G)
# ID: 8226311    Name: Jeolpyeon Korean Traditional Rice Cake With Red Bean Paste 12.7 Oz (360g)
# ID: 8226312    Name: Songpyeon 1.32lb(600g)
# ID: 8226315    Name: Shin Ramen 4.23oz(120g) 10 Packs
# ID: 8226318    Name: Oyster Jjamppong Ramen 3.49oz(99g) 4 Packs
# ID: 8226319    Name: ë°ì§ë½ ì¹¼êµ­ì 14.6oz(414g)
# ID: 8226320    Name: Ramen 4.23oz(120g) 4 Packs
# ID: 8226323    Name: Potato Noodle Soup 3.52oz(100g) 4 Packs
# ID: 8226324    Name: Tonkotsu Kuromayu Ramen Big Bowl 3.56oz(101g)
# ID: 8226325    Name: Soon Veggie Ramen 4pk 18.5oz(524.46g)
# ID: 8226327    Name: Vegetable Kimbap 8.11oz(230g)
# ID: 8226328    Name: Hong Sam Won Korean Red Ginseng Drink 1.69oz(50ml) 20 Pouches
# ID: 8226329    Name: Udon 2.2 LB (1 KG)
# ID: 8226331    Name: KOREA MEAL KIT JAPCHAE MARA FLAVOR 3.77 OZ (107G)
# ID: 8226332    Name: íê¹ì¹ 10.6oz(300g)
# ID: 8226333    Name: Sliced Kimchi 1.1lb(500g)
# ID: 8226335    Name: Ricecake with Sweet & Spicy Sauce 12.7oz(360g)
# ID: 8226336    Name: Fermented Konjac Kamut Rice Bowl 5.29oz(150g) X 30 Ea
# ID: 8226337    Name: Brown Rice Rice Paper 7.05oz(200g)
# ID: 8226339    Name: Hetbahn Cooked Sprouted Brown Rice 7.4oz(210g) 3 Ea
# ID: 8226340    Name: Bacchus D Drink 3.53oz(100ml) 10 Ea
# ID: 8226341    Name: Seaweed Soup 17.6oz(500g)
# ID: 8226342    Name: Black Bean Sauce Mix 35.27OZ (1000G)
# ID: 8226343    Name: Premium Gomtang Noodles 4.41oz(125g) 4 Packs
# ID: 8226345    Name: Malaking Bibim Ramen Multi 4.76oz(135g)
# ID: 8226347    Name: Mr.Kimchi Stir-fried Ramen Bundle 4.72oz(134g) 4 Packs
# ID: 8226348    Name: ì ë¼ë©´ ë¸ë ì»µ ë°ì¤ 21.38oz(606.11g)
# ID: 8226349    Name: Rice Porridge with Tuna 10.05oz(285g)
# ID: 8226350    Name: Cheese Cup Topokki (Rice Cake) 4.23oz(120g)
# ID: 8226352    Name: Fresh Udon & Jja Jang 2.2 LB (1 KG)
# ID: 8226355    Name: Zucchuni Potato Pancake 2p 17.64oz 500g(250g X 2)
# ID: 8226359    Name: Noodle Tteok-bokki 15.37oz(436g)
# ID: 8226360    Name: Jjajang Rapokki 11.57oz(328g)
# ID: 8226362    Name: Mozzarella Cheese & Potato Hotdog 11.2oz(320g)
# ID: 8226364    Name: Yaki Soba Shio 3 PC 16.82 OZ (480 G)
# ID: 8226365    Name: Tomyum Buldak Artificial Spicy Chicken Flavor Ramen Multi 4.76oz(135g)x5pack
# ID: 8226366    Name: Big Bowl Shrimp Tempura Udon 4.02oz(114g)
# ID: 8226367    Name: Roasting Seoul Jjajang 3.49 Oz (99g)
# ID: 8226368    Name: IHODAM NAMWON MUDFISH SOUP 15.87 OZ (450G)
# ID: 8226369    Name: Nori Maki Arare 3oz(85g)
# ID: 8226370    Name: Lih Noodle Jah Jan Flavor 15.87oz(450g)
# ID: 8226374    Name: Singapore Chili Crab Flavored La Mian Noodle 5.6oz(160g) 4 Packs
# ID: 8226375    Name: Instant Miso Soup Wakame Seaweed 6.21oz(176g)
# ID: 8226378    Name: Kalguksu Knife-cut Wheat Noodle 31.7oz(900g)
# ID: 8226379    Name: Laver(GIM) Roll Fritter Original 1.1lb(500g)
# ID: 8226380    Name: Frozen Roasted Eel Unagi 8oz
# ID: 8226381    Name: Korean Pancake Sweet Red Bean 1.1lb(480g)
# ID: 8226383    Name: ë¶ê²½ ì§í ì§ì¥ë©´ 23.3oz(660g)
# ID: 8226384    Name: Noodle With Spicy Soup 1.59LB (720 G)
# ID: 8226385    Name: Spicy Beef Flavored Ramen Noodle Soup 4.26oz(121g) 4 Packs
# ID: 8226386    Name: Soupy Sweet & Spicy Ddukbokki 14.9oz(424g)
# ID: 8226388    Name: Cooked Multi Grain Rice 3 Pack*210g
# ID: 8226390    Name: Cooked Whole Grain Rice 6.87oz(195g) 3 Packs
# ID: 8226391    Name: Perilla Seeds Korean Style Pasta 15.34oz(435g)
# ID: 8226392    Name: Sutah Ramen 4.23oz(120g) 5 Packs
# ID: 8226393    Name: Porridge With Abalone 14.8oz(420g) 3 Packs
# ID: 8226394    Name: Extra Hot Chicken Flavor Ramen 4.94oz(140g) 5 Packs
# ID: 8226396    Name: Spicy Galguksu Noodle Soup 9.45OZ(268G)
# ID: 8226397    Name: Ripe Kimchi Egg Kimbap 7.76oz(220g)
# ID: 8226399    Name: Shin Ramen (Chicken Broth) 4.58oz(130g) 4 Pack
# ID: 8226400    Name: Ansung Seafood Ramen 19.75oz(559.90g)
# ID: 8226401    Name: Laver Sesame Ramen Bundle 3.52oz(100g) 4 Packs
# ID: 8226402    Name: All Purpose Vegetable & Pork Dumpling 25oz(710g)
# ID: 8226403    Name: Instant Noodle Spicy Beef Flavour 4.13oz(117g) 5 Packs
# ID: 8226404    Name: O! Noodle Cha Jang Noodle 2 PC 22.57 OZ (640 G)
# ID: 8226406    Name: Sesame Flavor Ramen 4.05oz(115g) 5 Packs
# ID: 8226408    Name: Buckwheat Noodle 25.39oz(720g)
# ID: 8226409    Name: O! Noodle Fresh Noodle 2.2 LB (1 KG)
# ID: 8226410    Name: Fresh Knife-cut Noodle 2.2lb(1kg)
# ID: 8226411    Name: Extra Hot Chicken Ramen Big Bowl 3.70oz(104.89g)
# ID: 8226412    Name: Shin Ramyun Red Bowl 4.12 Oz (117g)
# ID: 8226413    Name: Hot Chicken Flavor Ramen Stew Type Big Bowl 4.23oz(120g)
# ID: 8226414    Name: Spicy Chicken Stir-fried Ramen Carbonara Flavor 4.86oz(137.8g) 5pk
# ID: 8226417    Name: Virac Fermented Rice Punch 8.04oz(238ml) 6 Cans
# ID: 8226419    Name: Vegemil Black Bean Almond&walnut Soymilk 6.43oz(190ml) 24 Pack
# ID: 8226420    Name: Tuna Vegetable Porridge 10.6oz(300g)
# ID: 8226424    Name: Kimchi Ramen Bundle 4.23oz
# ID: 8226425    Name: Rice Porridge with Chestnut & Red Bean 10.05oz(285g)
# ID: 8226426    Name: Rice Porridge with Abalone 10.16oz(288g)
# ID: 8226429    Name: Rice Porridge With Pine Nuts 10.16oz(286g)
# ID: 8226430    Name: Egg and Vegetable Rice Porridge 10.05oz(285g)
# ID: 8226432    Name: Red Bean Rice Porridge 10.05oz(285g)
# ID: 8226433    Name: Sweet Pumpkin Porridge with Red Bean 9.88oz (280g)
# ID: 8226435    Name: Abalone Porridge 8.92oz(253g)
# ID: 8226436    Name: Sweet Red Bean Porridge 9.88 Oz (280 G)
# ID: 8226437    Name: Soybean Paste Stew 16.2oz(460g)
# ID: 8226438    Name: Chicken Soup with Ginseng 28.2oz(800g)
# ID: 8226440    Name: ë¶ê²½ì§¬ë½ 4.23oz(120g) 5í©
# ID: 8226441    Name: Hong Ramen Mild Flavor 4.2oz (120g) 5 Packs
# ID: 8226445    Name: Soybean Paste Stew with Pork 1.1lb(500g)
# ID: 8226447    Name: Sliced Rice Cakes 22.9 Oz (650 G)
# ID: 8226448    Name: ì°¸ë§ë 1.65lb(750g)
# ID: 8226451    Name: Ichiban Shio Ramen 18oz(510.29g)
# ID: 8226452    Name: Ichiban Miso Ramen 17.75oz(503.20g)
# ID: 8226453    Name: Demae Ramen Black Garlic Oil 17.64oz(500g)
# ID: 8226454    Name: Hetbahn Cooked Sprouted Brown Rice Box 7.4oz(210g) 12 Ea
# ID: 8226455    Name: Seafood Porridge 10.6oz(300g)
# ID: 8226456    Name: FARMS BANK OPPANE ICE BANANA ROASTED SWEET POTATOES 4.58 OZ (130G)
# ID: 8226457    Name: Thin Somen 3.3lb(1.5kg)
# ID: 8226459    Name: Tempura Udon Noodle Big Bowl 3.88oz(110g)
# ID: 8226460    Name: Seafood Porridge Bowl 9.52oz(270g)
# ID: 8226461    Name: Yam Noodle High Fiber 8.82 OZ (250 G)
# ID: 8226462    Name: FARMS BANK OPPANE ICE PINEAPPLE ROASTED SWEET POTATOES 4.58 OZ (130G)/
# ID: 8226463    Name: Shrimp Fried Rice 15.8oz(420g)
# ID: 8226464    Name: ì¬ì¼ì°ë 15.6oz(442.4g)
# ID: 8226465    Name: Hot Pepper Japchae Dumplings 24oz(680g)
# ID: 8226466    Name: Rose Topokki With Holes 12oz(340g)
# ID: 8226467    Name: Rice Cake with Beef Bone Soup (Cup) 151g
# ID: 8226468    Name: Snack Ramen 3.04oz(108g) 5 Packs
# ID: 8226469    Name: Jinjja Jjolmyeon 5.29oz(150g) 4 Packs
# ID: 8226471    Name: Hot & Spicy Jumbo Bowl Noodle 3.88oz(110g)
# ID: 8226473    Name: Korean Cold Noodles 27.51 OZ (780 G)
# ID: 8226474    Name: Hongya (Sichuan) Spicy Jjajang Noodle 2.02 Lb (920g)
# ID: 8226475    Name: Oriental Style Noodle Vermicelle 2.2lb(1kg)
# ID: 8226477    Name: Noodle With Black Soybean Sauce 32.45 OZ (920 G)
# ID: 8226478    Name: Jjajang Noodle 4.76oz(135g) 5 Packs
# ID: 8226479    Name: Medium Round Noodle 1.98lb(900g)
# ID: 8226480    Name: Rice Noodle with Non-spicy Seafood Flavored Soup 3.25oz(92g) 6 Packs
# ID: 8226481    Name: Rice Noodle 1.76lb(800g)
# ID: 8226485    Name: Wheat Noodle Thin Round 31.7oz(900g)
# ID: 8226486    Name: Gonghwachun Zajang Noodle 6.84oz(193g) 4 Packs
# ID: 8226487    Name: Gong Hwa Chun Zajang Cup Noodle 5.64oz(160g)
# ID: 8226488    Name: Yangban Bibimedbap Tuna Kimchi Bibimbap 8.82 Oz(250g)
# ID: 8226489    Name: Spicy&Sour Vermicelli Rice Noodle (Cup) 4.6oz
# ID: 8226493    Name: Sanukiya Udon Pack 2.75lb
# ID: 8226494    Name: Knife-Cut Noodle 1.76lb(800g)
# ID: 8226497    Name: Cup Noodle Original 2.4oz(68g)
# ID: 8226498    Name: STIR-FRIED WEBFOOT OCTOPUS - CHEESE FLAVOR 10.58 OZ (300G)/20
# ID: 8226499    Name: Stir Fry Neoguri 4.83oz(137g) 4 Packs
# ID: 8226500    Name: Hot Spicy Cup Topokki 4.23oz(120g)
# ID: 8226501    Name: Kaguri Big Bowl 3.63oz(103g)
# ID: 8226503    Name: Jjajang Bokki 4.23oz(120g)
# ID: 8226504    Name: ì§í ì§ì¥ë©´ 22.6oz(640g)
# ID: 8226506    Name: Cold Noodle With Soup 2.2 Lb(1kg)
# ID: 8226507    Name: 33whole Grain Tteok-bokki With Mill 16.57oz(470g)
# ID: 8226508    Name: ì¤ì ìµì¢ë ì²­êµ­ì¥ì°ê° 650g
# ID: 8226510    Name: Ox Bone Soup with Beef 15.9oz(450g)
# ID: 8226511    Name: Spicy Beef And Vege Soup 1.21 LB (548 G)
# ID: 8226513    Name: Korean Red Ginseng Extract Gold 101.44oz(3000ml)
# ID: 8226514    Name: Pork Loin Cutlet 12oz(340g)
# ID: 8226515    Name: Spicy Kimchi Ramen Bowl 3.03oz(85.8g)
# ID: 8226516    Name: Shin Ramen Multi Pack, Vegan (Mushroom & Fried Tofu) 4 Pack
# ID: 8226517    Name: Cooksi Korean Rice Noodle Kimchi 1.21oz(34.3g) 6 Packs
# ID: 8226518    Name: Dukboki Mad Spicy 1.32lb(600g)
# ID: 8226519    Name: Seaweed Roll Original 17.6oz(500g)
# ID: 8226520    Name: Sanuki Udon(Noodle Only) 7.05oz(200g) 3 Pk
# ID: 8226521    Name: Jumbo Udon 3 PC 20.94 OZ (593 G)
# ID: 8226522    Name: Cold Noodle Multi(Beef Broth, Spicy) 40.91oz(1.2kg)
# ID: 8226523    Name: Leek Yaki Gyoza 1.1lb(500g)
# ID: 8226524    Name: ê³µíì¶ ì§¬ë½ ë©í° 16.92 oz 4ê°ì
# ID: 8226525    Name: Neoguri Spicy Seafood Ramen 4.2OZ(120G) 10 Packs
# ID: 8226526    Name: Ricecake with Cheese Flavored Sauce 12.7oz(360g)
# ID: 8226528    Name: Perilla Seeds Knife Cut Noodles 13.64oz(387g)
# ID: 8226529    Name: Chapagetti Multi Box 4.47oz(127g)
# ID: 8226530    Name: Sesame Pancake 19.4oz(550g)
# ID: 8226531    Name: SPICY JJOLMYUN NOODLE KIT 16.2oz
# ID: 8226532    Name: Tomato Hot Chicken Flavor Ramen 4.94oz(140g) 5 Packs
# ID: 8226533    Name: Korean Fusion Rice Cake with Cheese 21.16oz(600g)
# ID: 8226534    Name: Kokomen Spicy Chicken Flavor 4.2oz(120g) 5 Packs
# ID: 8226535    Name: Demon Slayer Curry 5.6oz
# ID: 8226536    Name: Oriental Style Soup Stock for Cold Noodles Beef Flavor 11.49oz(340ml) 6 Packs
# ID: 8226538    Name: Assorted Korean Ddeok S 12oz(340g)
# ID: 8226539    Name: Instant Noodle Stew Pork Flavour 3.98oz(113g) 5 Packs
# ID: 8226540    Name: Big Soup Noodle Japanese Pork Bone Soup Flavor
# ID: 8226541    Name: Instant Noodle Stew Beef Flavour 3.88oz(110g) 5 Packs
# ID: 8226542    Name: Instant Noodle Beef Flavor & Sour Pickled Cabbage 4.24oz(120g) 5 Packs
# ID: 8226543    Name: Rice Paper For Deep-fried (Size 22cm) 17.6oz(500g)
# ID: 8226544    Name: Zaru Soba 2.99lb(1.36kg)
# ID: 8226546    Name: CRISPY CHICKEN SOY SESAME 18OZ(510G)
# ID: 8226549    Name: Kimchi Hot Chicken Ramen 4.76oz(135g) 5 Packs
# ID: 8226550    Name: Jin Jjajang Bundle 4.76oz(135g) 4 Packs
# ID: 8226551    Name: Spicy Pork & Vegetable Dumpling 24oz(680g)
# ID: 8226552    Name: Gomtang Myon Ramen 3.88oz(110g) 4 Packs
# ID: 8226553    Name: Assorted Sweet Bean Rice Cake (Soybean Powder) 13oz(368g)
# ID: 8226556    Name: Big Soup Noodle Seafood Flavor 4.94oz(140g) 5 Packs
# ID: 8226557    Name: Big Soup Noodle Sour & Hot Pork Bone Soup Flavor 4.94oz(140g) 5 Packs
# ID: 8226558    Name: Mozz, Cheddar & Fishcake Corn Dogs 14.1oz(400g)
# ID: 8226559    Name: Instant Miso Soup Green Onion 6.21oz(176g)
# ID: 8226560    Name: Soon Kimchi Ramen Cup 2.6oz(75g) 6 Cups
# ID: 8226561    Name: Seaweed Ramen 2.3oz(65g) 6 Cups
# ID: 8226562    Name: Spicy Beef and Vegetable Soup 19.4oz(550g)
# ID: 8226563    Name: Stir-Fried Pork with Kimchi 12.03oz(350g)
# ID: 8226564    Name: Cold Buckwheat Noodle with Chilled Broth 22oz(624g)
# ID: 8226565    Name: Pyeong Yang Cold Noodle 22 OZ (623 G)
# ID: 8226566    Name: Cooked Konjac & Oats & Chickpeas 5.29oz(150g) X 20 Ea
# ID: 8226567    Name: Jjajang Hot Chicken Ramen Big Bowl 3.7oz(104.8g)
# ID: 8226568    Name: PIAGOL MISEONSSL TOFU JJAGEULI 7.05 OZ (200G)
# ID: 8226569    Name: Traditional Wheat Noodle Thin Round 31.7oz(900g)
# ID: 8226570    Name: Sweet & Spicy Ddukbokki 16.9oz(480g)
# ID: 8226572    Name: Starch Noodle with Spicy Sauce 9.69oz(275g)
# ID: 8226573    Name: Mushroom Dumplings 12.34oz(350g)
# ID: 8226574    Name: Kimchi Dumplings 12.34oz(350g)
# ID: 8226575    Name: Mixed Vegetable Glass Noodles Dumplings 12.34oz(350g)
# ID: 8226576    Name: Japchae Vegan Kimbap 7.76oz(220g)
# ID: 8226577    Name: Korean Spicy Cold Noodles 13.4 OZ (380 G)
# ID: 8226578    Name: ì¬ëí¤ì¼ ì°ëì»µ ê°ì°ì¤ 7.79oz(220.8g)
# ID: 8226581    Name: Noodle (Chicken Curry) 5 Pack 2.65oz
# ID: 8226582    Name: íì ë¬¼ëë©´ 2.21lb(1.01kg)
# ID: 8226583    Name: Pork & Vegetable Crispy Dumplings 1.5lb(680g)
# ID: 8226584    Name: Cheese Hot Chicken Ramen Big Bowl 3.70oz(105g)
# ID: 8226586    Name: Kimchi Ramen 2.99oz(85g) 6 Packs
# ID: 8226587    Name: Garlic Miso Ramen 2 PC 10.86 OZ (309 G)
# ID: 8226588    Name: Big Soup Noodle Chicken & Mushroom Flavor 4.87oz(138g) 5 Packs
# ID: 8226589    Name: Spicy Chicken Bowl Noodle Soup 3.03oz(86g)
# ID: 8226590    Name: Vivid Green Vegan Curry 6.3oz(180g)
# ID: 8226591    Name: Plant Based Szechuan Style Flat Dumplings 24.7oz(700g)
# ID: 8226593    Name: Sweet Rice 2lb(907g)
# ID: 8226595    Name: Gochujang Hot Pepper Paste 1.1lb(500g)
# ID: 8226596    Name: Organic Peeled Roasted Chestnut 3.5oz(100g)
# ID: 8226597    Name: íêµ­ ìì¡ì´ ë²ì¯ 1í©
# ID: 8226598    Name: Vegetable Steamed Bun 9oz(255g)
# ID: 8226599    Name: Acorn Flour 1lb(454g)
# ID: 8226600    Name: Soon Tofu 10.58oz(300g)
# ID: 8226601    Name: Pickled Radish 12.35oz(350g)
# ID: 8226602    Name: Korean Dried Shitake Sliced Mushroom 3.52oz(100g)
# ID: 8226603    Name: Black Beans 2lb(0.9kg)
# ID: 8226604    Name: Dried Taro Stem 2.82oz(80g)
# ID: 8226605    Name: Dried Eggplant 2.82oz(80g)
# ID: 8226606    Name: Mixed Grains 5lb(2.26kg)
# ID: 8226607    Name: Burdock Chips 3.52oz(100g)
# ID: 8226608    Name: Chili Pepper Chips 3.52oz(100g)
# ID: 8226609    Name: Mill Rice Bun with Sweet Potato 1.76 Oz (50g) X 10Pack
# ID: 8226610    Name: Sweet Pumpkin Steamed Bread 1.75 Oz (50g) X 10Pack
# ID: 8226611    Name: Black Soybean Natto 10.5oz(297g)
# ID: 8226612    Name: Corn Tea 300g(10g x 30T)
# ID: 8226613    Name: Light Standard Tuna 5.29oz(150g) 4 Cans
# ID: 8226614    Name: Sunchang Soy Bean Paste 15.9oz(450g)
# ID: 8226617    Name: Choco Heim Big Size 10oz(284g)
# ID: 8226618    Name: ì§ê°ì¥ ê¸F3 29.08oz(860ml)
# ID: 8226619    Name: ë°ì´ì¤í ìêµ¬ë¥´í¸ 2.2 fl.oz(65ml) 25ê°ì
# ID: 8226621    Name: Coarse Red Pepper Powder 1lb(450g)
# ID: 8226622    Name: Monk Fish Spicy Stew 1.52lb(689.4g)
# ID: 8226623    Name: Ppushu Ppushu Bulgogi Flavor 3.17oz(90g)
# ID: 8226625    Name: Frozen Yogurt 2.09fl(62ml) 20pc
# ID: 8226627    Name: Matdongsan Snack 10.58 Oz (300g)
# ID: 8226628    Name: Gyoza Dipping Sauce 10.22oz(290g)
# ID: 8226629    Name: Sweet Rice Powder 14.1oz(400g)
# ID: 8226630    Name: Chestnut Bundle Pack 28.02oz(800g)
# ID: 8226632    Name: Korean Angelica Tea 1.41oz(40g)
# ID: 8226633    Name: Mocha Gold Mild Coffee Mix 0.42oz(12g) 100 Sticks
# ID: 8226634    Name: Kanu Americano Mild 30 Sticks /1.6g
# ID: 8226635    Name: Low Sugar Rice Cooker (Mint)
# ID: 8226636    Name: Korean Dried Braken 2.46oz(70g)
# ID: 8226637    Name: Dried Shiitake Mushroom (Sliced) 2.46oz(70g)
# ID: 8226638    Name: Dried Fernbrake 3.52oz(100g)
# ID: 8226639    Name: Youngin Dried Bracken 2.82oz(80g)
# ID: 8226640    Name: Perilla Oil 8.45fl Oz(250ml)
# ID: 8226641    Name: Fresh Wasabi Paste for Meat 4.23oz(120g)
# ID: 8226642    Name: Korean Dried Daikon Radish 5.29oz(150g)
# ID: 8226643    Name: Maxim Kanu Espresso Matcha Latte 8 Sticks 4.88 Oz (138.4g)
# ID: 8226647    Name: Honey Butter Chip 4.23oz(120g)
# ID: 8226648    Name: Oh Yes 0.99oz(28g) 12 Pcs
# ID: 8226649    Name: Corn Choco 2.33oz(66g)
# ID: 8226650    Name: O! Tube Cheddar Cheese 4.06oz(115g)
# ID: 8226651    Name: Peanut Crunch Big Size 5.89oz(167g)
# ID: 8226653    Name: Dried Kelp 6OZ (170G)
# ID: 8226654    Name: Pure Dried Seaweed 5.29oz(150g)
# ID: 8226655    Name: Banana Kick Banana Snack 1.58oz(45g)
# ID: 8226656    Name: Vegemil Black Bean High Calcium Soymilk 6.43oz(190ml) 24 Packs
# ID: 8226657    Name: Choco Homerun Ball Big Size 4.52oz(128g)
# ID: 8226658    Name: Shrimp Meat Chip 1.58oz(45g)
# ID: 8226659    Name: Korean Traditional Cookie (Yak-Gwa) 3.52oz(100g)
# ID: 8226660    Name: Turtle Chips Cornsoup 2.8oz(80g)
# ID: 8226661    Name: Peanut and Squid Ball Snack Big Size 7.12oz(202g)
# ID: 8226663    Name: Premium Korean Mackerel Fillet 1+1 Set 11.99oz(340g)
# ID: 8226664    Name: Pickled Seaweed Tot 12.34oz(350g)
# ID: 8226665    Name: Gosomi Biscuit 7.62oz(216g) 12 Packs
# ID: 8226670    Name: White Rice 15lb(6.8kg)
# ID: 8226671    Name: Wasabi Furikake 1.7oz(48g)
# ID: 8226672    Name: Hot Pepper Paste Mild 1.1lb(500g)
# ID: 8226673    Name: Shrimp Crackers Gochujang Flavor 2.64oz(75g)
# ID: 8226674    Name: O'Food Mild Doenjang (Original Soybean Paste) 1.1lb(500g)
# ID: 8226675    Name: Premium Roasted Seaweed(GIM) (Green Laver) 0.71oz(20g) 4 Packs
# ID: 8226676    Name: Premium Roasted Seaweed (Laver) 0.71oz(20g) 4 Packs
# ID: 8226677    Name: íë¯¸ìì´ 16.9oz(500ml)
# ID: 8226678    Name: Rice Crackers Senbei 3.95oz(112g)
# ID: 8226680    Name: Roasted Seaweed 20 Sheets 1.41oz(40g)
# ID: 8226681    Name: Jin Ramen 18 Pack (Box) Mild 4.23 Oz (120g)
# ID: 8226683    Name: Korean Rice Cookie 3.52 OZ (100 G)
# ID: 8226684    Name: Peeled Garlic 1lb(454g)
# ID: 8226685    Name: Shijang Fish Cake 7.94oz(225g)
# ID: 8226686    Name: Vegetable Sausage Pack 8.82oz
# ID: 8226687    Name: Pickled White Radish (Whole) 1.1 LB (500 G)
# ID: 8226688    Name: Yangban Cabbage Kimchi 14.1oz(400g)
# ID: 8226689    Name: Seasoned Perilla Leaves 7oz(200g)
# ID: 8226690    Name: Pure Sesame Oil 12fl Oz(355ml)
# ID: 8226691    Name: Premium Koimo Sweet Potato 6ea (3lb)
# ID: 8226692    Name: Beef Bone Broth Soup 17.6oz(500g)
# ID: 8226693    Name: Turtle Chips Caramel Popcorn 5.64 Oz (160g)
# ID: 8226694    Name: Kancho Choco Biscuit Cup 3.35oz(95g)
# ID: 8226695    Name: Food Cham Sauce 10.58oz(300g)
# ID: 8226697    Name: Pickling Sauce for Onion 11.64oz(330g)
# ID: 8226698    Name: Mini Shrimp Chip 4PK (120G)
# ID: 8226699    Name: Binch Multi Pack 7.2oz(204g)
# ID: 8226700    Name: Bai Top Shell Yudong 14.1oz(400g)
# ID: 8226701    Name: The Mishik Squid Ramen 4.59 Oz (130g) X 4 Pack
# ID: 8226702    Name: Spicy Ramen 4.15 Oz (117g) X 4 Pack
# ID: 8226704    Name: Chicken Frying Mix 35.27oz(1kg)
# ID: 8226705    Name: Vinyl Gloves 200 Ea
# ID: 8226706    Name: Chocolate Milk 6 Pk 40.56 Fl Oz (1200 Ml)
# ID: 8226707    Name: Korean Dried Pumpkin 5.29oz(150g)
# ID: 8226708    Name: Organic Boiled Radish Leaves 10.58oz(300g)
# ID: 8226709    Name: Whole Barely 2lb(907g)
# ID: 8226711    Name: Uv Sun Visor
# ID: 8226712    Name: Pocari Sweat Drink
# ID: 8226713    Name: French Cafe Stevia 0.36oz(10g) 100 Sticks
# ID: 8226714    Name: Tuna In Sesame Oil 3.17 Oz (90g) X 4 Can
# ID: 8226715    Name: Soybean Paste Shellfish Anchovy Flavor 1.98lb(900g)
# ID: 8226716    Name: Pororo Apple Flavor Juice Drink 7.95 fl.oz(235ml)
# ID: 8226717    Name: Probiotics Dairy Drink Will Original 5.07 Fl Oz (150ml) X 4ea
# ID: 8226718    Name: ì ë¼ë í¬ê¸°ê¹ì¹ 2.2lb(1kg)
# ID: 8226719    Name: Nonfat Probiotic Drink (Original) Yakult
# ID: 8226720    Name: Sesame Oil Can 56fl oz(1656ml)
# ID: 8226721    Name: Plum Flavored Extract 2.2lb(1kg)
# ID: 8226723    Name: Tuna Broth Cube 3.5oz(99g)
# ID: 8226724    Name: Soy Bean Paste 1.1lb(500g)
# ID: 8226725    Name: Gourmet Seasoning Sauce for Soup 14.1oz(400g)
# ID: 8226726    Name: Black Rice 4lb(64oz)
# ID: 8226728    Name: Soba Tsuyu 16.7 fl.oz(500ml)
# ID: 8226735    Name: Pork /chunk /single Rib Belly 2lb (907g)
# ID: 8226736    Name: Soybean Sprouts 12oz(340g)
# ID: 8226737    Name: Premium Bean Sprouts 12oz(340g)
# ID: 8226739    Name: Pork & Vegetable Dumpling 1.79lb(810g)
# ID: 8226742    Name: Bibim Yache Kimbap 8.25 Oz (234g)
# ID: 8226743    Name: Frozen Persimmon 8.56oz(282g)
# ID: 8226745    Name: Dried Persimmon 5.29 Oz (150g)
# ID: 8226746    Name: Seasoned Dried Fish Meat 2oz(57g)
# ID: 8226747    Name: Fried Fish Snack 3.88oz(110g)
# ID: 8226748    Name: SWEET RICE DRINK 50.72 FL OZ (1.5L)
# ID: 8226749    Name: SWEET PUMPKIN RICE DRINK 50.72 FL OZ (1.5L)
# ID: 8226752    Name: ì ê¸°ë í¬ì»µ ëë¶ (ì°ê°ì©) 15.5oz(439g)
# ID: 8226753    Name: ì ê¸°ë ëë¶ (ììì©) 14oz(397g)
# ID: 8226754    Name: 1966 MUGYO-DONG YUJEONG SMALL OCTOPUS 10.58OZ(300G)
# ID: 8226755    Name: Fried Squid Roll 14.1oz(400g)
# ID: 8226756    Name: Kombucha Calamango 10 EA 1.76 Oz (50g)
# ID: 8226758    Name: Bai Top Shell 14.1oz(400g)
# ID: 8226759    Name: Disposable Toothpicks (420pcs)
# ID: 8226760    Name: Charcoal Fridge Deodorizer
# ID: 8226761    Name: Steamer 9.84in(250mm)
# ID: 8226762    Name: Banana Flavored Milk Drink 6.8oz(200ml) 6 Packs
# ID: 8226765    Name: Ramie Ingeolmi  Rice Cake With Bean Powder 11.1oz(315g)
# ID: 8226768    Name: Tuna In  Spicy Sesame Oil  3.17 Oz (90g) X 4 Can
# ID: 8226769    Name: Spicy Broth Cube 3.5oz(99g)
# ID: 8226772    Name: Dried Sweet Potato 2.12 Oz(60g)
# ID: 8226773    Name: CHILDREN'S CHEESE Step 2 6.34oz (180G)(18g/10)
# ID: 8226775    Name: Probiotics Dairy Drink Will Low Fat 5.07 Fl Oz (150ml) X 4ea
# ID: 8226778    Name: Frozen Peeled Shrimp 71/90 1lb(454g)
# ID: 8226779    Name: Dried Chestnut 1.76 Oz(50g)
# ID: 8226781    Name: O! Tube Sweet Chilli 4.06oz(115g)
# ID: 8226783    Name: Churros Strawberry 1.6oz(46g)
# ID: 8226784    Name: Safe Baby Food Puree Oatmeal & Apple Prune 3.52 OZ (100G) x 10 Pack
# ID: 8226785    Name: Safe Baby Food Puree Scallop & Tofu 3.52 OZ (100G) x 10 Pack
# ID: 8226787    Name: Yakkwa(Korean Traditional Sweet Rice Cake) 12.70oz(360g)
# ID: 8226788    Name: Korean Soy Sauce Kimjaban 1.76oz(50g)
# ID: 8226789    Name: Korean Traditional Biscuit(Regular) 5.99oz(170g)
# ID: 8226790    Name: Daifuku Mochi 6pc (White) 10.58oz(300g)
# ID: 8226791    Name: Akai Bohshi Elegant Pink Cookie Box Set 2.37OZ(67.1G)
# ID: 8226792    Name: Korean Traditional Cookie Set 1.54lb(700g)
# ID: 8226793    Name: Sansyoku Dango 4.76 OZ (135 G)
# ID: 8226794    Name: Daifdaifuku Mochi 6pc (Pink) 10.58oz(300g)
# ID: 8226795    Name: Ddaifuku Mochi 6pc (Green) 10.58oz(300g)
# ID: 8226796    Name: Ramie Sweet Rice Cake 11.6oz(330g)
# ID: 8226797    Name: Dried Squid 3 Pcs 7.41oz(210g)
# ID: 8226799    Name: Green Bean Starch 1lb(453g)
# ID: 8226800    Name: Premium Wheat Flour 5.5 LB (2500 G)
# ID: 8226802    Name: Korean Pepper 1 Pack
# ID: 8226803    Name: Organic Tofu (Soft) 14oz(397g)
# ID: 8226806    Name: Frozen Oyster 8oz(226g)
# ID: 8226807    Name: Ginseng Chicken Soup (Samgyetang) Preparation 10oz(284g)
# ID: 8226809    Name: Mill Rice Bun 1.76 Oz (50g) X 10Pack
# ID: 8226810    Name: Furikake Mushroom 0.84oz(8g) 3 Ea
# ID: 8226811    Name: Dried Laver(GIM) for Gimbap 20 Sheets 1.41oz(40g)
# ID: 8226812    Name: Soy Bean Paste 6.17lb (2800g)
# ID: 8226814    Name: Choco Pie 1.37oz(39g) 12 Packs
# ID: 8226815    Name: Choco Pie Banana 15.65oz(444g)
# ID: 8226817    Name: Shrimp Chip 6.34oz(180g)
# ID: 8226820    Name: Pork Thin&Roll Single Rib Belly, Frozen 1lb(454g)
# ID: 8226821    Name: Sliced Pork Jowl Meat 0.5lb (227g)
# ID: 8226822    Name: Marinated Pork Tenderized CT Butt Steak 1lb(454g)
# ID: 8226823    Name: Seafood Salted Seaweed 10.58oz(300g)
# ID: 8226824    Name: Organic Two Pack Tofu (Firm) 15.5oz(439g)
# ID: 8226826    Name: ë¹ë¹ê³  ì°ìë°°ì¶ê¹ì¹ 32OZ Sliced Kimchi 32oz(907g)
# ID: 8226831    Name: Chosun Ganjang Naturally Brewed Soy Sauce for Soup 31.4 fl.oz(930ml)
# ID: 8226833    Name: Frozen Cleaned Squid 12.34oz(350g)
# ID: 8226835    Name: Peanut Crunch 2.82oz(80g)
# ID: 8226838    Name: Very Berry Strawberry Choco Ball 1.12 OZ (32G)
# ID: 8226839    Name: Choco Ball Puss In Boots 1.12 OZ (32G)
# ID: 8226840    Name: Crispy Roasted Seaweed Snack 0.18oz(5g) 8 Packs
# ID: 8226841    Name: Premium Oyster Flavored Sauce 18oz(510g)
# ID: 8226842    Name: Black Bean Garlic Sauce 13oz(368g)
# ID: 8226849    Name: Tofu Shirataki Spaghetti 8oz(226g)
# ID: 8226850    Name: Kadayif Pistachio Dubai Chocolate 2.82 OZ (80G)
# ID: 8226852    Name: Sweet Potato Stick 10.58oz(300g)
# ...
# ID: 108174268  Name: Rock 2 In 1 (Bbq Shrimp With Seafood Sauce) 69g
# ID: 108174319  Name: Milk Dacquoise 6.98 Oz (198g)
# ID: 108174379  Name: Limited Edition Korean Smoked Galbi Flavour 3.52OZ(100G)
# ID: 108174395  Name: 100% Sesame Oil 18.6fl oz(550ml)
# ID: 108174399  Name: Navel Orange 4 Ea
# ID: 108174413  Name: Baby Crab Chips 3.52oz(100g)
# ID: 108174451  Name: Paik Cook Spicy Topokki Sauce 5.46oz(155g)
# ID: 108174473  Name: CARBON MAT(SINGLE) EME 501 (37.4x70.8 IN)/1
# ID: 108174485  Name: Jeju Flounder Fish-Cake Bar With Corn & Shrimp 8.81 Oz (250g)
# ID: 108174501  Name: Frozen Boiled Clam 12oz(340g)
# ID: 108174507  Name: Soft Tofu JJigae Sauce 4.93oz(140g)
# ID: 108174526  Name: Quail Eggs In Water 15oz
# ID: 108174554  Name: Parsley & Garlic Baguette Chips 2.46oz(70g)
# ID: 108174562  Name: MISUNG FROZEN YELLOW CROAKER 1.32 LB (600G)
# ID: 108174573  Name: Korean Dried Green Chwinamul 2.46oz(70g)
# ID: 108174668  Name: DRIED SEAWEED CUT 1.76OZ(50G)
# ID: 108174746  Name: Red Ginseng Drink 60 PK 162fl oz(4790ml)
# ID: 108174754  Name: 100% Pure Sesame Oil 12.5fl oz(370ml)
# ID: 108174762  Name: Mayonnaise Light 80% Calorie Cut 10.93 Oz (310g)
# ID: 108174783  Name: Jeju Mandarin Sable Sand 6.35 Oz (180g)
# ID: 108174797  Name: Stiky Rice Deep-fried Honey Cookies 6.35oz(180g)
# ID: 108174799  Name: Biscuit Crystal Grape & Peach Flavor 3.42 Oz (92g)
# ID: 108174816  Name: Honey Roasted Peanuts Can 4.59oz(130g)
# ID: 108174825  Name: ROASTED SESAME SEED 3.52 OZ(100G)
# ID: 108174833  Name: EDIBLE SALT 2.2LBS(1KG)
# ID: 108174843  Name: ORGANIC 7 MIXED GRAINS 12LB(5.44KG)
# ID: 108174846  Name: BASASAK CRISPY SEAWEED SNACK 1.41OZ(40G)
# ID: 108174873  Name: Injeolmi Peanuts 3.88oz(110g)
# ID: 108174884  Name: Tonic Water Original 300ml
# ID: 108174893  Name: SEASONED SLICED RAW SKATE-RAY 4.23OZ(120G)
# ID: 108174921  Name: Tofu Snack 4.23oz(120g)
# ID: 108174922  Name: Konjac Jelly Peach 5.29oz(150g)
# ID: 108174926  Name: Calming Serum : Green Tea + Panthenol 30ml
# ID: 108174929  Name: Joongmago Ramen Snack 11.64oz(330g)
# ID: 108174932  Name: Sesame Long Stick Cracker 3.17oz(90g)
# ID: 108174964  Name: Muskmelon Sparkling Soda 10.58oz(300ml)
# ID: 108175016  Name: Ulleungdo Myeongyi Pickle 4.59oz(130g)
# ID: 108175029  Name: Organic Rice Puffing Snack Ring Blueberry 1.41oz(40g)
# ID: 108175030  Name: Organic Rice Puffing Snack Ring Banana 1.41oz(40g)
# ID: 108175031  Name: Organic Rice Puffing Snack Ring Hallabong1.41oz(40g)
# ID: 108175050  Name: Real Puffing Strawberry & Banana 0.88oz(25g)
# ID: 108175052  Name: Brown Rice Puff with Apple 1.06oz(30g)
# ID: 108175076  Name: Ramune Grape Flavor 6.76oz(191g) 6 Pack
# ID: 108175092  Name: Our Tea Jeju Mandarin & Chamomile Tea 0.7oz(17g) 10T
# ID: 108175093  Name: Mayonnais 2.2 Lb (1kg)
# ID: 108175100  Name: Thousand Island Dressing 10.5oz(310G)
# ID: 108175102  Name: Choco Diy 1.26oz(36g)
# ID: 108175113  Name: Gochujang Bulgogi Sauce 4.93oz(140g)
# ID: 108175125  Name: Acorn Starch 16 Oz(453g)
# ID: 108175128  Name: Korean Shine Muscat Grape 1 Pack
# ID: 108175133  Name: HSJ Anchovy Sauce 17FL OZ (500ML)
# ID: 108175134  Name: Dried Kelp Korea 5.29OZ(150G)
# ID: 108175141  Name: Nuruk Enzyme Amylase Powder 16oz(453g)
# ID: 108175150  Name: Lemon Tea (Jasmine) 15.21 Fl Oz (450 Ml)
# ID: 108175223  Name: Youngdeok Crab Meat 3.17oz(90g)
# ID: 108175240  Name: SALTED SHRIMPS 2.2 LB (1KG)
# ID: 108175241  Name: THE RICE HAENAM SWEET POTATO RICE BREAD 2.82 OZ (80G)
# ID: 108175256  Name: Biscuit Chocolate Creme Chocolate Creme Flavor 3.42 Oz (92g)
# ID: 108175279  Name: Farmer Rice Punch 16.9floz(480g)
# ID: 108175327  Name: Fried Crispy Pollock Chip 1.76oz(50g)
# ID: 108175340  Name: Sujeonggwa Drink 11.49 Fl Oz (340ml) 8 Pack
# ID: 108175356  Name: Chocopie Strawberies 14.39oz(408g)
# ID: 108175364  Name: Boy Assorted Jelly 48.2oz
# ID: 108175365  Name: Girl Assorted Jelly 48.2oz
# ID: 108175367  Name: Sparkling Water (Lemon) 16.9 floz(500ml) 6 Packs
# ID: 108175387  Name: Pure Fit Cica Cream 50ml
# ID: 108175431  Name: Khao Soi Chicken 69g
# ID: 108175437  Name: Sc Chocochip Cookie 3.13oz(80g)
# ID: 108175484  Name: [H MART Exclusive]Traditional Black Sesame Donuts 2.11 Lb (960g)
# ID: 108175542  Name: Ultra Vitamin D 2000
# ID: 108175549  Name: 100% Pure Sesame Oil 22.11fl Oz(654ml)
# ID: 108175554  Name: HANTORE RICE 1.1LB(500G)
# ID: 108175557  Name: MyKids Omega-3 Chewable
# ID: 108175569  Name: Egg Cookies 3 Packs Bundle 6.34oz(180g)
# ID: 108175573  Name: Grade A Organic 12 Medium Brown Eggs 21oz(596g)
# ID: 108175574  Name: Pickled Yellow Radish 17.6 OZ (500 G)
# ID: 108175579  Name: Konjac Jelly Mango 5.29oz(150g)
# ID: 108175580  Name: Konjac Jelly Grape 5.29oz(150g)
# ID: 108175581  Name: Konjac Jelly Apple 5.29oz(150g)
# ID: 108175582  Name: Konjac Jelly Mikan 5.29oz(150g)
# ID: 108175620  Name: Tonic Water Black Tea
# ID: 108175629  Name: Damizle Shine Musckat Tea 14.1oz(400g)
# ID: 108175639  Name: Dried Kelp 7oz(198g)
# ID: 108175646  Name: Fish Sausage 4 PC 10.56 OZ (300 G)
# ID: 108175659  Name: DRIED KELP 5.29 OZ (160G)
# ID: 108175712  Name: CHUNJIHAE STIR-FRIED LAVER(GIM) FLAKE 1.76 OZ (50G)
# ID: 108175715  Name: Aqua Soothing Sheet Mask Honey 0.88oz(25g)
# ID: 108175725  Name: Duck Thin&Roll Boneless Breast 1lb(454g)
# ID: 108175726  Name: Roasted Laver(GIM) Perilla Oil 9PK 1.58OZ (45G)
# ID: 108175746  Name: BUCKWHEAT NOODLE SAUCE 7.05OZ(200G)
# ID: 108175749  Name: Birch Juice Moisturizing Cream
# ID: 108175750  Name: Hydra Soothing Sheet Mask
# ID: 108175753  Name: Pure Calming Sheet Mask
# ID: 108175756  Name: Parsley & Garlic Baguette Chips 14.10oz(400g)
# ID: 108175758  Name: Ultra Vitamin B Complex C
# ID: 108175762  Name: Premium Roasted Seaweed 0.15oz(4.25g) 16 Packs
# ID: 108175810  Name: EGG COOKIE 2.2 LB (1KG)
# ID: 108175816  Name: Red Ginseng Essense Mask Sheet 0.81oz(23g)
# ID: 108175824  Name: Big Roll Grilled Seaweed Roll (Classic) 0.95oz
# ID: 108175836  Name: DRIED SEAWEED 5.29 OZ (160G)
# ID: 108175859  Name: Electric Heating Pad with Washable Cover Double 53.14 X 70.86 in
# ID: 108175873  Name: Hallabong Dacquoise 6.98 Oz (198g)
# ID: 108175880  Name: Kit Kat Mini Cookie & Cream 13 Bars 4.5oz(128g)
# ID: 108175885  Name: Biscuit White Peach Oolong Tea Flavor 3.42 Oz (92g)
# ID: 108175913  Name: Perfect Serum Treatment 180ml
# ID: 108175918  Name: Probiotics Granola Fullmix Banana 1.41oz(40g) 7 Pouches
# ID: 108175920  Name: Roll Cakes (Yaki) 7.7 OZ (218 G)
# ID: 108175930  Name: ê¹ë¹ë 4lb(1.8kg)
# ID: 108175937  Name: 100% Sesame Oil 56fl oz(1657ml)
# ID: 108175946  Name: PREMIUM TROPICAL ICE CREAM (MACAPUNO UBE) 48OZ
# ID: 108175950  Name: HSW Calm Unsweetened Sparkling Herbal Drink With Korean Red Ginseng
# ID: 108175968  Name: Cream Shrimp & Mushroom 0.99oz(28g)
# ID: 108175974  Name: Coned Beef with Juice 12oz(340g)
# ID: 108176000  Name: Mouth Refresher 800pc
# ID: 108176009  Name: LAVA MOONCAKE (ASSORTED) 12.3OZ (348G)
# ID: 108176013  Name: Sanrio Characters Shio Seto 3.67 Oz (104g)
# ID: 108176016  Name: Soybean Powder 8oz(226g)
# ID: 108176031  Name: Balloon Flower Drink 30pk 71floz
# ID: 108176045  Name: Bath Spa Gift Set
# ID: 108176073  Name: Grade A Organic 12 Large Brown Eggs 24oz(681g)
# ID: 108176088  Name: INJE Schisandra Extract 16.9FLOZ(500ML)
# ID: 108176118  Name: Bottle Opener
# ID: 108176119  Name: DALKONG BLACK BEAN 3.52OZ(100G)
# ID: 108176121  Name: Family Cake 10.1oz(286g)
# ID: 108176125  Name: All Purpose Wheat Flour 2.2lb(1kg)
# ID: 108176144  Name: Potato Snack Red Chili 2.11oz(60g)
# ID: 108176148  Name: FRIED FISH SNACK 2.82 OZ (80G)
# ID: 108176153  Name: TURTLE CHIPS CORNSOUP 1.06 OZ (30G)/12
# ID: 108176161  Name: ZJR EP-PBC10 ELECTRIC SKILLET
# ID: 108176172  Name: Frozen Dried Pollock Meat 2oz(56g)
# ID: 108176175  Name: Yukgaejang Sauce 4.23oz(120g)
# ID: 108176179  Name: Fish Sausage 13.4 OZ (380 G)
# ID: 108176236  Name: Soft Salad Rice Snack 4.92oz(140g)
# ID: 108176280  Name: Aguri Konjac Jelly Mix (Mango,muscat,mikan) 10.15 Oz(288g)
# ID: 108176282  Name: Smoked Berkshire Sausage (Spicy) 8 OZ (230 G)
# ID: 108176288  Name: Youngdeok Crab Meat Sauce 3.17oz(90g)
# ID: 108176301  Name: Laver&tofu Chip Black Garlic 1.05oz(30g)
# ID: 108176305  Name: Star Eat Pokemon 3.03 Oz (86g)
# ID: 108176311  Name: Sparkling Water (Muscat) 16.9 Floz(500ml)
# ID: 108176317  Name: Pakila Chocolate 1.5oz(44g)
# ID: 108176318  Name: K-BBQ Seaweed 16PK 2.24OZ (63.5G)
# ID: 108176329  Name: Pomegranate Essense Sheet Mask 0.81oz (23g)
# ID: 108176337  Name: Kitkat Mont Blanc Flavor 4.09 Oz (116g)
# ID: 108176339  Name: Poke Piece Small Star Tabe Yoshio Flavor 3pk 1.06 Oz (30g)
# ID: 108176349  Name: Citrus Flavored Yugwa 14.11oz(400g)
# ID: 108176369  Name: JAYEONBONGA SIKHYE 18.59 FL OZ(550ML)
# ID: 108176370  Name: HEALTHY YAM MEAL WITH 15GRAINS 10.58OZ(300G)
# ID: 108176640  Name: íë¦¬ì¤ íë§ë¼ì¼ íí¬ìí¸ ë´ì ì¹«ì(4pcs)
# ID: 108176984  Name: DRIED PERSIMMON SLICES JELLY 5.29 OZ (150G)
# ID: 108177351  Name: Caramel Sauce 6.4 Floz(190ml)
# ID: 108177518  Name: FRIED SHRIMP HEAD 1.05 OZ (30G)
# ID: 108177606  Name: Grassfed Organic Milk 64 Fl Oz (1900 Ml)
# ID: 108177898  Name: [H Mart Exclusive] ê²ìì½©ì¹¼ìëì  6.5OZ(190ML) x 24 í© [H Mart Exclusive] Soymilk with Balckbean & Calcium 6.5OZ(190ML) x 24 Pack
# ID: 108178596  Name: D-kids Red Ginseng 30pk 71floz
# ID: 108179225  Name: í´ì°¸ ê³ ê¸ ëª¨ë¬ì´ë¬µ 13ì¢ 1.1lb(500g)
# ID: 108179377  Name: Jasmine Brown Rice 5lb(2.26kg)
# ID: 108179491  Name: Ultra Vitamin C 1000
# ID: 108179517  Name: The Kimchi Young Radish Kimchi 1.1 lb(500g)
# ID: 108179618  Name: Kitkat Mini Matcha Latte 4.5oz(128g)
# ID: 108179694  Name: Probiotics Granola Fullmix Chocolate 1.41oz(40g) 7 Pouches
# ID: 108179702  Name: Potato Chips Tx Bbq (Bag) 2.46oz
# ID: 108179726  Name: Dried Kelp Slice 8oz
# ID: 108179988  Name: Young Coconut With Straw 500g
# ID: 108180045  Name: Organic Half & Half 32 Fl Oz (950 Ml)
# ID: 108180127  Name: Roasted Seaweed Gift Set 27pk 2.7oz (76.5g)
# ID: 108180288  Name: Canada Red Ginsend Extract 60 PK 162fl oz(4790ml)
# ID: 108180301  Name: SEAWEED SNACK (WASABI FLAVOR) 1.76 OZ (50G)
# ID: 108180324  Name: All Clean Balm 120ml
# ID: 108180359  Name: Apricot Blossom Peeling Gel 100ml
# ID: 108180377  Name: Pear & Bell Flower Plus Drink 3.38fl oz(100ml)
# ID: 108180412  Name: CHUNJIHAE STIR-FRIED LAVER(GIM) FLAKE WITH ANCHOVY 1.76 OZ (50G)
# ID: 108180427  Name: Sushihane Yakinori 10 Sheets 0.75oz(21g)
# ID: 108180474  Name: Pickled Yellow Radish Whole 17.6 OZ (500 G)
# ID: 108180476  Name: Yuzu Fruit Spread 7oz(200g)
# ID: 108180491  Name: ì ìµì  ì·ê±¸ì´í "ëë ì ìµì  ìëë¤" 4.23oz(120g)
# ID: 108180547  Name: SEMI-DRIED PERSIMMON 10.58 OZ (300G)/15
# ID: 108180558  Name: Plastic Food Wrap with Cutter 11.811in X 3937in (30cm X 100m)
# ID: 108180617  Name: Donga Bacchus Drink 7.78oz(220g)
# ID: 108180780  Name: Sriracha Chili Sauce 28 Oz
# ID: 108180842  Name: Long Spoon 5 Pcs Set
# ID: 108180858  Name: Korean Traditional Biscuit Set Lucky 1.65lb(750g)
# ID: 108180860  Name: Korean Traditional Biscuit Set 10 1.65lb(750g)
# ID: 108182415  Name: Plastic Bbq Dish Plate 3 Color Set 3pcs
# ID: 108182990  Name: New Hello Bubble Hair Dye 6A Dusty Ash 3.52 Oz (100g)
# ID: 108183223  Name: Organic Large Brown Grade A Eggs Dozen
# ID: 108184355  Name: Piggy Jelly Jar Lychee 25.04OZ (710G)
# ID: 108184748  Name: Banana Jubilee Crunch 4.3 OZ (122G)
# ID: 108184801  Name: Blueberry Extract Drink 71.01fl oz(2100ml)
# ID: 109579935  Name: Mango Bread 8.39 Oz (238g) èæéºµå
# ID: 109580056  Name: Pocky Cherry Blossom Matcha 3.35oz(95g)
# ID: 109580168  Name: Crispy White Dars Bar 1.38 Oz (39g)
# ID: 109580169  Name: Bite Sized Koeda Bar 1.03 Oz (29g)
# ID: 109580170  Name: Pureral Gummy Grape 2.04 Oz (58g)
# ID: 109580171  Name: Tough Gummy Grape Punch 3.52 Oz (100g)
# ID: 109580174  Name: Tough Gummy Kiwi Spark 3.52 Oz (100g)
# ID: 109580175  Name: Pureral Gummy Apple 2.04 Oz (58g)
# ID: 109580282  Name: Shin Ramyun Toomba Square Bowl 3.73 Oz (106g)
# ID: 109580283  Name: Tangle Chunky Tomato Pasta 3.7 Oz (105g) X 4Packs
# ID: 109580284  Name: Tangle Bulgogi Alfredo Pasta 3.7 Oz (105g) X 4Packs
# ID: 109580285  Name: Tangle Garlic Oil Pasta 3.53 Oz (100g) X 4Packs
# ID: 109580286  Name: Tangle Creamy Mushroom Pasta 3.7 Oz (105g) X 4Packs
# ID: 109581309  Name: Jegichagi Korean Kick Shuttlecock (Random)
# ID: 109581362  Name: It's Gim Mini Original Seaweed Snack 0.53 Oz (15g) X 10 Pcs
# ID: 109581521  Name: Korean Rice Suhyang Rice 11lb (5kg)
# ID: 109581637  Name: Top Fruit Soft Sweets Pure Juice Candy Mango 11.28 Oz (320g)
# ID: 109581699  Name: Sakura Russian Cake 4.66 Oz (132g)
# ID: 109581809  Name: Hot Octopus Stir Fried Ramen 130g X 4Packs
# ID: 109581838  Name: Imokase First Dosirak Seasoned Seaweed 0.14 Oz (4g) X 12 Packs
# ID: 109581906  Name: Marinated Beef  /Sliced /Short Ribs /LA Style 1.5lb (680g)
# ID: 109581966  Name: Top Fruit Soft Sweets Pure Juice Candy Mixed 11.28 Oz (320g)
# ID: 109582226  Name: Monster Ball Stick Bubble (Random)
# ID: 109582305  Name: Figure Jumping Rope Cinnamoroll
# ID: 109582431  Name: Seasoned Yellow Croaker 8.8oz(250g)
# ID: 112449964  Name: Homerun Ball Matcha Strawberry 1.72 Oz (49g)
# ID: 112450034  Name: Vita 500 Zero Ice Pouch 11.50 Fl Oz (340ml)
# ID: 112450074  Name: Korean Yogurt Candy 2.82 Oz(80g)
# ID: 112450112  Name: Dried Shiitake Mushroom 3.53 Oz (100g)
# ID: 112450126  Name: Canele Mix 1.1 Lb (500g)
# ID: 112450143  Name: Almost Crab 1.1 Lb (500g)
# ID: 112450144  Name: It's Gim Mini Seaweed Flakes 0.88 Oz (25g)
# ID: 112450163  Name: ORGANIC MINI KING OYSTER MUSHROOM KOREA 300G
# ID: 112450189  Name: Bingsu Rice Cake 24.69oz(700g)
# ID: 112450220  Name: Korean Soda Candy 3.53 Oz(100g)
# ID: 112450221  Name: Korean Cola Candy 3.53 Oz(100g)
# ID: 112450426  Name: Honey Butter Twist Potato 9.52 Oz (270g)
# ID: 112450562  Name: Topokki Jjajang 11.6 Oz (330g)
# ID: 112450628  Name: Hot Pepper Paste With Vinegar 10.58 Oz (300g)
# ID: 112450650  Name: Fruit Ade Honey & Pear 11.49 Fl Oz (340ml) x 8 Packs
# ID: 112450996  Name: Probiotic Mixed Berry Yoggies 0.7 Oz (20g) X 12 Packs
# ID: 112451644  Name: Jeju Yuzu Green Tea 11.49 Fl Oz (340ml) X 8 Packs
# ID: 112451653  Name: Frenchpie Petit Chocolate 6.31 Oz (179g)
# ID: 112451713  Name: Ginger Soymilk 16pk 102.79 Fl Oz (3040ml)
# ID: 112451742  Name: Probiotic Strawberry Yoggies 0.7 Oz (20g) X 12 Packs
# ID: 112451777  Name: Savory Shrimp Cup Noodle 3.03oz(86g)
# ID: 112452043  Name: Green Tea Iced Tea 11.49 Fl Oz (340ml) X 8 Packs
# ID: 147253286  Name: Korean Puffed Rice Original Flavor 4.23 Oz (120g)
# ID: 147253287  Name: Popcorn Green Onion Cream Cheese Flavor 4.4 Oz (125g)
# ID: 147253412  Name: Ice Cream (Lemon Yogurt) 3.3 Fl Oz (90ml)
# ID: 147253413  Name: Ice Cream (Taoshan Milk) 2.4 Fl Oz (72ml)
# ID: 147253414  Name: Bibimchip Signature 2.82 Oz (80g)
# ID: 147253447  Name: Thin Wheat Flour Noodles Somyeon 1 Lb (454g)
# ID: 147253624  Name: Stir-fry Cheesy Ramen Cheddar & Mascarpone 3.88 Oz (110g) X 4Packs
# ID: 147253626  Name: Volcano Carbonara Chicken Noodle King Cup 3.7 Oz (105g)
# ID: 147253712  Name: Pear Chips 0.49oz(14g)
# ID: 147253713  Name: Fig Chips 0.49oz(14g)
# ID: 147253751  Name: Real Soft Cheese Cake Strawberry Flavor 14.81 Oz (420g)
# ID: 147253804  Name: Hot Cake Mix 21.16 Oz (600g)
# ID: 147253906  Name: Bibimchip Butter Soy Sauce 2.82 Oz (80g)
# ID: 147253909  Name: Nacho Chips Kimchi Fried Rice Flavor 6.7 Oz (190g)
# ID: 147253970  Name: Real Soft Cheese Cake Original Flavor 14.81 Oz (420g)
# ID: 147254033  Name: Buldak Yakisoba Ramen Multi 4.4 Oz (125g) X 5 Pack
# ID: 147254050  Name: Top Fruit Soft Sweets Pure Juice Candy Peach 11.28 Oz (320g)
# ID: 147254085  Name: Thin Wheat Flour Noodles Somyeon 3 Lb (1kg)
# ID: 147254271  Name: Buldak Hot Sauce Stick Original 50pk 10.5 Oz (298g) X 50Packs
# ID: 147254607  Name: Coco Ppuyo Peach 9.47 Fl Oz (280ml)
# ID: 147254749  Name: Squid Game Dalgona Chocolate 1.41 Oz (40g)
# ID: 147254875  Name: Top Fruit Soft Sweets Pure Juice Candy Green Grape 11.28 Oz (320g)
# ID: 147255220  Name: Umami Gyoza Dumplings Chicken&Leek 21oz(595g)
# ID: 147255363  Name: Popular Stationery Set Cinnamoroll
# ID: 147255465  Name: Coco Ppuyo Apple Mango 9.47 Fl Oz (280ml)
# ID: 147255497  Name: ë»¥íê¸° (ì´ëì¸) 4.23 Oz (120g) Korean Puffed Rice Onion Flavor 4.23 Oz (120g)
# ID: 147255509  Name: Bibimbap Kit 7.05 Oz (200g)

# %% [markdown]
# # for all merchants and all periods
# ## right now only merchant is hmart because there is no other sale / cost data anywhere

# %%
# run the actual query get_all_pricing_info_with_scraping, and store the results in temporary.raw
df = run_query('get_all_pricing_info_with_scraping.sql')
df = df[['bb_id', 'period_id', 'merchant_id', 'store_id', 'item_id', 'name', 'day', 'timezone', 'regular_price', 'scraping_regular_price', 'promo_price', 'avg_selling_price', 'unit_cost', 'units_sold', 'total_basket_size', 'num_baskets', 'avg_basket_size', 'period_start_local', 'period_end_local']]
df.head(20)
# query = """SELECT * FROM temporary.analysis_cleaned;"""
# df = run_query(None, query)
# df.head(20)
# Out:
#         bb_id  period_id  merchant_id  store_id  item_id  \
# 0      8902.0          0           17      1173  8225800
# 1      2319.0          0           17      1173  8225801
# 2   2397073.0          0           17      1173  8225803
# 3      4140.0          0           17      1173  8225812
# 4      2320.0          0           17      1173  8225814
# 5      6190.0          0           17      1173  8225815
# 6      7952.0          0           17      1173  8225816
# 7   2397101.0          0           17      1173  8225817
# 8      4070.0          0           17      1173  8225824
# 9      6958.0          0           17      1173  8225831
# 10  1147801.0          0           17      1173  8225832
# 11     3550.0          0           17      1173  8225834
# 12     1801.0          0           17      1173  8225835
# 13     7077.0          0           17      1173  8225836
# 14     3512.0          0           17      1173  8225837
# 15     2256.0          0           17      1173  8225839
# 16     6670.0          0           17      1173  8225841
# 17     1750.0          0           17      1173  8225842
# 18     2335.0          0           17      1173  8225843
# 19     3998.0          0           17      1173  8225844
#
#                                                  name        day  \
# 0                          Frozen Udon 2.75lb(1.25kg) 2024-06-21
# 1             Golden Curry Sauce Mix Mild 7.8oz(220g) 2024-06-21
# 2                         Glass Noodles 15.87oz(450g) 2024-06-21
# 3                           Dukboki Sauce 1.76oz(50g) 2024-06-21
# 4       Golden Curry Sauce Mix Medium Hot 7.8oz(220g) 2024-06-21
# 5   íì´í¸ê³¨ë ì»¤í¼ë¯¹ì¤ 0.42oz(12g) 100ê°... 2024-06-21
# 6     Seasoned Green Laver(GIM) Box 10pk 7.1oz (201g) 2024-06-21
# 7   Viet Huong Three Crabs Fish Sauce 24 fl.oz(682ml) 2024-06-21
# 8            Beef Bone Soup 16.9 fl.oz(500ml) 6 Packs 2024-06-21
# 9   (H-Mart Exclusive) Jjajang Ramen Bundle 20.6 O... 2024-06-21
# 10  Strawberry Flavored Milk Drink 6.8oz(200ml) 6 ... 2024-06-21
# 11         Cut Cabbage Kimchi (Mat Kimchi) 2.2lb(1kg) 2024-06-21
# 12                Shin Ramen 16Pk Box 4.23OZ(120G)*16 2024-06-21
# 13   Bibim Men Spicy Cold Noodles 4.58oz(130g) 5 Pack 2024-06-21
# 14     Beef Vegetable Extra Large Dumpling 24oz(680g) 2024-06-21
# 15  Japanese Buckwheat Noodles Zaru Soba 31.8oz(900g) 2024-06-21
# 16          Moncher Cacao Cake 13.6oz(384g) 12 Pieces 2024-06-21
# 17               Ansung Tang Myun 4.4oz(125g) 4 Packs 2024-06-21
# 18        Tasty Hayashi Rice Gravy Mix 5.6 OZ (160 G) 2024-06-21
# 19             Cooked Brown Rice 7.4oz(210g) 12 Packs 2024-06-21
#
#             timezone  regular_price scraping_regular_price promo_price  \
# 0   America/New_York           5.99                   None        None
# 1   America/New_York           4.49                   None        None
# 2   America/New_York           4.99                   None        None
# 3   America/New_York           1.99                   None        None
# 4   America/New_York           4.99                   None        None
# 5   America/New_York          24.99                   None        None
# 6   America/New_York          19.99                   None        None
# 7   America/New_York           6.99                   None        None
# 8   America/New_York          12.99                   None        None
# 9   America/New_York           5.99                   None        None
# 10  America/New_York           7.99                   None        None
# 11  America/New_York          14.99                   None        None
# 12  America/New_York          18.99                   None        None
# 13  America/New_York           6.79                   None        None
# 14  America/New_York          12.99                   None        None
# 15  America/New_York           6.99                   None        None
# 16  America/New_York           7.99                   None        None
# 17  America/New_York           5.99                   None        None
# 18  America/New_York           4.29                   None        None
# 19  America/New_York          15.99                   None        None
#
#     avg_selling_price  unit_cost  units_sold  total_basket_size  num_baskets  \
# 0            5.390000        NaN         1.0             151.32            1
# 1            3.490000        NaN         1.0             213.20            1
# 2            4.990000        NaN         1.0              92.00            1
# 3            1.116000        NaN        10.0             465.38            3
# 4            3.193846        NaN        13.0            1060.47            7
# 5           24.990000        NaN         2.0             404.04            1
# 6           19.990000        NaN         1.0             213.20            1
# 7            6.990000        NaN         4.0             245.16            2
# 8           11.090000        NaN         9.0             952.78            5
# 9            4.650714        NaN        14.0            1694.46           10
# 10           7.723333        NaN         6.0             616.36            4
# 11          14.990000        NaN         1.0             206.08            1
# 12          18.990000        NaN         3.0             305.45            2
# 13           6.676667        NaN         6.0             711.88            5
# 14          11.490000        NaN         2.0             359.66            2
# 15           6.990000        NaN         1.0             166.24            1
# 16           7.590000        NaN         2.0             381.26            2
# 17           4.340000        NaN         6.0             717.05            5
# 18           4.290000        NaN        10.0             168.87            1
# 19          15.670000        NaN        10.0             560.94            5
#
#     avg_basket_size period_start_local period_end_local
# 0        151.320000         2024-06-21       2024-07-05
# 1        213.200000         2024-06-21       2024-07-05
# 2         92.000000         2024-06-21       2024-07-05
# 3        155.126667         2024-06-21       2024-07-05
# 4        151.495714         2024-06-21       2024-07-05
# 5        404.040000         2024-06-21       2024-07-05
# 6        213.200000         2024-06-21       2024-07-05
# 7        122.580000         2024-06-21       2024-07-05
# 8        190.556000         2024-06-21       2024-07-05
# 9        169.446000         2024-06-21       2024-07-05
# 10       154.090000         2024-06-21       2024-07-05
# 11       206.080000         2024-06-21       2024-07-05
# 12       152.725000         2024-06-21       2024-07-05
# 13       142.376000         2024-06-21       2024-07-05
# 14       179.830000         2024-06-21       2024-07-05
# 15       166.240000         2024-06-21       2024-07-05
# 16       190.630000         2024-06-21       2024-07-05
# 17       143.410000         2024-06-21       2024-07-05
# 18       168.870000         2024-06-21       2024-07-05
# 19       112.188000         2024-06-21       2024-07-05

# %%
# # some analysis of raw_data 

# df_raw_test = df.copy()
# df_raw_test.head(20)

# # filter for item id 8225846 and period 13, 14, 15
# df_raw_test = df_raw_test[df_raw_test['item_id'] == 8225846]
# df_raw_test = df_raw_test[df_raw_test['period_id'].isin([13, 14, 15])]
# df_raw_test.head(40)

df_specific_test = run_query('debug_weird_pricing.sql')
df_specific_test.head(20)

# filter to periods 13 14 15 
df_specific_test = df_specific_test[df_specific_test['period_id'].isin([13, 14, 15])]
df_specific_test.head(40)
# Out:
#      store_id  item_id        day          timezone  period_id  bb_id  \
# 329      1173  8225846 2024-12-20  America/New_York         13   3437
# 330      1173  8225846 2024-12-21  America/New_York         13   3437
# 331      1173  8225846 2024-12-22  America/New_York         13   3437
# 332      1173  8225846 2024-12-23  America/New_York         13   3437
# 333      1173  8225846 2024-12-24  America/New_York         13   3437
# 334      1173  8225846 2024-12-25  America/New_York         13   3437
# 335      1173  8225846 2024-12-26  America/New_York         13   3437
# 336      1173  8225846 2024-12-27  America/New_York         13   3437
# 337      1173  8225846 2024-12-28  America/New_York         13   3437
# 338      1173  8225846 2024-12-29  America/New_York         13   3437
# 339      1173  8225846 2024-12-30  America/New_York         13   3437
# 340      1173  8225846 2024-12-31  America/New_York         13   3437
# 341      1173  8225846 2025-01-01  America/New_York         13   3437
# 342      1235  8225846 2024-12-20  America/New_York         13   3437
# 343      1235  8225846 2024-12-21  America/New_York         13   3437
# 344      1235  8225846 2024-12-22  America/New_York         13   3437
# 345      1235  8225846 2024-12-23  America/New_York         13   3437
# 346      1235  8225846 2024-12-24  America/New_York         13   3437
# 347      1235  8225846 2024-12-25  America/New_York         13   3437
# 348      1235  8225846 2024-12-26  America/New_York         13   3437
# 349      1235  8225846 2024-12-27  America/New_York         13   3437
# 350      1235  8225846 2024-12-28  America/New_York         13   3437
# 351      1235  8225846 2024-12-29  America/New_York         13   3437
# 352      1235  8225846 2024-12-30  America/New_York         13   3437
# 353      1235  8225846 2024-12-31  America/New_York         13   3437
# 354      1235  8225846 2025-01-01  America/New_York         13   3437
# 355      1235  8225846 2025-01-02  America/New_York         13   3437
# 356      1173  8225846 2025-01-02  America/New_York         14   3437
# 357      1173  8225846 2025-01-03  America/New_York         14   3437
# 358      1173  8225846 2025-01-04  America/New_York         14   3437
# 359      1173  8225846 2025-01-05  America/New_York         14   3437
# 360      1173  8225846 2025-01-06  America/New_York         14   3437
# 361      1173  8225846 2025-01-07  America/New_York         14   3437
# 362      1173  8225846 2025-01-08  America/New_York         14   3437
# 363      1173  8225846 2025-01-09  America/New_York         14   3437
# 364      1173  8225846 2025-01-10  America/New_York         14   3437
# 365      1173  8225846 2025-01-11  America/New_York         14   3437
# 366      1173  8225846 2025-01-12  America/New_York         14   3437
# 367      1173  8225846 2025-01-13  America/New_York         14   3437
# 368      1173  8225846 2025-01-14  America/New_York         14   3437
#
#      merchant_id                                     name period_start_local  \
# 329           17  Cooked White Rice Box 7.4oz(210g) 12 Ea         2024-12-19
# 330           17  Cooked White Rice Box 7.4oz(210g) 12 Ea         2024-12-19
# 331           17  Cooked White Rice Box 7.4oz(210g) 12 Ea         2024-12-19
# 332           17  Cooked White Rice Box 7.4oz(210g) 12 Ea         2024-12-19
# 333           17  Cooked White Rice Box 7.4oz(210g) 12 Ea         2024-12-19
# 334           17  Cooked White Rice Box 7.4oz(210g) 12 Ea         2024-12-19
# 335           17  Cooked White Rice Box 7.4oz(210g) 12 Ea         2024-12-19
# 336           17  Cooked White Rice Box 7.4oz(210g) 12 Ea         2024-12-19
# 337           17  Cooked White Rice Box 7.4oz(210g) 12 Ea         2024-12-19
# 338           17  Cooked White Rice Box 7.4oz(210g) 12 Ea         2024-12-19
# 339           17  Cooked White Rice Box 7.4oz(210g) 12 Ea         2024-12-19
# 340           17  Cooked White Rice Box 7.4oz(210g) 12 Ea         2024-12-19
# 341           17  Cooked White Rice Box 7.4oz(210g) 12 Ea         2024-12-19
# 342           17  Cooked White Rice Box 7.4oz(210g) 12 Ea         2024-12-19
# 343           17  Cooked White Rice Box 7.4oz(210g) 12 Ea         2024-12-19
# 344           17  Cooked White Rice Box 7.4oz(210g) 12 Ea         2024-12-19
# 345           17  Cooked White Rice Box 7.4oz(210g) 12 Ea         2024-12-19
# 346           17  Cooked White Rice Box 7.4oz(210g) 12 Ea         2024-12-19
# 347           17  Cooked White Rice Box 7.4oz(210g) 12 Ea         2024-12-19
# 348           17  Cooked White Rice Box 7.4oz(210g) 12 Ea         2024-12-19
# 349           17  Cooked White Rice Box 7.4oz(210g) 12 Ea         2024-12-19
# 350           17  Cooked White Rice Box 7.4oz(210g) 12 Ea         2024-12-19
# 351           17  Cooked White Rice Box 7.4oz(210g) 12 Ea         2024-12-19
# 352           17  Cooked White Rice Box 7.4oz(210g) 12 Ea         2024-12-19
# 353           17  Cooked White Rice Box 7.4oz(210g) 12 Ea         2024-12-19
# 354           17  Cooked White Rice Box 7.4oz(210g) 12 Ea         2024-12-19
# 355           17  Cooked White Rice Box 7.4oz(210g) 12 Ea         2024-12-19
# 356           17  Cooked White Rice Box 7.4oz(210g) 12 Ea         2025-01-02
# 357           17  Cooked White Rice Box 7.4oz(210g) 12 Ea         2025-01-02
# 358           17  Cooked White Rice Box 7.4oz(210g) 12 Ea         2025-01-02
# 359           17  Cooked White Rice Box 7.4oz(210g) 12 Ea         2025-01-02
# 360           17  Cooked White Rice Box 7.4oz(210g) 12 Ea         2025-01-02
# 361           17  Cooked White Rice Box 7.4oz(210g) 12 Ea         2025-01-02
# 362           17  Cooked White Rice Box 7.4oz(210g) 12 Ea         2025-01-02
# 363           17  Cooked White Rice Box 7.4oz(210g) 12 Ea         2025-01-02
# 364           17  Cooked White Rice Box 7.4oz(210g) 12 Ea         2025-01-02
# 365           17  Cooked White Rice Box 7.4oz(210g) 12 Ea         2025-01-02
# 366           17  Cooked White Rice Box 7.4oz(210g) 12 Ea         2025-01-02
# 367           17  Cooked White Rice Box 7.4oz(210g) 12 Ea         2025-01-02
# 368           17  Cooked White Rice Box 7.4oz(210g) 12 Ea         2025-01-02
#
#     period_end_local promo_price scraping_regular_price  unit_cost  \
# 329       2025-01-02        None                  17.99        NaN
# 330       2025-01-02        None                  17.99        NaN
# 331       2025-01-02        None                  17.99        NaN
# 332       2025-01-02        None                  17.99        NaN
# 333       2025-01-02        None                  17.99        NaN
# 334       2025-01-02       12.99                   None        NaN
# 335       2025-01-02       12.99                   None        NaN
# 336       2025-01-02       12.99                   None        NaN
# 337       2025-01-02       12.99                   None        NaN
# 338       2025-01-02       12.99                   None        NaN
# 339       2025-01-02       12.99                   None        NaN
# 340       2025-01-02       12.99                   None        NaN
# 341       2025-01-02        None                  17.99        NaN
# 342       2025-01-02        None                  17.99        NaN
# 343       2025-01-02        None                  17.99        NaN
# 344       2025-01-02        None                  17.99        NaN
# 345       2025-01-02        None                  17.99        NaN
# 346       2025-01-02        None                  17.99        NaN
# 347       2025-01-02       12.99                   None        NaN
# 348       2025-01-02       12.99                   None        NaN
# 349       2025-01-02       12.99                   None        NaN
# 350       2025-01-02       12.99                   None        NaN
# 351       2025-01-02       12.99                   None        NaN
# 352       2025-01-02       12.99                   None        NaN
# 353       2025-01-02       12.99                   None        NaN
# 354       2025-01-02        None                  17.99        NaN
# 355       2025-01-02        None                  17.99        NaN
# 356       2025-01-16        None                  17.99        NaN
# 357       2025-01-16        None                  17.99        NaN
# 358       2025-01-16        None                  17.99        NaN
# 359       2025-01-16        None                  17.99        NaN
# 360       2025-01-16        None                  17.99        NaN
# 361       2025-01-16        None                  17.99        NaN
# 362       2025-01-16        None                  17.99        NaN
# 363       2025-01-16        None                  17.99        NaN
# 364       2025-01-16        None                  17.99        NaN
# 365       2025-01-16        None                  17.99        NaN
# 366       2025-01-16        None                  17.99        NaN
# 367       2025-01-16        None                  17.99        NaN
# 368       2025-01-16        None                  17.99        NaN
#
#      units_sold  total_basket_size  num_baskets  avg_basket_size  \
# 329        16.0            1767.76            8       220.970000
# 330         4.0             315.68            2       157.840000
# 331        10.0             618.98            6       103.163333
# 332         2.0             304.72            2       152.360000
# 333         6.0             338.32            2       169.160000
# 334        18.0            2210.10           10       221.010000
# 335        24.0            2532.08           18       140.671111
# 336        52.0            2975.38           22       135.244545
# 337        28.0            2644.32           16       165.270000
# 338        52.0            4629.18           36       128.588333
# 339        42.0            3780.16           24       157.506667
# 340        20.0            1491.64           10       149.164000
# 341        15.0            1528.53           11       138.957273
# 342         NaN                NaN            0              NaN
# 343         NaN                NaN            0              NaN
# 344         4.0             429.94            4       107.485000
# 345         NaN                NaN            0              NaN
# 346         NaN                NaN            0              NaN
# 347         2.0             291.44            2       145.720000
# 348         4.0             485.50            4       121.375000
# 349         2.0             437.24            2       218.620000
# 350         4.0             223.68            2       111.840000
# 351         8.0             609.58            6       101.596667
# 352        12.0             476.70            4       119.175000
# 353         2.0             326.42            2       163.210000
# 354         NaN                NaN            0              NaN
# 355         2.0             395.30            2       197.650000
# 356        14.0            1551.60           10       155.160000
# 357        19.0            3036.95           15       202.463333
# 358        10.0            2087.54           10       208.754000
# 359        16.0            1759.88           12       146.656667
# 360        10.0            1939.40           10       193.940000
# 361         4.0             311.96            2       155.980000
# 362         4.0             458.08            4       114.520000
# 363         6.0             580.78            6        96.796667
# 364         4.0             188.04            2        94.020000
# 365        20.0            1684.40           12       140.366667
# 366        10.0            1194.30           10       119.430000
# 367        10.0             725.24            6       120.873333
# 368        10.0            1148.78            8       143.597500
#
#      avg_selling_price  regular_price
# 329          17.765000          17.99
# 330          17.990000          17.99
# 331          16.550000          17.99
# 332          17.990000          17.99
# 333          17.990000          17.99
# 334          12.990000          17.99
# 335          11.798333          17.99
# 336          11.840000          17.99
# 337          12.154286          17.99
# 338          12.040000          17.99
# 339          13.228095          17.99
# 340          12.990000          17.99
# 341          17.870000          17.99
# 342                NaN            NaN
# 343                NaN            NaN
# 344          17.990000          17.99
# 345                NaN            NaN
# 346                NaN            NaN
# 347          12.990000          17.99
# 348          12.340000          17.99
# 349          11.690000          17.99
# 350          12.990000          17.99
# 351          12.340000          17.99
# 352          12.990000          17.99
# 353          12.990000          17.99
# 354                NaN            NaN
# 355          17.990000          17.99
# 356          17.861429          17.99
# 357          17.421579          17.99
# 358          17.270000          17.99
# 359          17.315000          17.99
# 360          17.990000          17.99
# 361          17.990000          17.99
# 362          17.990000          17.99
# 363          16.790000          17.99
# 364          17.990000          17.99
# 365          17.990000          17.99
# 366          17.990000          17.99
# 367          17.990000          17.99
# 368          17.990000          17.99

# %% [markdown]
# # data cleaning and visualizaiton

# %% [markdown]
# ## cleaning to put in analysis_staging (just populate rows and backfill non price information)

# %%
import pandas as pd
import time


def generate_missing_rows(df):
    # 1) make sure 'day' is datetime (sanity check)
    df = df.copy()
    df['day'] = pd.to_datetime(df['day'])

    # 2) find the first date each item was store in a specific store_id
    sold_mask = df['units_sold'] > 0
    first_sold = (
        df[sold_mask]
        .groupby(['item_id', 'store_id'])['day']
        .min()
        .rename('first_sold')
    )

    # 3) get the overall last date
    last_date = df['day'].max()

    # 4) build the full calendar for each (item_id, store_id)
    records = []
    for (item_id, store_id), start_date in first_sold.items():
        # daily frequency from first sold to last_date
        full_days = pd.date_range(start=start_date, end=last_date, freq='D')
        records.extend(
            {'item_id': item_id, 'store_id': store_id, 'day': d}
            for d in full_days
        )
    full_calendar = pd.DataFrame(records)

    # 5) merge original data onto the full calendar
    df_complete = full_calendar.merge(
        df,
        on=['item_id', 'store_id', 'day'],
        how='left',
        suffixes=('', '_orig')
    )

    # backfilled information handelded in a different method

    return df_complete

def fill_metadata_only(df):
    # 1) sort once so ffill/bfill makes sense
    df = df.sort_values(['item_id','store_id','day']).reset_index(drop=True)

    # 2) pick only the columns you actually want to fill
    fill_cols = ['bb_id','timezone','period_id','merchant_id','name', 'period_start_local', 'period_end_local']
    existing = [c for c in fill_cols if c in df]

    # 3) do a group‐wise ffill→bfill on those columns
    df[existing] = (
        df
        .groupby(['item_id','store_id'])[existing]
        .transform(lambda s: s.ffill().bfill())
    )

    # if units sold is NA then replace iwth 0
    df['units_sold'] = df['units_sold'].fillna(0)

    return df

# add a function to make sure our data types are correct
def correct_data_types(df):
    # DateTime conversion (handles NaT automatically)
    df['day'] = pd.to_datetime(df['day'])
    df['period_start_local'] = pd.to_datetime(df['period_start_local'])
    df['period_end_local'] = pd.to_datetime(df['period_end_local'])
    
    # Float conversions (handle NaN automatically)
    float_columns = ['regular_price', 'promo_price', 'avg_selling_price', 'unit_cost', 'avg_basket_size', 'total_basket_size', 'scraping_regular_price']
    for col in float_columns:
        df[col] = df[col].astype(float)
    
    # Integer conversions with null handling
    int_columns = ['units_sold', 'bb_id', 'period_id', 'merchant_id', 'store_id', 'item_id', 'num_baskets']
    for col in int_columns:
        # Only convert non-null values to int
        mask = df[col].notna()
        df.loc[mask, col] = df.loc[mask, col].astype(int)
        # Convert the entire column to nullable int
        df[col] = df[col].astype('Int64')
    
    return df

df_raw = df.copy()
time_start = time.time()
df_raw = generate_missing_rows(df_raw)
time_end = time.time()
print(f"Time taken for generate_missing_rows: {time_end - time_start} seconds")

time_start = time.time()
df_raw = fill_metadata_only(df_raw)
time_end = time.time()
print(f"Time taken for fill_metadata_only: {time_end - time_start} seconds")

time_start = time.time()
df_raw = correct_data_types(df_raw)
time_end = time.time()
print(f"Time taken for correct_data_types: {time_end - time_start} seconds")

time_start = time.time()
# insert this into table analysis_raw
write_to_table(df_raw, 'temporary', 'analysis_staging')
time_end = time.time()
print(f"Time taken for write_to_table: {time_end - time_start} seconds")
# Out:
# Time taken for generate_missing_rows: 10.217973947525024 seconds
# Time taken for fill_metadata_only: 7.264764308929443 seconds
# Time taken for correct_data_types: 2.011046886444092 seconds
# Time taken for write_to_table: 35.9659698009491 seconds

# %% [markdown]
# ## full cleaning for analysis_cleaned

# %%
# for situations of regular_price, promo_price, selling_price, unit_cost, if there is a null, then fill it with the last non-null value for taht item id / store_id combination 
import pandas as pd
import time
import numpy as np

def fill_null_prices_with_source(df):
    # 1) sort once
    df = df.sort_values(['item_id','store_id','day']).reset_index(drop=True)

    # 2) your lists
    fill_cols  = ['bb_id','timezone','period_id','merchant_id','name', 'period_start_local', 'period_end_local', 'on_promotion',
                  'regular_price','promo_price','avg_selling_price','unit_cost']
    track_cols = ['regular_price','promo_price','avg_selling_price','unit_cost']
    cols       = [c for c in fill_cols if c in df]

    # 3) copy originals for both tracking and thresholding
    orig = df[cols].copy()

    # 4a) do the “normal” fill for everything _except_ promo_price
    other_cols = [c for c in cols if c != 'promo_price']
    df[other_cols] = (
        df
        .groupby(['item_id','store_id'])[other_cols]
        .transform(lambda g: g.ffill().bfill())
    )

    # 4b) promo_price: only fill _within_ each (item,store,period) if ≥70% non‐null originally
    def _promo_fill(s):
        pct = s.notnull().sum() / len(s)
        if pct >= 0.7:
            return s.ffill().bfill()
        else:
            return s  # leave all as-is (no fill)
    df['promo_price'] = (
        df
        .groupby(['item_id','store_id','period_id'])['promo_price']
        .transform(_promo_fill)
    )
    # mark whether the fill or not happened as on_promotion flag 
    promo_eligible = (
        orig['promo_price']
        .notnull()
        .groupby([df['item_id'], df['store_id'], df['period_id']])
        .transform(lambda s: s.sum()/len(s) >= 0.7)
    )
    df['on_promotion'] = promo_eligible

    # 5) build mask of originally non-null (for all track_cols)
    mask = orig[track_cols].notnull().values  # shape (n,4)

    # 6) extract the “day” as numpy dates and broadcast
    days       = df['day'].values.astype('datetime64[D]')              # shape (n,)
    day_vals_2d = np.broadcast_to(days[:, None], mask.shape)           # shape (n,4)

    # 7) place src_vals where orig was non-null
    src_vals = np.full(mask.shape, np.datetime64('NaT'), dtype='datetime64[D]')
    src_vals[mask] = day_vals_2d[mask]

    # 8) make a DataFrame to run groupwise fills on those “source‐dates”
    src_df = (
        pd.DataFrame(src_vals, columns=track_cols)
          .assign(
             item_id   = df['item_id'],
             store_id  = df['store_id'],
             period_id = df['period_id']
          )
    )

    # 9a) for the non-promo columns, ffill→bfill _per item,store_ (as before)
    non_promo = [c for c in track_cols if c != 'promo_price']
    src_no_promo = (
        src_df
        .groupby(['item_id','store_id'])[non_promo]
        .transform(lambda g: g.ffill().bfill())
    )

    # 9b) for promo_price, ffill→bfill _per item,store,period_
    src_promo = (
        src_df
        .groupby(['item_id','store_id','period_id'])['promo_price']
        .transform(lambda g: g.ffill().bfill())
        .to_frame()
    )

    # 10) stitch back together
    src = pd.concat([
        src_no_promo,
        src_promo,
        src_df[['item_id','store_id']]
    ], axis=1)

    # 11) build your JSON snippets exactly as before
    snippets = []
    for col in track_cols:
        m = orig[col].isna() & src[col].notna()
        dates = src[col].dt.strftime('%Y-%m-%d').where(m, '')
        snippet = dates.str.replace(r'(.+)', f'"{col}":"\\1"', regex=True).where(m, '')
        snippets.append(snippet)

    snippet_df = pd.concat(snippets, axis=1)
    snippet_df.columns = track_cols

    # 12) join only the non-empty snippets into `{…}` or `{}` if none
    df['filled_from'] = snippet_df.apply(
        lambda row: '{' + ','.join(v for v in row if v) + '}',
        axis=1
    )

    # 13) your final Nan→0 fills
    if 'units_sold' in df:       df['units_sold']     = df['units_sold'].fillna(0)
    if 'avg_basket_size' in df:  df['avg_basket_size'] = df['avg_basket_size'].fillna(0)
    if 'total_basket_size' in df:df['total_basket_size']= df['total_basket_size'].fillna(0)
    if 'num_baskets' in df:      df['num_baskets']     = df['num_baskets'].fillna(0)

    return df

# add a function to make sure our data types are correct
def correct_data_types(df):
    # DateTime conversion (handles NaT automatically)
    df['day'] = pd.to_datetime(df['day'])
    df['period_start_local'] = pd.to_datetime(df['period_start_local'])
    df['period_end_local'] = pd.to_datetime(df['period_end_local'])

    # boolean conversion 
    df['on_promotion'] = df['on_promotion'].astype(bool)
    
    # Float conversions (handle NaN automatically)
    float_columns = ['regular_price', 'promo_price', 'avg_selling_price', 'unit_cost', 'avg_basket_size', 'total_basket_size', 'scraping_regular_price']
    for col in float_columns:
        df[col] = df[col].astype(float)
    
    # Integer conversions with null handling
    int_columns = ['units_sold', 'bb_id', 'period_id', 'merchant_id', 'store_id', 'item_id', 'num_baskets']
    for col in int_columns:
        # Only convert non-null values to int
        mask = df[col].notna()
        df.loc[mask, col] = df.loc[mask, col].astype(int)
        # Convert the entire column to nullable int
        df[col] = df[col].astype('Int64')
    
    return df

# for items that exist in a store_id on some dates but not all, we need to generate missing rows 
# for items in a store_id that exist after its first sold date populate all instances of units_sold = 0 for days that date doesnt exist in between start/now()
def generate_missing_rows(df):
    # 1) make sure 'day' is datetime (sanity check)
    df = df.copy()
    df['day'] = pd.to_datetime(df['day'])

    # 2) find the first date each item was store in a specific store_id
    sold_mask = df['units_sold'] > 0
    first_sold = (
        df[sold_mask]
        .groupby(['item_id', 'store_id'])['day']
        .min()
        .rename('first_sold')
    )

    # 3) get the overall last date
    last_date = df['day'].max()

    # 4) build the full calendar for each (item_id, store_id)
    records = []
    for (item_id, store_id), start_date in first_sold.items():
        # daily frequency from first sold to last_date
        full_days = pd.date_range(start=start_date, end=last_date, freq='D')
        records.extend(
            {'item_id': item_id, 'store_id': store_id, 'day': d}
            for d in full_days
        )
    full_calendar = pd.DataFrame(records)

    # 5) merge original data onto the full calendar
    df_complete = full_calendar.merge(
        df,
        on=['item_id', 'store_id', 'day'],
        how='left',
        suffixes=('', '_orig')
    )

    # backfilled information handelded in a different method

    return df_complete

def calculate_metrics(df):
    # active price is promo price if it on promotion, else regular price 
    df['active_price'] = np.where(df['on_promotion'],
                              df['promo_price'],
                              df['regular_price'])
    df['promo_spending'] = df['units_sold'] * df['regular_price'] / df['promo_price']
    df['revenue'] = df['units_sold'] * df['active_price']
    df['profit'] = df['units_sold'] * (df['active_price'] - df['unit_cost'])
    df['revenue_to_promo_spending_ratio'] = df['revenue'] / df['promo_spending']
    df['promo_spending (selling_price_based)'] = df['units_sold'] * df['regular_price'] / df['avg_selling_price']
    df['revenue (selling_price_based)'] = df['units_sold'] * df['avg_selling_price']
    df['profit (selling_price_based)'] = df['units_sold'] * (df['avg_selling_price'] - df['unit_cost'])
    df['revenue_to_promo_spending_ratio (selling_price_based)'] = df['revenue (selling_price_based)'] / df['promo_spending (selling_price_based)']
    
    return df

df_cleaning = df.copy()

time_start = time.time()
df_cleaning = generate_missing_rows(df_cleaning)
time_end = time.time()
print(f"Time taken to generate missing rows: {time_end - time_start} seconds")

time_start = time.time()
df_cleaned = fill_null_prices_with_source(df_cleaning)
time_end = time.time()
print(f"Time taken to fill null prices: {time_end - time_start} seconds")

time_start = time.time()
df_cleaned = correct_data_types(df_cleaned)
time_end = time.time()
print(f"Time taken to correct data types: {time_end - time_start} seconds")

time_start = time.time()
df_cleaned = calculate_metrics(df_cleaned)
time_end = time.time()
print(f"Time taken to calculate metrics: {time_end - time_start} seconds")

# order it a bit 
# reorder the columns 
df_cleaned = df_cleaned[['bb_id', 'period_id', 'period_start_local', 'period_end_local', 'on_promotion', 'merchant_id', 'store_id', 'item_id', 'name', 'day', 'timezone', 'active_price',
                         'regular_price', 'promo_price', 'avg_selling_price', 'unit_cost', 'units_sold', 
                         'total_basket_size', 'num_baskets', 'avg_basket_size', 
                         'promo_spending', 'revenue', 'profit', 'revenue_to_promo_spending_ratio', 
                         'promo_spending (selling_price_based)', 'revenue (selling_price_based)', 'profit (selling_price_based)', 'revenue_to_promo_spending_ratio (selling_price_based)', 
                         'filled_from']]
# Reset index if you want clean sequential indexing
df_cleaned = df_cleaned.reset_index(drop=True)

# Display the first 20 rows to verify
print(f"df num of rows: {df.shape[0]}, df_cleaned num of rows: {df_cleaned.shape[0]}, df_cleaned num of columns: {df_cleaned.shape[1]}")
df_cleaned.head(20) # almost 600 thousand rows
# Out:
# Time taken to generate missing rows: 10.67543911933899 seconds
# Time taken to fill null prices: 77.01239609718323 seconds
# Time taken to correct data types: 2.417123794555664 seconds
# Time taken to calculate metrics: 0.10974502563476562 seconds
# df num of rows: 1996631, df_cleaned num of rows: 4447347, df_cleaned num of columns: 29
#     bb_id  period_id period_start_local period_end_local  on_promotion  \
# 0    8902          0         2024-06-21       2024-07-05         False
# 1    8902          0         2024-06-21       2024-07-05         False
# 2    8902          0         2024-06-21       2024-07-05         False
# 3    8902          0         2024-06-21       2024-07-05         False
# 4    8902          0         2024-06-21       2024-07-05         False
# 5    8902          0         2024-06-21       2024-07-05         False
# 6    8902          0         2024-06-21       2024-07-05         False
# 7    8902          0         2024-06-21       2024-07-05         False
# 8    8902          0         2024-06-21       2024-07-05         False
# 9    8902          0         2024-06-21       2024-07-05         False
# 10   8902          0         2024-06-21       2024-07-05         False
# 11   8902          0         2024-06-21       2024-07-05         False
# 12   8902          0         2024-06-21       2024-07-05         False
# 13   8902          0         2024-06-21       2024-07-05         False
# 14   8902          0         2024-06-21       2024-07-05         False
# 15   8902          0         2024-06-21       2024-07-05         False
# 16   8902          1         2024-07-05       2024-07-19         False
# 17   8902          1         2024-07-05       2024-07-19         False
# 18   8902          1         2024-07-05       2024-07-19         False
# 19   8902          1         2024-07-05       2024-07-19         False
#
#     merchant_id  store_id  item_id                        name        day  \
# 0            17      1173  8225800  Frozen Udon 2.75lb(1.25kg) 2024-06-21
# 1            17      1173  8225800  Frozen Udon 2.75lb(1.25kg) 2024-06-22
# 2            17      1173  8225800  Frozen Udon 2.75lb(1.25kg) 2024-06-23
# 3            17      1173  8225800  Frozen Udon 2.75lb(1.25kg) 2024-06-24
# 4            17      1173  8225800  Frozen Udon 2.75lb(1.25kg) 2024-06-25
# 5            17      1173  8225800  Frozen Udon 2.75lb(1.25kg) 2024-06-26
# 6            17      1173  8225800  Frozen Udon 2.75lb(1.25kg) 2024-06-27
# 7            17      1173  8225800  Frozen Udon 2.75lb(1.25kg) 2024-06-28
# 8            17      1173  8225800  Frozen Udon 2.75lb(1.25kg) 2024-06-29
# 9            17      1173  8225800  Frozen Udon 2.75lb(1.25kg) 2024-06-30
# 10           17      1173  8225800  Frozen Udon 2.75lb(1.25kg) 2024-07-01
# 11           17      1173  8225800  Frozen Udon 2.75lb(1.25kg) 2024-07-02
# 12           17      1173  8225800  Frozen Udon 2.75lb(1.25kg) 2024-07-03
# 13           17      1173  8225800  Frozen Udon 2.75lb(1.25kg) 2024-07-04
# 14           17      1173  8225800  Frozen Udon 2.75lb(1.25kg) 2024-07-05
# 15           17      1173  8225800  Frozen Udon 2.75lb(1.25kg) 2024-07-06
# 16           17      1173  8225800  Frozen Udon 2.75lb(1.25kg) 2024-07-07
# 17           17      1173  8225800  Frozen Udon 2.75lb(1.25kg) 2024-07-08
# 18           17      1173  8225800  Frozen Udon 2.75lb(1.25kg) 2024-07-09
# 19           17      1173  8225800  Frozen Udon 2.75lb(1.25kg) 2024-07-10
#
#     ... avg_basket_size  promo_spending  revenue  profit  \
# 0   ...         151.320            <NA>     5.99  4.0744
# 1   ...         151.900            <NA>     5.99  4.0744
# 2   ...           0.000            <NA>      0.0     0.0
# 3   ...           0.000            <NA>      0.0     0.0
# 4   ...           0.000            <NA>      0.0     0.0
# 5   ...           0.000            <NA>      0.0     0.0
# 6   ...           0.000            <NA>      0.0     0.0
# 7   ...           0.000            <NA>      0.0     0.0
# 8   ...           0.000            <NA>      0.0     0.0
# 9   ...           0.000            <NA>      0.0     0.0
# 10  ...           0.000            <NA>      0.0     0.0
# 11  ...           0.000            <NA>      0.0     0.0
# 12  ...           0.000            <NA>      0.0     0.0
# 13  ...           0.000            <NA>      0.0     0.0
# 14  ...           0.000            <NA>      0.0     0.0
# 15  ...           0.000            <NA>      0.0     0.0
# 16  ...         135.970            <NA>    11.98  8.1488
# 17  ...         147.930            <NA>     5.99  4.0744
# 18  ...         162.075            <NA>    11.98  8.1488
# 19  ...           0.000            <NA>      0.0     0.0
#
#     revenue_to_promo_spending_ratio  promo_spending (selling_price_based)  \
# 0                              <NA>                              1.111317
# 1                              <NA>                              1.111317
# 2                              <NA>                                   0.0
# 3                              <NA>                                   0.0
# 4                              <NA>                                   0.0
# 5                              <NA>                                   0.0
# 6                              <NA>                                   0.0
# 7                              <NA>                                   0.0
# 8                              <NA>                                   0.0
# 9                              <NA>                                   0.0
# 10                             <NA>                                   0.0
# 11                             <NA>                                   0.0
# 12                             <NA>                                   0.0
# 13                             <NA>                                   0.0
# 14                             <NA>                                   0.0
# 15                             <NA>                                   0.0
# 16                             <NA>                              2.162455
# 17                             <NA>                                   1.0
# 18                             <NA>                                   2.0
# 19                             <NA>                                   0.0
#
#     revenue (selling_price_based)  profit (selling_price_based)  \
# 0                            5.39                        3.4744
# 1                            5.39                        3.4744
# 2                             0.0                           0.0
# 3                             0.0                           0.0
# 4                             0.0                           0.0
# 5                             0.0                           0.0
# 6                             0.0                           0.0
# 7                             0.0                           0.0
# 8                             0.0                           0.0
# 9                             0.0                           0.0
# 10                            0.0                           0.0
# 11                            0.0                           0.0
# 12                            0.0                           0.0
# 13                            0.0                           0.0
# 14                            0.0                           0.0
# 15                            0.0                           0.0
# 16                          11.08                        7.2488
# 17                           5.99                        4.0744
# 18                          11.98                        8.1488
# 19                            0.0                           0.0
#
#     revenue_to_promo_spending_ratio (selling_price_based)  \
# 0                                              4.8501
# 1                                              4.8501
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                           5.123806
# 17                                               5.99
# 18                                               5.99
# 19                                                NaN
#
#                                           filled_from
# 0                          {"unit_cost":"2025-06-02"}
# 1                          {"unit_cost":"2025-06-02"}
# 2   {"regular_price":"2024-06-22","avg_selling_pri...
# 3   {"regular_price":"2024-06-22","avg_selling_pri...
# 4   {"regular_price":"2024-06-22","avg_selling_pri...
# 5   {"regular_price":"2024-06-22","avg_selling_pri...
# 6   {"regular_price":"2024-06-22","avg_selling_pri...
# 7   {"regular_price":"2024-06-22","avg_selling_pri...
# 8   {"regular_price":"2024-06-22","avg_selling_pri...
# 9   {"regular_price":"2024-06-22","avg_selling_pri...
# 10  {"regular_price":"2024-06-22","avg_selling_pri...
# 11  {"regular_price":"2024-06-22","avg_selling_pri...
# 12  {"regular_price":"2024-06-22","avg_selling_pri...
# 13  {"regular_price":"2024-06-22","avg_selling_pri...
# 14  {"regular_price":"2024-06-22","avg_selling_pri...
# 15  {"regular_price":"2024-06-22","avg_selling_pri...
# 16                         {"unit_cost":"2025-06-02"}
# 17                         {"unit_cost":"2025-06-02"}
# 18                         {"unit_cost":"2025-06-02"}
# 19  {"regular_price":"2024-07-09","avg_selling_pri...
#
# [20 rows x 29 columns]

# %%
# write into table 
time_start = time.time()
write_to_table(df_cleaned, 'temporary', 'analysis_cleaned')
time_end = time.time()
print(f"Time taken for write_to_table: {time_end - time_start} seconds")
# Out:
# Time taken for write_to_table: 65.10539412498474 seconds

# %%
# tion to calculate revenue per item per period, profit per item per period, promo spending per item per period based on these metrics 

def aggregate_data_by_period(df):
    df = (
        df
        .groupby(
            ['period_id', 'store_id', 'item_id'],
            as_index=False
        )
        .agg(
            avg_active_price    = ('active_price', 'mean'),
            avg_regular_price   = ('regular_price', 'mean'), 
            avg_promo_price      = ('promo_price',    'mean'),
            avg_selling_price   = ('avg_selling_price', 'mean'),
            avg_unit_cost       = ('unit_cost',     'mean'),
            total_units_sold    = ('units_sold',    'sum'),
            avg_basket_size     = ('avg_basket_size','sum'),
            total_num_baskets   = ('num_baskets', 'sum'),
            total_promo_spending = ('promo_spending','sum'),
            total_revenue       = ('revenue', 'sum'),
            total_profit        = ('profit', 'sum'),
            total_promo_spending_selling_price_based = ('promo_spending (selling_price_based)', 'sum'),
            total_revenue_selling_price_based = ('revenue (selling_price_based)', 'sum'),
            total_profit_selling_price_based = ('profit (selling_price_based)', 'sum'),
            # we are not going to aggregate filled from data here because that was row level 
            # non aggregations here
            name = ('name', 'first'),
            bb_id = ('bb_id', 'first'),
            merchant_id = ('merchant_id', 'first'),
            timezone = ('timezone', 'first'),
            period_start_local = ('period_start_local', 'first'),
            period_end_local = ('period_end_local', 'first')

            
        )
    )
    df['weighted_average_promo_spending_ratio'] = df['total_promo_spending'] / df['total_revenue']
    df['weighted_average_promo_spending_ratio_selling_price_based'] = df['total_promo_spending_selling_price_based'] / df['total_revenue_selling_price_based']
    return df

df_analyzed = aggregate_data_by_period(df_cleaned)

# # order by total_profit descending
df_analyzed = df_analyzed.sort_values('total_profit', ascending=False)
df_analyzed.head(20)


# df_test = df.copy()
# df_test = df_test[(df_test['item_id'] == 8229321)]
# df_test = generate_missing_rows(df_test)
# df_test = fill_null_prices_with_source(df_test)
# df_test = correct_data_types(df_test)
# df_test = calculate_metrics(df_test)
# # only keep 
# # filter out where promo_price is not nan

# df_test.head(20)

# filter for 8226315 item_id and periods 22 and 23
# Out:
#         period_id  store_id  item_id  avg_active_price  avg_regular_price  \
# 5225            1      1173  8226315         14.990000          14.990000
# 20322           4      1173  8225846         15.990000          15.990000
# 72158          13      1173  8226147         45.990000          45.990000
# 92121          16      1173  8228198        283.930000         283.930000
# 20311           4      1173  8225835         18.990000          18.990000
# 20312           4      1173  8225836          6.790000           6.790000
# 60430          11      1173  8225824         14.990000          14.990000
# 60745          11      1173  8226238         14.990000          14.990000
# 68990          12      1173  8232131         12.990000          22.990000
# 26390           5      1173  8225846         15.990000          15.990000
# 15006           3      1173  8225824         12.990000          12.990000
# 50424           9      1173  8225846         17.990000          17.990000
# 20289           4      1173  8225811          6.990000           6.990000
# 26667           5      1173  8226238         14.990000          14.990000
# 15036           3      1173  8225858          8.990000           8.990000
# 71925          13      1173  8225846         17.990000          17.990000
# 90436          16      1173  8225846         13.990000          13.990000
# 84260          15      1173  8225858          9.990000           9.990000
# 115904         20      1173  8226670         15.990000          15.775714
# 122152         21      1173  8226670         17.847143          17.847143
#
#         avg_promo_price  avg_selling_price  avg_unit_cost  total_units_sold  \
# 5225                NaN           9.309523         6.0847               420
# 20322             12.99          13.750723        11.0000               570
# 72158             29.99          32.575281        24.9974               128
# 92121             39.99          38.104286        17.6410                10
# 20311             13.99          13.457053         9.6864               285
# 20312              5.22           4.464164         3.5750               820
# 60430             10.99          11.109415         7.6900               354
# 60745             10.99          10.867881         6.6094               290
# 68990             12.99          11.972066         8.7500               749
# 26390             12.99          12.259917        11.0000               474
# 15006               NaN           7.076044         7.6900               406
# 50424             15.99          16.660768        11.0000               288
# 20289              3.99           4.872031         3.4595               556
# 26667              9.99           9.482030         6.6094               231
# 15036               NaN           4.816643         4.6738               448
# 71925             12.99          14.414706        11.0000               276
# 90436             13.99          14.148403        11.0000               644
# 84260              4.99           6.009152         4.6738               356
# 115904            15.99          14.450883         9.5000               282
# 122152              NaN          16.613018         9.5000               213
#
#         avg_basket_size  ...  total_revenue_selling_price_based  \
# 5225        1438.082593  ...                             2647.5
# 20322       2211.679041  ...                             7452.4
# 72158        890.306000  ...                            3623.12
# 92121        658.147500  ...                              363.9
# 20311       1759.167015  ...                            3710.05
# 20312       2103.843768  ...                            3164.95
# 60430       2259.164543  ...                            3670.06
# 60745       1815.188512  ...                             2991.5
# 68990       1765.486021  ...                            8695.91
# 26390       2028.412436  ...                             5771.2
# 15006       1961.092203  ...                            2643.35
# 50424       2238.410016  ...                            4755.12
# 20289       1910.202853  ...                            2093.99
# 26667       2095.158527  ...                            2089.89
# 15036       2077.189966  ...                            2004.37
# 71925       2295.244402  ...                            3642.44
# 90436       1805.579710  ...                            8777.76
# 84260       1414.524949  ...                            1894.44
# 115904      2070.736193  ...                            4124.33
# 122152      1242.375958  ...                            3371.07
#
#         total_profit_selling_price_based  \
# 5225                              91.926
# 20322                             1182.4
# 72158                           423.4528
# 92121                             187.49
# 20311                            949.426
# 20312                             233.45
# 60430                              947.8
# 60745                           1074.774
# 68990                            2142.16
# 26390                              557.2
# 15006                            -478.79
# 50424                            1587.12
# 20289                            170.508
# 26667                           563.1186
# 15036                           -89.4924
# 71925                             606.44
# 90436                            1693.76
# 84260                           230.5672
# 115904                           1445.33
# 122152                           1347.57
#
#                                                      name    bb_id  \
# 5225                     Shin Ramen 4.23oz(120g) 10 Packs     1764
# 20322             Cooked White Rice Box 7.4oz(210g) 12 Ea     3437
# 72158                 Korean Rice Suhyang Rice 22lb(10kg)     7689
# 92121                 Coarse Red Pepper Powder 2.2lb(1kg)     7698
# 20311                 Shin Ramen 16Pk Box 4.23OZ(120G)*16     1801
# 20312    Bibim Men Spicy Cold Noodles 4.58oz(130g) 5 Pack     7077
# 60430            Beef Bone Soup 16.9 fl.oz(500ml) 6 Packs     4070
# 60745              Cooked White Rice 7.4oz(210g) 12 Packs     3996
# 68990                          Tokyo Banana 1.06LB (480G)  2393886
# 26390             Cooked White Rice Box 7.4oz(210g) 12 Ea     3437
# 15006            Beef Bone Soup 16.9 fl.oz(500ml) 6 Packs     4070
# 50424             Cooked White Rice Box 7.4oz(210g) 12 Ea     3437
# 20289                   Neoguri Spicy 4.2oz(120g) 4 Packs     1724
# 26667              Cooked White Rice 7.4oz(210g) 12 Packs     3996
# 15036   Carbo Hot Chicken Flavor Ramen 4.5oz(130g) 5 P...     6785
# 71925             Cooked White Rice Box 7.4oz(210g) 12 Ea     3437
# 90436             Cooked White Rice Box 7.4oz(210g) 12 Ea     3437
# 84260   Carbo Hot Chicken Flavor Ramen 4.5oz(130g) 5 P...     6785
# 115904                             White Rice 15lb(6.8kg)     3283
# 122152                             White Rice 15lb(6.8kg)     3283
#
#         merchant_id          timezone  period_start_local    period_end_local  \
# 5225             17  America/New_York 2024-07-05 00:00:00 2024-07-19 00:00:00
# 20322            17  America/New_York 2024-08-16 00:00:00 2024-08-30 00:00:00
# 72158            17  America/New_York 2024-12-19 23:00:00 2025-01-02 23:00:00
# 92121            17  America/New_York 2025-01-30 23:00:00 2025-02-13 23:00:00
# 20311            17  America/New_York 2024-08-16 00:00:00 2024-08-30 00:00:00
# 20312            17  America/New_York 2024-08-16 00:00:00 2024-08-30 00:00:00
# 60430            17  America/New_York 2024-11-21 23:00:00 2024-12-05 23:00:00
# 60745            17  America/New_York 2024-11-21 23:00:00 2024-12-05 23:00:00
# 68990            17  America/New_York 2024-12-05 23:00:00 2024-12-19 23:00:00
# 26390            17  America/New_York 2024-08-30 00:00:00 2024-09-13 00:00:00
# 15006            17  America/New_York 2024-08-02 00:00:00 2024-08-16 00:00:00
# 50424            17  America/New_York 2024-10-25 00:00:00 2024-11-07 23:00:00
# 20289            17  America/New_York 2024-08-16 00:00:00 2024-08-30 00:00:00
# 26667            17  America/New_York 2024-08-30 00:00:00 2024-09-13 00:00:00
# 15036            17  America/New_York 2024-08-02 00:00:00 2024-08-16 00:00:00
# 71925            17  America/New_York 2024-12-19 23:00:00 2025-01-02 23:00:00
# 90436            17  America/New_York 2025-01-30 23:00:00 2025-02-13 23:00:00
# 84260            17  America/New_York 2025-01-16 23:00:00 2025-01-30 23:00:00
# 115904           17  America/New_York 2025-03-28 00:00:00 2025-04-11 00:00:00
# 122152           17  America/New_York 2025-04-11 00:00:00 2025-04-25 00:00:00
#
#         weighted_average_promo_spending_ratio  \
# 5225                                      0.0
# 20322                                0.049971
# 72158                                0.024487
# 92121                                0.010003
# 20311                                0.022071
# 20312                                0.115942
# 60430                                0.051922
# 60745                                0.046123
# 68990                                0.164354
# 26390                                0.009907
# 15006                                     0.0
# 50424                                0.032572
# 20289                                0.029751
# 26667                                0.033367
# 15036                                     0.0
# 71925                                0.052995
# 90436                                 0.07148
# 84260                                0.112585
# 115904                               0.062192
# 122152                                    0.0
#
#         weighted_average_promo_spending_ratio_selling_price_based
# 5225                                             0.382207
# 20322                                            0.093789
# 72158                                            0.057602
# 92121                                            0.215304
# 20311                                            0.112443
# 20312                                            0.461943
# 60430                                            0.141443
# 60745                                            0.141972
# 68990                                            0.172554
# 26390                                            0.108278
# 15006                                             0.30782
# 50424                                            0.066227
# 20289                                            0.495075
# 26667                                            0.184288
# 15036                                             0.45084
# 71925                                            0.105008
# 90436                                            0.075532
# 84260                                            0.369239
# 115904                                           0.074415
# 122152                                           0.071854
#
# [20 rows x 25 columns]

# %%
# quick analysis of hmart file
file_path = "/Users/kappavi/Documents/Avi's Documents /Work/data/hmart/new_daily list.csv"
# file_path = "/Users/kappavi/Documents/Avi's Documents /Work/data/hmart/Daily sales list copy.csv"
# file_path = "/Users/kappavi/Documents/Avi's Documents /Work/data/hmart/Report_transformed.csv"
# load csv into df
df_hmart_debug = pd.read_csv(file_path)
df_hmart_debug.head()

print(df_hmart_debug.dtypes)

# filter based on last change date of 2025-02-19 and ID SKU 111
# df_hmart_debug = df_hmart_debug[df_hmart_debug['UPC'] == 3114602398]
# filter based on name containing "Shin Ramen"
df_hmart_debug = df_hmart_debug[df_hmart_debug['SKU Name'].str.contains('Shin Ramen 4.23oz')]
# date should be between 2/17 and 2/20
df_hmart_debug = df_hmart_debug[(df_hmart_debug['Creation Date'] >= '2025-02-17') & (df_hmart_debug['Creation Date'] <= '2025-02-21')]
df_hmart_debug = df_hmart_debug[['SKU Name', 'Creation Date', 'Last Change Date', 'SKU Value']]
# order by last change date
df_hmart_debug = df_hmart_debug.sort_values('Creation Date')

df_hmart_debug.head(20)

df_hmart_debug_2 = pd.read_csv(file_path)
# want to group by SKU Name, and then see the creation date and last change date 
# order by creation date
df_hmart_debug_2 = df_hmart_debug_2.sort_values('Creation Date')
# show sku name, sku value, creation date
df_hmart_debug_2 = df_hmart_debug_2[['SKU Name', 'SKU Value', 'Creation Date']]
# find SKU value of 14.13
df_hmart_debug_2 = df_hmart_debug_2[df_hmart_debug_2['SKU Value'] == 14.13]

df_hmart_debug_2.head(20)
# Out:
# /var/folders/hx/4z3d1xsd4kn2grfhp_cvzcm80000gn/T/ipykernel_58731/4210629795.py:6: DtypeWarning: Columns (14,29,30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_hmart_debug = pd.read_csv(file_path)
# Origin                             object
# Order                              object
# Sequence                            int64
# Creation Date                      object
# Courrier                           object
# Estimate Delivery Date             object
# Delivery Deadline                  object
# Status                             object
# Last Change Date                   object
# UtmMedium                          object
# Quantity_SKU                        int64
# ID_SKU                              int64
# Category Ids Sku                   object
# Reference Code                      int64
# UPC                                object
# SKU Name                           object
# SKU Value                         float64
# SKU Selling Price                 float64
# SKU Total Price                   float64
# SKU Path                           object
# Item Attachments                  float64
# List Id                           float64
# List Type Name                    float64
# Service (Price/ Selling Price)    float64
# Shipping List Price               float64
# Shipping Value                    float64
# Total Value                       float64
# Discounts Totals                  float64
# Discounts Names                    object
# Call Center Email                  object
# Call Center Code                   object
# Tracking Number                    object
# Host                               object
# Currency Code                      object
# Taxes                             float64
# Invoice Numbers                    object
# Country                            object
# Input Invoices Numbers             object
# Output Invoices Numbers            object
# Status raw value (temporary)       object
# Cancellation Data                 float64
# dtype: object
# /var/folders/hx/4z3d1xsd4kn2grfhp_cvzcm80000gn/T/ipykernel_58731/4210629795.py:23: DtypeWarning: Columns (14,29,30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_hmart_debug_2 = pd.read_csv(file_path)
# Empty DataFrame
# Columns: [SKU Name, SKU Value, Creation Date]
# Index: []

# %%
# lets do some manual analysis here

# lets compare for example period 25 and 24 
# lets find top 10 revenue grossing items for period 25 and 24 
df_24 = df_analyzed[df_analyzed['period_id'] == 24]
df_25 = df_analyzed[df_analyzed['period_id'] == 25]

df_24.head(20)
df_25.head(20)

# lets find the top 10 revenue grossing items for period 25 and 24 
df_24_top_10 = df_24.sort_values('total_revenue', ascending=False).head(10)
df_25_top_10 = df_25.sort_values('total_revenue', ascending=False).head(10)

df_24_top_10.head(20)
df_25_top_10.head(20)

# lets find top 10 items based on revenue_to_promo_spending_ratio for period 25 and 24 
df_24_top_10_revenue_to_promo_spending_ratio = df_24.sort_values('weighted_average_promo_spending_ratio', ascending=False).head(10)
df_25_top_10_revenue_to_promo_spending_ratio = df_25.sort_values('weighted_average_promo_spending_ratio', ascending=False).head(10)

df_24_top_10_revenue_to_promo_spending_ratio.head(20)
df_25_top_10_revenue_to_promo_spending_ratio.head(20)

# lets find top 10 items that have greatest units sold 
df_24_top_10_units_sold = df_24.sort_values('total_units_sold', ascending=False).head(10)
df_25_top_10_units_sold = df_25.sort_values('total_units_sold', ascending=False).head(10)

df_24_top_10_units_sold.head(20)
df_25_top_10_units_sold.head(20)

# create a df that melts this based on period
# common: bb_id, period_id, merchant_id, store_id, item_id, name
# 24: revenue, profit, promo_spending, total_units_sold, revenue_to_promo_spending_ratio
# 25: revenue, profit, promo_spending, total_units_sold, revenue_to_promo_spending_ratio
keys    = ['bb_id','merchant_id','store_id','item_id','name']
metrics = [
    'total_revenue',
    'total_profit',
    'total_promo_spending',
    'total_units_sold',
    'weighted_average_promo_spending_ratio'
]

# slice each period down to keys + metrics
df24 = df_24[keys + metrics]
df25 = df_25[keys + metrics]

# now merge them side-by-side, adding suffixes for period 24 vs 25
df_compare = pd.merge(
    df24,
    df25,
    on=keys,
    how='inner',
    suffixes=('_24','_25')
)
# add a metric for lift from 24 to 25 
df_compare['lift'] = df_compare['total_revenue_25'] / df_compare['total_revenue_24']
# order by lift
df_compare = df_compare.sort_values('lift', ascending=False)
df_compare.head(20)
# Out:
#         bb_id  merchant_id  store_id  item_id  \
# 3315     7625           17      1235  8229779
# 2961     2356           17      1235  8228777
# 2947   800180           17      1235  8228744
# 2948  2428324           17      1235  8228747
# 2950     7134           17      1235  8228783
# 2952     3673           17      1235  8228787
# 2953     8024           17      1235  8228750
# 2954     3974           17      1235  8228794
# 2955     7791           17      1235  8228797
# 2956     7030           17      1235  8228798
# 2957     4378           17      1235  8228799
# 2958  2393467           17      1235  8228781
# 2959     3674           17      1235  8228780
# 2962     2182           17      1235  8228756
# 2977     3487           17      1235  8228644
# 2963     2767           17      1235  8228758
# 2965     7801           17      1235  8228764
# 2966     7156           17      1235  8228767
# 2967     7702           17      1235  8228768
# 2968    44212           17      1235  8228769
#
#                                                    name  total_revenue_24  \
# 3315    Coarse Red Pepper Powder 3lb(1.36kg) for Kimchi               0.0
# 2961                        Dark Chocolate 8.82oz(250g)               0.0
# 2947  Matcha Green Tea Traditional Tea Bags 0.05oz(1...               0.0
# 2948  Hong Kong Style Milk Tea 8.45 fl.oz(250ml) X 6...               0.0
# 2950     European Premium Roll Type Cookies 3.7oz(105g)               0.0
# 2952                   Black Milk Tea 11.8 fl.oz(350ml)               0.0
# 2953  Konjac Jelly Collagen Watermelon10Pk 50.70fl(1...               0.0
# 2954                      Nature Black Rice 2lb (0.9kg)               0.0
# 2955                         Hallabong Tea 2.09lb(950g)               0.0
# 2956                    Choco Boy Big Size 5.07oz(144g)               0.0
# 2957  [H Mart Exclusive] Canned Bai Top Shell Whelk ...               0.0
# 2958  Kukkia Catre Whipped Chocolate Cream Sandwiche...               0.0
# 2959    Mugicha Barley Tea Bags 54 Sachets 15.2oz(432g)               0.0
# 2962                             Hello Panda Strawberry               0.0
# 2977                                     Pork Sung 4 OZ               0.0
# 2963                    Black Bean Sauce 17.63OZ (500G)               0.0
# 2965               Strawberry Mini Wafers 3.53oz (100g)               0.0
# 2966                                 Rubber Gloves (XL)               0.0
# 2967                   Aloe Vera 93% Soothing Gel 300ml               0.0
# 2968                      Crispy Roll (Original) 3.52oz               0.0
#
#       total_profit_24  total_promo_spending_24  total_units_sold_24  \
# 3315              0.0                      0.0                    0
# 2961              0.0                      0.0                    1
# 2947              0.0                      0.0                    0
# 2948              0.0                      0.0                    1
# 2950              0.0                      0.0                    0
# 2952              0.0                      0.0                    0
# 2953              0.0                      0.0                    0
# 2954              0.0                      0.0                    0
# 2955              0.0                      0.0                    0
# 2956              0.0                      0.0                    0
# 2957              0.0                      0.0                    0
# 2958              0.0                      0.0                    0
# 2959              0.0                      0.0                    0
# 2962              0.0                      0.0                    0
# 2977              0.0                      0.0                    0
# 2963              0.0                      0.0                    0
# 2965              0.0                      0.0                    1
# 2966              0.0                      0.0                    0
# 2967              0.0                      0.0                    0
# 2968              0.0                      0.0                    0
#
#       weighted_average_promo_spending_ratio_24  total_revenue_25  \
# 3315                                       NaN               0.0
# 2961                                       NaN               0.0
# 2947                                       NaN               0.0
# 2948                                       NaN               0.0
# 2950                                       NaN               0.0
# 2952                                       NaN               0.0
# 2953                                       NaN               0.0
# 2954                                       NaN               0.0
# 2955                                       NaN               0.0
# 2956                                       NaN               0.0
# 2957                                       NaN               0.0
# 2958                                       NaN               0.0
# 2959                                       NaN               0.0
# 2962                                       NaN               0.0
# 2977                                       NaN               0.0
# 2963                                       NaN               0.0
# 2965                                       NaN               0.0
# 2966                                       NaN               0.0
# 2967                                       NaN               0.0
# 2968                                       NaN               0.0
#
#       total_profit_25  total_promo_spending_25  total_units_sold_25  \
# 3315              0.0                      0.0                    0
# 2961              0.0                      0.0                    0
# 2947              0.0                      0.0                    0
# 2948              0.0                      0.0                    1
# 2950              0.0                      0.0                    0
# 2952              0.0                      0.0                    0
# 2953              0.0                      0.0                    0
# 2954              0.0                      0.0                    0
# 2955              0.0                      0.0                    0
# 2956              0.0                      0.0                    0
# 2957              0.0                      0.0                    0
# 2958              0.0                      0.0                    0
# 2959              0.0                      0.0                    4
# 2962              0.0                      0.0                    0
# 2977              0.0                      0.0                    0
# 2963              0.0                      0.0                    0
# 2965              0.0                      0.0                    0
# 2966              0.0                      0.0                    0
# 2967              0.0                      0.0                    0
# 2968              0.0                      0.0                    0
#
#       weighted_average_promo_spending_ratio_25  lift
# 3315                                       NaN   NaN
# 2961                                       NaN   NaN
# 2947                                       NaN   NaN
# 2948                                       NaN   NaN
# 2950                                       NaN   NaN
# 2952                                       NaN   NaN
# 2953                                       NaN   NaN
# 2954                                       NaN   NaN
# 2955                                       NaN   NaN
# 2956                                       NaN   NaN
# 2957                                       NaN   NaN
# 2958                                       NaN   NaN
# 2959                                       NaN   NaN
# 2962                                       NaN   NaN
# 2977                                       NaN   NaN
# 2963                                       NaN   NaN
# 2965                                       NaN   NaN
# 2966                                       NaN   NaN
# 2967                                       NaN   NaN
# 2968                                       NaN   NaN

# %%
import pandas as pd
import plotly.express as px
from IPython.display import display
import ipywidgets as widgets
import nbformat
print(nbformat.__version__)  # should be ≥ 4.2.0

# Ensure `df_compare` is defined in your notebook's environment
# df_compare = pd.merge(...)

# Define which metrics to explore
metrics = [
    'revenue_24', 'revenue_25',
    'profit_24', 'profit_25',
    'total_promo_spending_24', 'total_promo_spending_25',
    'total_units_sold_24', 'total_units_sold_25',
    'revenue_to_promo_spending_ratio_24', 'revenue_to_promo_spending_ratio_25',
    'lift'
]

# Widgets for selecting metric and number of top items
metric_dropdown = widgets.Dropdown(options=metrics, description='Metric:')
top_n_slider = widgets.IntSlider(value=10, min=1, max=50, step=1, description='Top N:')

# Update function to redraw chart based on selections
def update_plot(metric, top_n):
    # Select top N rows by chosen metric
    df_plot = df_compare.nlargest(top_n, metric)
    # Create bar chart
    fig = px.bar(
        df_plot,
        x='name',
        y=metric,
        title=f'Top {top_n} Items by {metric.replace("_", " ")}',
        labels={metric: metric}
    )
    fig.update_layout(
        xaxis_tickangle=-45,
        yaxis_title=metric
    )
    fig.show()

# Assemble interactive dashboard
dashboard = widgets.interactive(update_plot, metric=metric_dropdown, top_n=top_n_slider)

display(dashboard)
# Out:
# 5.10.4
# interactive(children=(Dropdown(description='Metric:', options=('revenue_24', 'revenue_25', 'profit_24', 'profi…

# %% [markdown]
# # trying some even greater analysis

# %%
import ipywidgets as widgets
from IPython.display import display, clear_output
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import numpy as np
import pandas as pd
import seaborn as sns
from datetime import datetime

# Set matplotlib style
plt.style.use('seaborn-v0_8')
sns.set_palette("husl")

class PriceTrackingDashboard:
    def __init__(self, df_analyzed):
        self.df_analyzed = df_analyzed
        self.filtered_data = None
        self.analysis_data = None
        
        # Get unique values for filters
        self.periods = sorted(df_analyzed['period_id'].unique())
        self.items = sorted(df_analyzed['name'].unique())
        self.stores = sorted(df_analyzed['store_id'].unique())
        self.merchants = sorted(df_analyzed['merchant_id'].unique())
        
        # Create widgets
        self.create_widgets()
        
        # Create output widget for plots
        self.output = widgets.Output()
        
        # Set up interactions
        self.setup_interactions()
        
        # Initial update
        self.update_dashboard()
    
    def create_widgets(self):
        """Create all interactive widgets"""
        
        # Period selection
        self.current_period = widgets.Dropdown(
            options=[(f'Period {p}', p) for p in self.periods],
            value=self.periods[-1] if self.periods else None,
            description='Current Period:',
            style={'description_width': 'initial'},
            layout=widgets.Layout(width='250px')
        )
        
        self.comparison_period = widgets.Dropdown(
            options=[(f'Period {p}', p) for p in self.periods],
            value=self.periods[-2] if len(self.periods) > 1 else (self.periods[0] if self.periods else None),
            description='Comparison Period:',
            style={'description_width': 'initial'},
            layout=widgets.Layout(width='250px')
        )
        
        # Filters
        self.item_filter = widgets.SelectMultiple(
            options=self.items,
            value=self.items[:10] if len(self.items) > 10 else self.items,
            description='Items:',
            style={'description_width': 'initial'},
            layout=widgets.Layout(width='300px', height='120px')
        )
        
        self.store_filter = widgets.SelectMultiple(
            options=[(f'Store {s}', s) for s in self.stores],
            value=self.stores,
            description='Stores:',
            style={'description_width': 'initial'},
            layout=widgets.Layout(width='250px', height='120px')
        )
        
        self.merchant_filter = widgets.SelectMultiple(
            options=[(f'Merchant {m}', m) for m in self.merchants],
            value=self.merchants,
            description='Merchants:',
            style={'description_width': 'initial'},
            layout=widgets.Layout(width='250px', height='120px')
        )
        
        # Sort and display options
        self.sort_by = widgets.Dropdown(
            options=[
                ('Revenue (Highest)', 'revenue_desc'),
                ('Revenue (Lowest)', 'revenue_asc'),
                ('Profit (Highest)', 'profit_desc'),
                ('Profit (Lowest)', 'profit_asc'),
                ('Revenue Variance', 'revenue_variance_desc'),
                ('Profit Variance', 'profit_variance_desc'),
                ('Sales Lift', 'sales_lift_desc')
            ],
            value='revenue_desc',
            description='Sort By:',
            style={'description_width': 'initial'},
            layout=widgets.Layout(width='250px')
        )
        
        self.top_n = widgets.IntSlider(
            value=20,
            min=5,
            max=50,
            step=5,
            description='Top N Items:',
            style={'description_width': 'initial'},
            layout=widgets.Layout(width='300px')
        )
        
        # Chart selection
        self.chart_type = widgets.Dropdown(
            options=[
                ('Revenue vs Profit', 'revenue_profit'),
                ('Variance Analysis', 'variance'),
                ('Sales Lift', 'lift'),
                ('Performance Matrix', 'matrix'),
                ('Summary Table', 'table')
            ],
            value='revenue_profit',
            description='Chart Type:',
            style={'description_width': 'initial'},
            layout=widgets.Layout(width='250px')
        )
        
        # Update button
        self.update_button = widgets.Button(
            description='Update Dashboard',
            button_style='primary',
            layout=widgets.Layout(width='200px')
        )
    
    def setup_interactions(self):
        """Set up widget interactions"""
        self.update_button.on_click(lambda b: self.update_dashboard())
        
        # Auto-update on certain widget changes
        for widget in [self.current_period, self.comparison_period, self.chart_type]:
            widget.observe(lambda change: self.update_dashboard(), names='value')
    
    def calculate_variance_and_lift(self, df, current_period, comparison_period):
        """Calculate variance and lift between periods"""
        current_data = df[df['period_id'] == current_period].copy()
        comparison_data = df[df['period_id'] == comparison_period].copy()
        
        # Merge on item/store level
        merged = current_data.merge(
            comparison_data[['bb_id', 'store_id', 'item_id', 'revenue', 'profit', 'total_units_sold']], 
            on=['bb_id', 'store_id', 'item_id'], 
            how='left', 
            suffixes=('_current', '_comparison')
        )
        
        # Fill NaN values
        merged = merged.fillna(0)
        
        # Calculate variance and lift
        merged['revenue_variance'] = merged['revenue_current'] - merged['revenue_comparison']
        merged['profit_variance'] = merged['profit_current'] - merged['profit_comparison']
        merged['revenue_variance_pct'] = np.where(merged['revenue_comparison'] > 0, 
                                                (merged['revenue_variance'] / merged['revenue_comparison']) * 100, 0)
        merged['profit_variance_pct'] = np.where(merged['profit_comparison'] > 0, 
                                               (merged['profit_variance'] / merged['profit_comparison']) * 100, 0)
        
        # Calculate lift (sales ratio)
        merged['sales_lift'] = np.where(merged['total_units_sold_comparison'] > 0, 
                                       merged['total_units_sold_current'] / merged['total_units_sold_comparison'], 0)
        
        return merged
    
    def filter_and_sort_data(self):
        """Filter and sort data based on widget values"""
        # Filter data
        filtered_df = self.df_analyzed.copy()
        
        if self.item_filter.value:
            filtered_df = filtered_df[filtered_df['name'].isin(self.item_filter.value)]
        if self.store_filter.value:
            filtered_df = filtered_df[filtered_df['store_id'].isin(self.store_filter.value)]
        if self.merchant_filter.value:
            filtered_df = filtered_df[filtered_df['merchant_id'].isin(self.merchant_filter.value)]
        
        # Calculate variance and lift
        if self.current_period.value and self.comparison_period.value:
            analysis_df = self.calculate_variance_and_lift(filtered_df, self.current_period.value, self.comparison_period.value)
        else:
            analysis_df = filtered_df[filtered_df['period_id'] == self.current_period.value].copy()
            analysis_df['revenue_variance'] = 0
            analysis_df['profit_variance'] = 0
            analysis_df['sales_lift'] = 1
        
        # Sort data
        sort_mapping = {
            'revenue_desc': ('revenue_current', False),
            'revenue_asc': ('revenue_current', True),
            'profit_desc': ('profit_current', False),
            'profit_asc': ('profit_current', True),
            'revenue_variance_desc': ('revenue_variance', False),
            'profit_variance_desc': ('profit_variance', False),
            'sales_lift_desc': ('sales_lift', False)
        }
        
        if self.sort_by.value in sort_mapping:
            sort_col, ascending = sort_mapping[self.sort_by.value]
            analysis_df = analysis_df.sort_values(sort_col, ascending=ascending)
        
        # Limit to top N
        analysis_df = analysis_df.head(self.top_n.value)
        
        self.filtered_data = filtered_df
        self.analysis_data = analysis_df
        
        return analysis_df
    
    def create_summary_stats(self, analysis_df):
        """Create summary statistics"""
        total_revenue_current = analysis_df['revenue_current'].sum()
        total_profit_current = analysis_df['profit_current'].sum()
        total_revenue_variance = analysis_df['revenue_variance'].sum()
        total_profit_variance = analysis_df['profit_variance'].sum()
        avg_lift = analysis_df['sales_lift'].mean()
        
        print("="*80)
        print("DASHBOARD SUMMARY")
        print("="*80)
        print(f"📊 Total Revenue (Current):     ${total_revenue_current:,.0f}")
        print(f"💰 Total Profit (Current):      ${total_profit_current:,.0f}")
        print(f"📈 Revenue Variance:            ${total_revenue_variance:,.0f}")
        print(f"📈 Profit Variance:             ${total_profit_variance:,.0f}")
        print(f"🚀 Average Sales Lift:          {avg_lift:.2f}x")
        print(f"📦 Number of Items Analyzed:    {len(analysis_df)}")
        print("="*80)
    
    def plot_revenue_profit(self, analysis_df):
        """Create revenue vs profit chart"""
        fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
        
        # Revenue and Profit Bar Chart
        items = analysis_df['name'].head(10)
        x_pos = np.arange(len(items))
        
        ax1.bar(x_pos - 0.2, analysis_df['revenue_current'].head(10), 0.4, 
                label='Revenue', alpha=0.8, color='steelblue')
        ax1.bar(x_pos + 0.2, analysis_df['profit_current'].head(10), 0.4, 
                label='Profit', alpha=0.8, color='orange')
        
        ax1.set_xlabel('Items')
        ax1.set_ylabel('Amount ($)')
        ax1.set_title('Revenue vs Profit (Top 10 Items)')
        ax1.set_xticks(x_pos)
        ax1.set_xticklabels([name[:20] + '...' if len(name) > 20 else name for name in items], 
                           rotation=45, ha='right')
        ax1.legend()
        ax1.grid(True, alpha=0.3)
        
        # Profit Margin Analysis
        analysis_df_copy = analysis_df.copy()
        analysis_df_copy['profit_margin'] = np.where(analysis_df_copy['revenue_current'] > 0,
                                                   analysis_df_copy['profit_current'] / analysis_df_copy['revenue_current'],
                                                   0)
        
        scatter = ax2.scatter(analysis_df_copy['revenue_current'], analysis_df_copy['profit_current'],
                             s=analysis_df_copy['sales_lift'] * 50, alpha=0.6, c=analysis_df_copy['profit_margin'],
                             cmap='RdYlGn')
        
        ax2.set_xlabel('Revenue ($)')
        ax2.set_ylabel('Profit ($)')
        ax2.set_title('Revenue vs Profit (Bubble size = Sales Lift)')
        ax2.grid(True, alpha=0.3)
        
        # Add colorbar
        cbar = plt.colorbar(scatter, ax=ax2)
        cbar.set_label('Profit Margin')
        
        plt.tight_layout()
        plt.show()
    
    def plot_variance_analysis(self, analysis_df):
        """Create variance analysis charts"""
        fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(16, 10))
        
        # Revenue and Profit Variance
        items = analysis_df['name'].head(15)
        x_pos = np.arange(len(items))
        
        colors_rev = ['green' if x >= 0 else 'red' for x in analysis_df['revenue_variance'].head(15)]
        colors_prof = ['green' if x >= 0 else 'red' for x in analysis_df['profit_variance'].head(15)]
        
        ax1.bar(x_pos, analysis_df['revenue_variance'].head(15), color=colors_rev, alpha=0.7)
        ax1.set_xlabel('Items')
        ax1.set_ylabel('Revenue Variance ($)')
        ax1.set_title('Revenue Variance by Item (Top 15)')
        ax1.set_xticks(x_pos)
        ax1.set_xticklabels([name[:15] + '...' if len(name) > 15 else name for name in items], 
                           rotation=45, ha='right')
        ax1.axhline(y=0, color='black', linestyle='-', alpha=0.5)
        ax1.grid(True, alpha=0.3)
        
        ax2.bar(x_pos, analysis_df['profit_variance'].head(15), color=colors_prof, alpha=0.7)
        ax2.set_xlabel('Items')
        ax2.set_ylabel('Profit Variance ($)')
        ax2.set_title('Profit Variance by Item (Top 15)')
        ax2.set_xticks(x_pos)
        ax2.set_xticklabels([name[:15] + '...' if len(name) > 15 else name for name in items], 
                           rotation=45, ha='right')
        ax2.axhline(y=0, color='black', linestyle='-', alpha=0.5)
        ax2.grid(True, alpha=0.3)
        
        plt.tight_layout()
        plt.show()
    
    def plot_sales_lift(self, analysis_df):
        """Create sales lift analysis"""
        fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
        
        # Sales Lift Bar Chart
        items = analysis_df['name'].head(15)
        lifts = analysis_df['sales_lift'].head(15)
        colors = ['green' if x >= 1 else 'red' for x in lifts]
        
        ax1.bar(range(len(items)), lifts, color=colors, alpha=0.7)
        ax1.set_xlabel('Items')
        ax1.set_ylabel('Sales Lift (Ratio)')
        ax1.set_title('Sales Lift by Item (Top 15)')
        ax1.set_xticks(range(len(items)))
        ax1.set_xticklabels([name[:15] + '...' if len(name) > 15 else name for name in items], 
                           rotation=45, ha='right')
        ax1.axhline(y=1, color='black', linestyle='--', alpha=0.7, label='Baseline (1.0x)')
        ax1.legend()
        ax1.grid(True, alpha=0.3)
        
        # Sales Lift Distribution
        ax2.hist(analysis_df['sales_lift'], bins=20, alpha=0.7, color='skyblue', edgecolor='black')
        ax2.axvline(x=1, color='red', linestyle='--', alpha=0.7, label='Baseline (1.0x)')
        ax2.axvline(x=analysis_df['sales_lift'].mean(), color='orange', linestyle='-', 
                   alpha=0.7, label=f'Mean ({analysis_df["sales_lift"].mean():.2f}x)')
        ax2.set_xlabel('Sales Lift')
        ax2.set_ylabel('Frequency')
        ax2.set_title('Sales Lift Distribution')
        ax2.legend()
        ax2.grid(True, alpha=0.3)
        
        plt.tight_layout()
        plt.show()
    
    def plot_performance_matrix(self, analysis_df):
        """Create performance matrix"""
        fig, ax = plt.subplots(figsize=(12, 8))
        
        # Create quadrant analysis
        revenue_median = analysis_df['revenue_current'].median()
        profit_median = analysis_df['profit_current'].median()
        
        # Color code by quadrant
        colors = []
        for _, row in analysis_df.iterrows():
            if row['revenue_current'] >= revenue_median and row['profit_current'] >= profit_median:
                colors.append('green')  # High revenue, high profit
            elif row['revenue_current'] >= revenue_median and row['profit_current'] < profit_median:
                colors.append('orange')  # High revenue, low profit
            elif row['revenue_current'] < revenue_median and row['profit_current'] >= profit_median:
                colors.append('blue')  # Low revenue, high profit
            else:
                colors.append('red')  # Low revenue, low profit
        
        scatter = ax.scatter(analysis_df['revenue_current'], analysis_df['profit_current'],
                           s=analysis_df['sales_lift'] * 100, alpha=0.6, c=colors)
        
        # Add quadrant lines
        ax.axvline(x=revenue_median, color='black', linestyle='--', alpha=0.5)
        ax.axhline(y=profit_median, color='black', linestyle='--', alpha=0.5)
        
        # Add quadrant labels
        ax.text(analysis_df['revenue_current'].max() * 0.8, analysis_df['profit_current'].max() * 0.9,
                'High Rev\nHigh Profit', ha='center', va='center', fontsize=10, 
                bbox=dict(boxstyle="round,pad=0.3", facecolor="lightgreen", alpha=0.7))
        
        ax.text(analysis_df['revenue_current'].max() * 0.8, analysis_df['profit_current'].max() * 0.1,
                'High Rev\nLow Profit', ha='center', va='center', fontsize=10,
                bbox=dict(boxstyle="round,pad=0.3", facecolor="orange", alpha=0.7))
        
        ax.text(analysis_df['revenue_current'].max() * 0.2, analysis_df['profit_current'].max() * 0.9,
                'Low Rev\nHigh Profit', ha='center', va='center', fontsize=10,
                bbox=dict(boxstyle="round,pad=0.3", facecolor="lightblue", alpha=0.7))
        
        ax.text(analysis_df['revenue_current'].max() * 0.2, analysis_df['profit_current'].max() * 0.1,
                'Low Rev\nLow Profit', ha='center', va='center', fontsize=10,
                bbox=dict(boxstyle="round,pad=0.3", facecolor="lightcoral", alpha=0.7))
        
        ax.set_xlabel('Revenue ($)')
        ax.set_ylabel('Profit ($)')
        ax.set_title('Performance Matrix (Bubble size = Sales Lift)')
        ax.grid(True, alpha=0.3)
        
        plt.tight_layout()
        plt.show()
    
    def show_summary_table(self, analysis_df):
        """Display summary table"""
        # Select key columns for display
        display_cols = ['name', 'store_id', 'revenue_current', 'profit_current', 
                       'revenue_variance', 'profit_variance', 'sales_lift']
        
        table_df = analysis_df[display_cols].copy()
        table_df.columns = ['Item Name', 'Store ID', 'Current Revenue', 'Current Profit',
                           'Revenue Variance', 'Profit Variance', 'Sales Lift']
        
        # Format currency columns
        for col in ['Current Revenue', 'Current Profit', 'Revenue Variance', 'Profit Variance']:
            table_df[col] = table_df[col].apply(lambda x: f'${x:,.0f}')
        
        table_df['Sales Lift'] = table_df['Sales Lift'].apply(lambda x: f'{x:.2f}x')
        
        print("\nDETAILED ANALYSIS TABLE")
        print("="*120)
        print(table_df.to_string(index=False, max_colwidth=30))
    
    def update_dashboard(self):
        """Update the entire dashboard"""
        with self.output:
            clear_output(wait=True)
            
            # Filter and sort data
            analysis_df = self.filter_and_sort_data()
            
            if analysis_df.empty:
                print("No data available with current filters.")
                return
            
            # Show summary statistics
            self.create_summary_stats(analysis_df)
            
            # Create visualizations based on selected chart type
            if self.chart_type.value == 'revenue_profit':
                self.plot_revenue_profit(analysis_df)
            elif self.chart_type.value == 'variance':
                self.plot_variance_analysis(analysis_df)
            elif self.chart_type.value == 'lift':
                self.plot_sales_lift(analysis_df)
            elif self.chart_type.value == 'matrix':
                self.plot_performance_matrix(analysis_df)
            elif self.chart_type.value == 'table':
                self.show_summary_table(analysis_df)
    
    def display(self):
        """Display the complete dashboard"""
        # Create layout
        period_box = widgets.HBox([self.current_period, self.comparison_period])
        filter_box = widgets.HBox([self.item_filter, self.store_filter, self.merchant_filter])
        control_box = widgets.HBox([self.sort_by, self.top_n, self.chart_type])
        
        dashboard_layout = widgets.VBox([
            widgets.HTML("<h2>📊 Price Tracking Performance Dashboard</h2>"),
            widgets.HTML("<h3>Period Selection</h3>"),
            period_box,
            widgets.HTML("<h3>Filters</h3>"),
            filter_box,
            widgets.HTML("<h3>Display Options</h3>"),
            control_box,
            self.update_button,
            self.output
        ])
        
        display(dashboard_layout)

# Usage example:
dashboard = PriceTrackingDashboard(df_analyzed)
dashboard.display()
# Out:
# VBox(children=(HTML(value='<h2>📊 Price Tracking Performance Dashboard</h2>'), HTML(value='<h3>Period Selection…

# %%
import pandas as pd
from dash import Dash, dcc, html
from dash.dependencies import Input, Output
import plotly.express as px

# Replace this with your actual aggregated DataFrame
df = df_analyzed.copy()

# Unique values for filters
periods   = sorted(df['period_id'].unique())
items     = sorted(df['item_id'].unique())
stores    = sorted(df['store_id'].unique())
merchants = sorted(df['merchant_id'].unique())

app = Dash(__name__)

app.layout = html.Div([
    html.H1("Interactive Promotions Dashboard"),
    html.Div([
        html.Div([
            html.Label("Current Period"),
            dcc.Dropdown(
                id='current-period',
                options=[{'label': p, 'value': p} for p in periods],
                value=periods[-1]
            ),
        ], style={'width': '30%', 'display': 'inline-block'}),
        html.Div([
            html.Label("Promo Period"),
            dcc.Dropdown(
                id='promo-period',
                options=[{'label': p, 'value': p} for p in periods],
                value=periods[0]
            ),
        ], style={'width': '30%', 'display': 'inline-block', 'marginLeft': '2%'}),
    ]),
    html.Div([
        html.Div([
            html.Label("Item"),
            dcc.Dropdown(
                id='item-filter',
                options=[{'label': i, 'value': i} for i in items],
                placeholder="All Items"
            ),
        ], style={'width': '30%', 'display': 'inline-block'}),
        html.Div([
            html.Label("Store"),
            dcc.Dropdown(
                id='store-filter',
                options=[{'label': s, 'value': s} for s in stores],
                placeholder="All Stores"
            ),
        ], style={'width': '30%', 'display': 'inline-block', 'marginLeft': '2%'}),
        html.Div([
            html.Label("Merchant"),
            dcc.Dropdown(
                id='merchant-filter',
                options=[{'label': m, 'value': m} for m in merchants],
                placeholder="All Merchants"
            ),
        ], style={'width': '30%', 'display': 'inline-block', 'marginLeft': '2%'}),
    ], style={'marginTop': '20px'}),
    dcc.Graph(id='revenue-diff'),
    dcc.Graph(id='profit-diff'),
    dcc.Graph(id='lift-chart'),
    dcc.Graph(id='top-revenue-items'),
    dcc.Graph(id='top-profit-items')
])

@app.callback(
    [
        Output('revenue-diff', 'figure'),
        Output('profit-diff', 'figure'),
        Output('lift-chart', 'figure'),
        Output('top-revenue-items', 'figure'),
        Output('top-profit-items', 'figure')
    ],
    [
        Input('current-period', 'value'),
        Input('promo-period', 'value'),
        Input('item-filter', 'value'),
        Input('store-filter', 'value'),
        Input('merchant-filter', 'value')
    ]
)
def update_charts(current_period, promo_period, item_id, store_id, merchant_id):
    d = df.copy()
    # Apply filters
    if item_id:
        d = d[d['item_id'] == item_id]
    if store_id:
        d = d[d['store_id'] == store_id]
    if merchant_id:
        d = d[d['merchant_id'] == merchant_id]

    # Split periods
    df_curr  = d[d['period_id'] == current_period]
    df_promo = d[d['period_id'] == promo_period]

    # Merge on item/store/merchant
    merged = pd.merge(
        df_curr, df_promo,
        on=['item_id','store_id','merchant_id'],
        suffixes=('_curr', '_promo')
    )

    # Calculate diffs & lift
    merged['rev_diff']    = merged['revenue_curr'] - merged['revenue_promo']
    merged['profit_diff'] = merged['profit_curr']  - merged['profit_promo']
    merged['lift']        = merged['total_units_sold_curr'] / merged['total_units_sold_promo']

    # Build figures
    fig_rev_diff = px.bar(
        merged, x='item_id', y='rev_diff',
        labels={'rev_diff':'Revenue Δ'},
        title="Revenue Change (Current vs Promo)"
    )
    fig_profit_diff = px.bar(
        merged, x='item_id', y='profit_diff',
        labels={'profit_diff':'Profit Δ'},
        title="Profit Change (Current vs Promo)"
    )
    fig_lift = px.bar(
        merged, x='item_id', y='lift',
        labels={'lift':'Sales Lift'},
        title="Sales Lift Ratio"
    )

    top_rev = df_curr.groupby('item_id', as_index=False)['revenue'].sum().nlargest(10,'revenue')
    fig_top_rev = px.bar(
        top_rev, x='item_id', y='revenue',
        title="Top 10 Items by Revenue"
    )

    top_profit = df_curr.groupby('item_id', as_index=False)['profit'].sum().nlargest(10,'profit')
    fig_top_profit = px.bar(
        top_profit, x='item_id', y='profit',
        title="Top 10 Items by Profit"
    )

    return fig_rev_diff, fig_profit_diff, fig_lift, fig_top_rev, fig_top_profit

if __name__ == '__main__':
    app.run(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:5001/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # unused

# %%
def create_item_selector(df):
    """
    Create an interactive widget for selecting and visualizing items
    """
    # Get available items
    available_items = get_available_items(df)
    
    # Create dropdown options (item_id: name format)
    dropdown_options = [(f"{row['item_id']}: {row['name']}", row['item_id']) 
                       for _, row in available_items.iterrows()]
    
    # Create widgets
    item_dropdown = widgets.Dropdown(
        options=dropdown_options,
        description='Select Item:',
        style={'description_width': 'initial'},
        layout=widgets.Layout(width='600px')
    )
    
    # Multi-select for comparing multiple items
    multi_select = widgets.SelectMultiple(
        options=dropdown_options,
        description='Compare Items:',
        style={'description_width': 'initial'},
        layout=widgets.Layout(width='600px', height='150px')
    )
    
    # Buttons
    plot_single_btn = widgets.Button(description="Plot Single Item", button_style='primary')
    plot_compare_btn = widgets.Button(description="Compare Multiple Items", button_style='success')
    show_stats_btn = widgets.Button(description="Show Statistics", button_style='info')
    
    # Output area
    output = widgets.Output()
    
    def plot_single_item(b):
        with output:
            clear_output(wait=True)
            if item_dropdown.value:
                plot_price_variance(df, item_dropdown.value)
    
    def plot_multiple_items(b):
        with output:
            clear_output(wait=True)
            if multi_select.value:
                plot_multiple_price_variance(df, list(multi_select.value))
    
    def show_item_statistics(b):
        with output:
            clear_output(wait=True)
            if multi_select.value:
                show_price_statistics(df, list(multi_select.value))
            elif item_dropdown.value:
                show_price_statistics(df, [item_dropdown.value])
    
    # Bind button clicks
    plot_single_btn.on_click(plot_single_item)
    plot_compare_btn.on_click(plot_multiple_items)
    show_stats_btn.on_click(show_item_statistics)
    
    # Layout
    ui = widgets.VBox([
        widgets.HTML("<h3>Item Price Analysis Dashboard</h3>"),
        widgets.HTML(f"<p>Total items available: {len(available_items)}</p>"),
        widgets.HTML("<h4>Single Item Analysis:</h4>"),
        item_dropdown,
        plot_single_btn,
        widgets.HTML("<h4>Multi-Item Comparison:</h4>"),
        multi_select,
        widgets.HBox([plot_compare_btn, show_stats_btn]),
        output
    ])
    
    return ui

def plot_multiple_price_variance(df, item_ids, max_items=5):
    """
    Plot price variance for multiple items on the same chart
    """
    if len(item_ids) > max_items:
        print(f"Too many items selected. Showing first {max_items} items.")
        item_ids = item_ids[:max_items]
    
    plt.figure(figsize=(15, 8))
    
    colors = plt.cm.Set3(np.linspace(0, 1, len(item_ids)))
    
    for i, item_id in enumerate(item_ids):
        # Filter data for this item
        d = df[df['item_id'] == item_id].sort_values('day').copy()
        if d.empty:
            continue
            
        # Convert price columns to numeric
        price_cols = ['regular_price', 'sale_price', 'selling_price']
        for col in price_cols:
            if col in d.columns:
                d[col] = pd.to_numeric(d[col], errors='coerce')
        
        item_name = d['name'].iloc[0]
        color = colors[i]
        
        # Plot selling price (most important for comparison)
        if 'selling_price' in d.columns:
            selling_data = d[d['selling_price'].notna()]
            if not selling_data.empty:
                plt.plot(selling_data['day'], selling_data['selling_price'], 
                        label=f'{item_id}: {item_name[:30]}...', 
                        marker='o', linewidth=2, color=color)
    
    plt.xlabel('Date')
    plt.ylabel('Selling Price ($)')
    plt.title('Price Comparison Across Multiple Items')
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.xticks(rotation=45)
    plt.grid(True, alpha=0.3)
    plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${x:.2f}'))
    plt.tight_layout()
    plt.show()
